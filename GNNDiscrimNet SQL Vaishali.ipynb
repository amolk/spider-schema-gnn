# %% [markdown]
# ## GNNDiscrimNet SQL
# ```
# Input: NLU + Predicted Columns
# Output: 1 if correct, 0 if incorrect
# Side effect: Reranking of BEAM outputs from GNN model
# Architecture:
# BERT + classification layer
# ```

# %% [markdown]
# The beam output files are generated with the following command: (beam output should be 40 instead of 10 for train, can be 10 for dev). Make sure to modify the json source file (train, dev etc) as needed
# ```
# allennlp predict experiments/bert-spider-low-lr/ ./datasets/spider/train_spider.json --predictor spider_discriminator --use-dataset-reader --cuda-device=0 --silent --output-file out.jsonlines --include-package models.semantic_parsing.spider_parser --include-package dataset_readers.spider --include-package predictors.discriminator_dataset_generator --weights-file experiments/bert-spider-low-lr/best.th
# ```

# %%
# !pip install transformers
# !conda install -y -c conda-forge ipywidgets

# %%
# !conda install -y line_profiler

# %%
import os

# %%
os.environ['CUDA_VISIBLE_DEVICES'] = '0'

# %%
#!pip install sql_metadata

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from transformers import *
import numpy as np
import sql_metadata
from pathlib import Path
import json
from tqdm import tqdm_notebook as tqdm
import pprint
import random

# %%
# %load_ext line_profiler

# %%
pp = pprint.PrettyPrinter(indent=2)

# %%
def load_beam_outputs(filename):
    filename = Path(filename)
    data = []
    with filename.open('r') as f:
        for line in f:
            data.append(json.loads(line))
    return data

# %%
val_items = load_beam_outputs('dev_normal.jsonlines')#'dev_all_beam.jsonlines')
#train_items = load_beam_outputs('train_full.jsonlines')#'train_all_beam.jsonlines')  # train_all = train_spider + train_others
#val_normaleval_items = load_beam_outputs('dev_full.jsonlines')#'dev_all_normaleval_beam.jsonlines') # Created with the easier evaluator

# %%
val_items[226]
# Out:
# {'utterance': 'What is the airport code of the airport with the most flights?',
#  'instances': [{'sql_query': 'select airports.airportcode from flights join airports on flights.destairport = airports.airportcode group by airports.airportcode order by count ( * ) desc limit 1',
#    'tables_used': ['flights', 'airports'],
#    'columns_used': [['airports', 'airportcode'], ['flights', 'destairport']]},
#   {'sql_query': 'select airports.airportcode from flights join airports on flights.sourceairport = airports.airportcode group by airports.airportcode order by count ( * ) desc limit 1',
#    'tables_used': ['flights', 'airports'],
#    'columns_used': [['airports', 'airportcode'],
#     ['flights', 'sourceairport']]},
#   {'sql_query': 'select airports.airportcode from airports group by airports.airportcode order by count ( * ) desc limit 1',
#    'tables_used': ['airports'],
#    'columns_used': [['airports', 'airportcode']]},
#   {'sql_query': 'select airports.airportcode from flights join airports on flights.destairport = airports.airportcode group by airports.airportcode order by sum ( flights.destairport ) desc limit 1',
#    'tables_used': ['flights', 'airports'],
#    'columns_used': [['airports', 'airportcode'], ['flights', 'destairport']]},
#   {'sql_query': 'select airports.airportcode from airports join flights on airports.airportcode = flights.destairport group by flights.destairport order by count ( * ) desc limit 1',
#    'tables_used': ['flights', 'airports'],
#    'columns_used': [['airports', 'airportcode'], ['flights', 'destairport']]},
#   {'sql_query': 'select airports.airportcode from flights join airports on flights.destairport = airports.airportcode group by airports.airportcode order by sum ( flights.sourceairport ) desc limit 1',
#    'tables_used': ['flights', 'airports'],
#    'columns_used': [['airports', 'airportcode'],
#     ['flights', 'sourceairport'],
#     ['flights', 'destairport']]},
#   {'sql_query': 'select airports.airportcode from flights join airports on flights.sourceairport = airports.airportcode group by airports.airportcode order by sum ( flights.destairport ) desc limit 1',
#    'tables_used': ['flights', 'airports'],
#    'columns_used': [['airports', 'airportcode'],
#     ['flights', 'sourceairport'],
#     ['flights', 'destairport']]},
#   {'sql_query': 'select airports.airportcode from flights join airports on flights.sourceairport = airports.airportcode group by airports.airportcode order by sum ( flights.sourceairport ) desc limit 1',
#    'tables_used': ['flights', 'airports'],
#    'columns_used': [['airports', 'airportcode'],
#     ['flights', 'sourceairport']]},
#   {'sql_query': 'select airports.airportcode from airports join flights on airports.airportcode = flights.sourceairport group by flights.destairport order by count ( * ) desc limit 1',
#    'tables_used': ['flights', 'airports'],
#    'columns_used': [['flights', 'sourceairport'],
#     ['airports', 'airportcode'],
#     ['flights', 'destairport']]},
#   {'sql_query': 'select airports.airportcode from airports join flights on airports.airportcode = flights.destairport group by airports.airportcode order by count ( * ) desc limit 1',
#    'tables_used': ['flights', 'airports'],
#    'columns_used': [['airports', 'airportcode'], ['flights', 'destairport']]},
#   {'sql_query': 'select airports.airportcode from airports join flights on airports.airportcode = flights.destairport group by flights.sourceairport order by count ( * ) desc limit 1',
#    'tables_used': ['flights', 'airports'],
#    'columns_used': [['airports', 'airportcode'],
#     ['flights', 'sourceairport'],
#     ['flights', 'destairport']]},
#   {'sql_query': 'select airports.airportcode from airports group by airports.airportcode order by sum ( airports.airportname ) desc limit 1',
#    'tables_used': ['airports'],
#    'columns_used': [['airports', 'airportcode'], ['airports', 'airportname']]},
#   {'sql_query': 'select airports.airportcode from airports join flights on airports.airportcode = flights.destairport group by flights.destairport order by sum ( flights.flightno ) desc limit 1',
#    'tables_used': ['flights', 'airports'],
#    'columns_used': [['flights', 'destairport'],
#     ['airports', 'airportcode'],
#     ['flights', 'flightno']]},
#   {'sql_query': 'select airports.airportcode from airports join flights on airports.airportcode = flights.sourceairport group by airports.airportcode order by count ( * ) desc limit 1',
#    'tables_used': ['flights', 'airports'],
#    'columns_used': [['flights', 'sourceairport'],
#     ['airports', 'airportcode']]},
#   {'sql_query': 'select airports.airportcode from airports join flights on airports.airportcode = flights.sourceairport group by flights.sourceairport order by count ( * ) desc limit 1',
#    'tables_used': ['flights', 'airports'],
#    'columns_used': [['flights', 'sourceairport'],
#     ['airports', 'airportcode']]},
#   {'sql_query': 'select airports.airportcode from flights join airports on airports.airportcode = flights.destairport group by airports.airportcode order by count ( * ) desc limit 1',
#    'tables_used': ['flights', 'airports'],
#    'columns_used': [['airports', 'airportcode'], ['flights', 'destairport']]},
#   {'sql_query': 'select airports.airportcode from airports join flights on airports.airportcode = flights.sourceairport group by flights.destairport order by sum ( flights.flightno ) desc limit 1',
#    'tables_used': ['flights', 'airports'],
#    'columns_used': [['flights', 'destairport'],
#     ['flights', 'sourceairport'],
#     ['airports', 'airportcode'],
#     ['flights', 'flightno']]},
#   {'sql_query': 'select airports.airportcode from airports join flights on airports.airportcode = flights.destairport group by flights.sourceairport order by sum ( flights.flightno ) desc limit 1',
#    'tables_used': ['flights', 'airports'],
#    'columns_used': [['flights', 'destairport'],
#     ['airports', 'airportcode'],
#     ['flights', 'sourceairport'],
#     ['flights', 'flightno']]},
#   {'sql_query': 'select airports.airportcode from airports group by airports.airportname order by count ( * ) desc limit 1',
#    'tables_used': ['airports'],
#    'columns_used': [['airports', 'airportcode'], ['airports', 'airportname']]},
#   {'sql_query': 'select airports.airportcode from airports join flights on airports.airportcode = flights.destairport group by airports.airportcode order by sum ( flights.destairport ) desc limit 1',
#    'tables_used': ['flights', 'airports'],
#    'columns_used': [['airports', 'airportcode'], ['flights', 'destairport']]},
#   {'sql_query': 'select airports.airportcode from airports join flights on airports.airportcode = flights.destairport group by flights.destairport order by sum ( flights.airline ) desc limit 1',
#    'tables_used': ['flights', 'airports'],
#    'columns_used': [['flights', 'airline'],
#     ['airports', 'airportcode'],
#     ['flights', 'destairport']]},
#   {'sql_query': 'select airports.airportcode from airports join flights on airports.airportcode = flights.destairport group by airports.airportname order by count ( * ) desc limit 1',
#    'tables_used': ['flights', 'airports'],
#    'columns_used': [['flights', 'destairport'],
#     ['airports', 'airportcode'],
#     ['airports', 'airportname']]},
#   {'sql_query': 'select airports.airportcode from flights join airports on airports.airportcode = flights.sourceairport group by airports.airportcode order by count ( * ) desc limit 1',
#    'tables_used': ['flights', 'airports'],
#    'columns_used': [['flights', 'sourceairport'],
#     ['airports', 'airportcode']]},
#   {'sql_query': 'select airports.airportname from airports join flights on airports.airportcode = flights.destairport group by airports.airportcode order by count ( * ) desc limit 1',
#    'tables_used': ['flights', 'airports'],
#    'columns_used': [['flights', 'destairport'],
#     ['airports', 'airportcode'],
#     ['airports', 'airportname']]},
#   {'sql_query': 'select airports.airportcode from airports join flights on airports.airportcode = flights.sourceairport group by flights.sourceairport order by sum ( flights.flightno ) desc limit 1',
#    'tables_used': ['flights', 'airports'],
#    'columns_used': [['flights', 'sourceairport'],
#     ['airports', 'airportcode'],
#     ['flights', 'flightno']]},
#   {'sql_query': 'select airports.airportcode from airports join flights on airports.airportcode = flights.destairport group by airports.airportcode order by sum ( flights.sourceairport ) desc limit 1',
#    'tables_used': ['flights', 'airports'],
#    'columns_used': [['airports', 'airportcode'],
#     ['flights', 'sourceairport'],
#     ['flights', 'destairport']]},
#   {'sql_query': 'select airports.airportname from airports join flights on airports.airportcode = flights.destairport group by flights.destairport order by count ( * ) desc limit 1',
#    'tables_used': ['flights', 'airports'],
#    'columns_used': [['flights', 'destairport'],
#     ['airports', 'airportcode'],
#     ['airports', 'airportname']]},
#   {'sql_query': 'select airports.airportcode from airports join flights on airports.airportcode = flights.sourceairport group by airports.airportcode order by sum ( flights.destairport ) desc limit 1',
#    'tables_used': ['flights', 'airports'],
#    'columns_used': [['flights', 'sourceairport'],
#     ['airports', 'airportcode'],
#     ['flights', 'destairport']]},
#   {'sql_query': 'select airports.airportcode from airports join flights on airports.airportcode = flights.sourceairport group by flights.destairport order by sum ( flights.airline ) desc limit 1',
#    'tables_used': ['flights', 'airports'],
#    'columns_used': [['flights', 'airline'],
#     ['flights', 'sourceairport'],
#     ['airports', 'airportcode'],
#     ['flights', 'destairport']]},
#   {'sql_query': 'select airports.airportcode from airports join flights on airports.airportcode = flights.sourceairport group by airports.airportname order by count ( * ) desc limit 1',
#    'tables_used': ['flights', 'airports'],
#    'columns_used': [['flights', 'sourceairport'],
#     ['airports', 'airportcode'],
#     ['airports', 'airportname']]},
#   {'sql_query': 'select airports.airportcode from airports join flights on airports.airportcode = flights.destairport group by flights.sourceairport order by sum ( flights.airline ) desc limit 1',
#    'tables_used': ['flights', 'airports'],
#    'columns_used': [['flights', 'airline'],
#     ['airports', 'airportcode'],
#     ['flights', 'sourceairport'],
#     ['flights', 'destairport']]},
#   {'sql_query': 'select airports.airportcode from flights join airports on flights.destairport = airports.airportcode group by airports.airportname order by count ( * ) desc limit 1',
#    'tables_used': ['flights', 'airports'],
#    'columns_used': [['flights', 'destairport'],
#     ['airports', 'airportcode'],
#     ['airports', 'airportname']]},
#   {'sql_query': 'select airports.airportcode from flights join airports on flights.destairport = airports.airportcode group by flights.destairport order by count ( * ) desc limit 1',
#    'tables_used': ['flights', 'airports'],
#    'columns_used': [['airports', 'airportcode'], ['flights', 'destairport']]},
#   {'sql_query': 'select airports.airportcode from flights join airports on airports.airportcode = flights.destairport group by airports.airportcode order by sum ( flights.destairport ) desc limit 1',
#    'tables_used': ['flights', 'airports'],
#    'columns_used': [['airports', 'airportcode'], ['flights', 'destairport']]},
#   {'sql_query': 'select airports.airportcode from airports order by airports.airportname desc limit 1',
#    'tables_used': ['airports'],
#    'columns_used': [['airports', 'airportcode'], ['airports', 'airportname']]},
#   {'sql_query': 'select airports.airportcode from flights join airports on flights.destairport = airports.airportname group by airports.airportcode order by count ( * ) desc limit 1',
#    'tables_used': ['flights', 'airports'],
#    'columns_used': [['airports', 'airportname'],
#     ['airports', 'airportcode'],
#     ['flights', 'destairport']]},
#   {'sql_query': 'select airports.airportname from airports join flights on airports.airportcode = flights.sourceairport group by airports.airportcode order by count ( * ) desc limit 1',
#    'tables_used': ['flights', 'airports'],
#    'columns_used': [['flights', 'sourceairport'],
#     ['airports', 'airportcode'],
#     ['airports', 'airportname']]},
#   {'sql_query': 'select airports.airportcode from airports join flights on airports.airportcode = flights.sourceairport group by airports.airportcode order by sum ( flights.sourceairport ) desc limit 1',
#    'tables_used': ['flights', 'airports'],
#    'columns_used': [['flights', 'sourceairport'],
#     ['airports', 'airportcode']]},
#   {'sql_query': 'select airports.airportname from airports join flights on airports.airportcode = flights.sourceairport group by flights.destairport order by count ( * ) desc limit 1',
#    'tables_used': ['flights', 'airports'],
#    'columns_used': [['airports', 'airportname'],
#     ['flights', 'sourceairport'],
#     ['airports', 'airportcode'],
#     ['flights', 'destairport']]},
#   {'sql_query': 'select airports.airportname from airports join flights on airports.airportcode = flights.destairport group by flights.sourceairport order by count ( * ) desc limit 1',
#    'tables_used': ['flights', 'airports'],
#    'columns_used': [['flights', 'destairport'],
#     ['airports', 'airportcode'],
#     ['flights', 'sourceairport'],
#     ['airports', 'airportname']]}]}

# %%
count = 0
count_acc = 0
count_too_many_targets = 0
for idx, item in enumerate(val_items):
    instances = item['instances']
    if len(list(filter(lambda instance: instance['target'] > 0.5, instances))) == 0:
        count +=1
    if len(list(filter(lambda instance: instance['target'] > 0.5, instances))) > 1:
        count_too_many_targets += 1
    if instances[0]['target'] > 0.5:
        count_acc += 1
len(val_items), count, count_acc, count_too_many_targets
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-d198bf8ad6ca> in <module>
#       4 for idx, item in enumerate(val_items):
#       5     instances = item['instances']
# ----> 6     if len(list(filter(lambda instance: instance['target'] > 0.5, instances))) == 0:
#       7         count +=1
#       8     if len(list(filter(lambda instance: instance['target'] > 0.5, instances))) > 1:
#
# <ipython-input-13-d198bf8ad6ca> in <lambda>(instance)
#       4 for idx, item in enumerate(val_items):
#       5     instances = item['instances']
# ----> 6     if len(list(filter(lambda instance: instance['target'] > 0.5, instances))) == 0:
#       7         count +=1
#       8     if len(list(filter(lambda instance: instance['target'] > 0.5, instances))) > 1:
#
# KeyError: 'target'

# %%
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')

# %%
# Creates the input for BERT:
# Returns the tokenized bert input [CLS] <tokenized nlu> [SEP] col1 [SEP] col2 ...[SEP]
# and the start and end locations in the tokenized input for each of the columns
def create_tokenized_input(tokenizer, nlu, sql):
    tokens = []
    tokens += tokenizer.tokenize('[CLS]')
    tokens += tokenizer.tokenize(nlu)
    tokens += tokenizer.tokenize('[SEP]')
    tokens += tokenizer.tokenize(sql)
    tokens += tokenizer.tokenize('[SEP]')
    column_locations = []
    return tokens, tokenizer.convert_tokens_to_ids(tokens)

# %%
# {'utterance': 'How many singers do we have?',
# 'instances': [{'sql_query': 'select count ( * ) from singer',
#   'tables_used': ['singer'],
#   'columns_used': [],
#   'target': 1.0},
def preprocess_data(tokenizer, data, train=True):
    new_data = []
    for sample in tqdm(data):
        new_sample = {}
        new_sample['utterance'] = sample['utterance']
        correct_instances = []
        incorrect_instances = []
        instances = []
        try:
            sample['instances'][0]['target']
        except:
            continue
        for i, instance in enumerate(sample['instances']):
            #try: 
            #    instance['target']
            #except: 
            #    continue
                
            instance = instance.copy()
            tokens, encoded_tokens = create_tokenized_input(tokenizer, 
                                                            sample['utterance'], 
                                                            instance['sql_query'])
            instance['tokens'] = tokens
            instance['encoded_tokens'] = encoded_tokens
            instance['rank'] = i
            if len(encoded_tokens) <= 512:
                if instance['target'] > 0.5:
                    correct_instances.append(instance)
                else:
                    incorrect_instances.append(instance)
            else:
                print(f'Warning: too many tokens {instance}')
            instances.append(instance)
            
            # TODO(rohan): Handle case where encoded tokens > 512, right now it's being added to instances
        def make_key(instance): return instance['sql_query']
        unique_instances = {}
        uniq_correct_instances = []
        for instance in correct_instances:  # Need to make sure that earlier rank ones are retained
            key = make_key(instance)
            if key not in unique_instances:
                unique_instances[key] = instance
                uniq_correct_instances.append(instance)
        uniq_incorrect_instances = []
        # We don't reset unique_instances because we also want to exclude incorrect instances
        # if there is an equivalent instance in correct_instances
        for instance in incorrect_instances:
            key = make_key(instance)
            if key not in unique_instances:
                unique_instances[key] = instance
                uniq_incorrect_instances.append(instance)
        sample['correct_instances'] = uniq_correct_instances
        sample['incorrect_instances'] = uniq_incorrect_instances
        sample['instances'] = instances

        # TODO(rohan): Not sure if I want this?
        # Commenting out because I it changes the top 10 queries (eg. if there was a correct and incorrect with the same columns)
        # sample['instances'] = sorted(sample['correct_instances'] + sample['incorrect_instances'], key=lambda ins: ins['rank'])
        if train and len(uniq_correct_instances) == 0:  # For training, there must be at least one correct instance
            pass
        else:
            new_data.append(sample)
    return new_data

# %%
#train_data_processed = preprocess_data(tokenizer, train_items, train=True)
val_data_processed = preprocess_data(tokenizer, val_items, train=False)
#val_data_normaleval_preprocessed = preprocess_data(tokenizer, val_normaleval_items, train=False)
# Out:
# HBox(children=(IntProgress(value=0, max=1034), HTML(value='')))

# %%
len(train_data_processed)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-848e608e991a> in <module>
# ----> 1 len(train_data_processed)
#
# NameError: name 'train_data_processed' is not defined

# %%
val_data_processed[0]
# Out:
# {'utterance': 'How many singers do we have?',
#  'instances': [{'sql_query': 'select count ( * ) from singer',
#    'tables_used': ['singer'],
#    'columns_used': [],
#    'target': 1.0,
#    'tokens': ['[CLS]',
#     'how',
#     'many',
#     'singers',
#     'do',
#     'we',
#     'have',
#     '?',
#     '[SEP]',
#     'select',
#     'count',
#     '(',
#     '*',
#     ')',
#     'from',
#     'singer',
#     '[SEP]'],
#    'encoded_tokens': [101,
#     2129,
#     2116,
#     8453,
#     2079,
#     2057,
#     2031,
#     1029,
#     102,
#     7276,
#     4175,
#     1006,
#     1008,
#     1007,
#     2013,
#     3220,
#     102],
#    'rank': 0},
#   {'sql_query': 'select count ( * ) from concert',
#    'tables_used': ['concert'],
#    'columns_used': [],
#    'target': 0.0,
#    'tokens': ['[CLS]',
#     'how',
#     'many',
#     'singers',
#     'do',
#     'we',
#     'have',
#     '?',
#     '[SEP]',
#     'select',
#     'count',
#     '(',
#     '*',
#     ')',
#     'from',
#     'concert',
#     '[SEP]'],
#    'encoded_tokens': [101,
#     2129,
#     2116,
#     8453,
#     2079,
#     2057,
#     2031,
#     1029,
#     102,
#     7276,
#     4175,
#     1006,
#     1008,
#     1007,
#     2013,
#     4164,
#     102],
#    'rank': 1},
#   {'sql_query': 'select count ( * ) from stadium',
#    'tables_used': ['stadium'],
#    'columns_used': [],
#    'target': 0.0,
#    'tokens': ['[CLS]',
#     'how',
#     'many',
#     'singers',
#     'do',
#     'we',
#     'have',
#     '?',
#     '[SEP]',
#     'select',
#     'count',
#     '(',
#     '*',
#     ')',
#     'from',
#     'stadium',
#     '[SEP]'],
#    'encoded_tokens': [101,
#     2129,
#     2116,
#     8453,
#     2079,
#     2057,
#     2031,
#     1029,
#     102,
#     7276,
#     4175,
#     1006,
#     1008,
#     1007,
#     2013,
#     3346,
#     102],
#    'rank': 2},
#   {'sql_query': 'select count ( * ) from singer_in_concert',
#    'tables_used': ['singer_in_concert'],
#    'columns_used': [],
#    'target': 0.0,
#    'tokens': ['[CLS]',
#     'how',
#     'many',
#     'singers',
#     'do',
#     'we',
#     'have',
#     '?',
#     '[SEP]',
#     'select',
#     'count',
#     '(',
#     '*',
#     ')',
#     'from',
#     'singer',
#     '_',
#     'in',
#     '_',
#     'concert',
#     '[SEP]'],
#    'encoded_tokens': [101,
#     2129,
#     2116,
#     8453,
#     2079,
#     2057,
#     2031,
#     1029,
#     102,
#     7276,
#     4175,
#     1006,
#     1008,
#     1007,
#     2013,
#     3220,
#     1035,
#     1999,
#     1035,
#     4164,
#     102],
#    'rank': 3},
#   {'sql_query': 'select count ( distinct singer.name ) from singer',
#    'tables_used': ['singer'],
#    'columns_used': [['singer', 'name']],
#    'target': 0.0,
#    'tokens': ['[CLS]',
#     'how',
#     'many',
#     'singers',
#     'do',
#     'we',
#     'have',
#     '?',
#     '[SEP]',
#     'select',
#     'count',
#     '(',
#     'distinct',
#     'singer',
#     '.',
#     'name',
#     ')',
#     'from',
#     'singer',
#     '[SEP]'],
#    'encoded_tokens': [101,
#     2129,
#     2116,
#     8453,
#     2079,
#     2057,
#     2031,
#     1029,
#     102,
#     7276,
#     4175,
#     1006,
#     5664,
#     3220,
#     1012,
#     2171,
#     1007,
#     2013,
#     3220,
#     102],
#    'rank': 4},
#   {'sql_query': 'select count ( distinct singer.song_name ) from singer',
#    'tables_used': ['singer'],
#    'columns_used': [['singer', 'song_name']],
#    'target': 0.0,
#    'tokens': ['[CLS]',
#     'how',
#     'many',
#     'singers',
#     'do',
#     'we',
#     'have',
#     '?',
#     '[SEP]',
#     'select',
#     'count',
#     '(',
#     'distinct',
#     'singer',
#     '.',
#     'song',
#     '_',
#     'name',
#     ')',
#     'from',
#     'singer',
#     '[SEP]'],
#    'encoded_tokens': [101,
#     2129,
#     2116,
#     8453,
#     2079,
#     2057,
#     2031,
#     1029,
#     102,
#     7276,
#     4175,
#     1006,
#     5664,
#     3220,
#     1012,
#     2299,
#     1035,
#     2171,
#     1007,
#     2013,
#     3220,
#     102],
#    'rank': 5},
#   {'sql_query': 'select singer.name , count ( * ) from singer group by singer.name',
#    'tables_used': ['singer'],
#    'columns_used': [['singer', 'name']],
#    'target': 0.0,
#    'tokens': ['[CLS]',
#     'how',
#     'many',
#     'singers',
#     'do',
#     'we',
#     'have',
#     '?',
#     '[SEP]',
#     'select',
#     'singer',
#     '.',
#     'name',
#     ',',
#     'count',
#     '(',
#     '*',
#     ')',
#     'from',
#     'singer',
#     'group',
#     'by',
#     'singer',
#     '.',
#     'name',
#     '[SEP]'],
#    'encoded_tokens': [101,
#     2129,
#     2116,
#     8453,
#     2079,
#     2057,
#     2031,
#     1029,
#     102,
#     7276,
#     3220,
#     1012,
#     2171,
#     1010,
#     4175,
#     1006,
#     1008,
#     1007,
#     2013,
#     3220,
#     2177,
#     2011,
#     3220,
#     1012,
#     2171,
#     102],
#    'rank': 6},
#   {'sql_query': 'select count ( distinct singer.song_release_year ) from singer',
#    'tables_used': ['singer'],
#    'columns_used': [['singer', 'song_release_year']],
#    'target': 0.0,
#    'tokens': ['[CLS]',
#     'how',
#     'many',
#     'singers',
#     'do',
#     'we',
#     'have',
#     '?',
#     '[SEP]',
#     'select',
#     'count',
#     '(',
#     'distinct',
#     'singer',
#     '.',
#     'song',
#     '_',
#     'release',
#     '_',
#     'year',
#     ')',
#     'from',
#     'singer',
#     '[SEP]'],
#    'encoded_tokens': [101,
#     2129,
#     2116,
#     8453,
#     2079,
#     2057,
#     2031,
#     1029,
#     102,
#     7276,
#     4175,
#     1006,
#     5664,
#     3220,
#     1012,
#     2299,
#     1035,
#     2713,
#     1035,
#     2095,
#     1007,
#     2013,
#     3220,
#     102],
#    'rank': 7},
#   {'sql_query': 'select count ( distinct singer.singer_id ) from singer',
#    'tables_used': ['singer'],
#    'columns_used': [['singer', 'singer_id']],
#    'target': 0.0,
#    'tokens': ['[CLS]',
#     'how',
#     'many',
#     'singers',
#     'do',
#     'we',
#     'have',
#     '?',
#     '[SEP]',
#     'select',
#     'count',
#     '(',
#     'distinct',
#     'singer',
#     '.',
#     'singer',
#     '_',
#     'id',
#     ')',
#     'from',
#     'singer',
#     '[SEP]'],
#    'encoded_tokens': [101,
#     2129,
#     2116,
#     8453,
#     2079,
#     2057,
#     2031,
#     1029,
#     102,
#     7276,
#     4175,
#     1006,
#     5664,
#     3220,
#     1012,
#     3220,
#     1035,
#     8909,
#     1007,
#     2013,
#     3220,
#     102],
#    'rank': 8},
#   {'sql_query': "select count ( * ) from singer where singer.name = ' value '",
#    'tables_used': ['singer'],
#    'columns_used': [['singer', 'name']],
#    'target': 0.0,
#    'tokens': ['[CLS]',
#     'how',
#     'many',
#     'singers',
#     'do',
#     'we',
#     'have',
#     '?',
#     '[SEP]',
#     'select',
#     'count',
#     '(',
#     '*',
#     ')',
#     'from',
#     'singer',
#     'where',
#     'singer',
#     '.',
#     'name',
#     '=',
#     "'",
#     'value',
#     "'",
#     '[SEP]'],
#    'encoded_tokens': [101,
#     2129,
#     2116,
#     8453,
#     2079,
#     2057,
#     2031,
#     1029,
#     102,
#     7276,
#     4175,
#     1006,
#     1008,
#     1007,
#     2013,
#     3220,
#     2073,
#     3220,
#     1012,
#     2171,
#     1027,
#     1005,
#     3643,
#     1005,
#     102],
#    'rank': 9},
#   {'sql_query': "select count ( * ) from singer where singer.singer_id = ' value '",
#    'tables_used': ['singer'],
#    'columns_used': [['singer', 'singer_id']],
#    'target': 0.0,
#    'tokens': ['[CLS]',
#     'how',
#     'many',
#     'singers',
#     'do',
#     'we',
#     'have',
#     '?',
#     '[SEP]',
#     'select',
#     'count',
#     '(',
#     '*',
#     ')',
#     'from',
#     'singer',
#     'where',
#     'singer',
#     '.',
#     'singer',
#     '_',
#     'id',
#     '=',
#     "'",
#     'value',
#     "'",
#     '[SEP]'],
#    'encoded_tokens': [101,
#     2129,
#     2116,
#     8453,
#     2079,
#     2057,
#     2031,
#     1029,
#     102,
#     7276,
#     4175,
#     1006,
#     1008,
#     1007,
#     2013,
#     3220,
#     2073,
#     3220,
#     1012,
#     3220,
#     1035,
#     8909,
#     1027,
#     1005,
#     3643,
#     1005,
#     102],
#    'rank': 10},
#   {'sql_query': 'select count ( distinct concert.concert_name ) from concert',
#    'tables_used': ['concert'],
#    'columns_used': [['concert', 'concert_name']],
#    'target': 0.0,
#    'tokens': ['[CLS]',
#     'how',
#     'many',
#     'singers',
#     'do',
#     'we',
#     'have',
#     '?',
#     '[SEP]',
#     'select',
#     'count',
#     '(',
#     'distinct',
#     'concert',
#     '.',
#     'concert',
#     '_',
#     'name',
#     ')',
#     'from',
#     'concert',
#     '[SEP]'],
#    'encoded_tokens': [101,
#     2129,
#     2116,
#     8453,
#     2079,
#     2057,
#     2031,
#     1029,
#     102,
#     7276,
#     4175,
#     1006,
#     5664,
#     4164,
#     1012,
#     4164,
#     1035,
#     2171,
#     1007,
#     2013,
#     4164,
#     102],
#    'rank': 11},
#   {'sql_query': 'select count ( distinct singer.age ) from singer',
#    'tables_used': ['singer'],
#    'columns_used': [['singer', 'age']],
#    'target': 0.0,
#    'tokens': ['[CLS]',
#     'how',
#     'many',
#     'singers',
#     'do',
#     'we',
#     'have',
#     '?',
#     '[SEP]',
#     'select',
#     'count',
#     '(',
#     'distinct',
#     'singer',
#     '.',
#     'age',
#     ')',
#     'from',
#     'singer',
#     '[SEP]'],
#    'encoded_tokens': [101,
#     2129,
#     2116,
#     8453,
#     2079,
#     2057,
#     2031,
#     1029,
#     102,
#     7276,
#     4175,
#     1006,
#     5664,
#     3220,
#     1012,
#     2287,
#     1007,
#     2013,
#     3220,
#     102],
#    'rank': 12},
#   {'sql_query': 'select count ( * ) from concert join singer on singer.singer_id = concert.stadium_id',
#    'tables_used': ['concert', 'singer'],
#    'columns_used': [['concert', 'stadium_id'], ['singer', 'singer_id']],
#    'target': 0.0,
#    'tokens': ['[CLS]',
#     'how',
#     'many',
#     'singers',
#     'do',
#     'we',
#     'have',
#     '?',
#     '[SEP]',
#     'select',
#     'count',
#     '(',
#     '*',
#     ')',
#     'from',
#     'concert',
#     'join',
#     'singer',
#     'on',
#     'singer',
#     '.',
#     'singer',
#     '_',
#     'id',
#     '=',
#     'concert',
#     '.',
#     'stadium',
#     '_',
#     'id',
#     '[SEP]'],
#    'encoded_tokens': [101,
#     2129,
#     2116,
#     8453,
#     2079,
#     2057,
#     2031,
#     1029,
#     102,
#     7276,
#     4175,
#     1006,
#     1008,
#     1007,
#     2013,
#     4164,
#     3693,
#     3220,
#     2006,
#     3220,
#     1012,
#     3220,
#     1035,
#     8909,
#     1027,
#     4164,
#     1012,
#     3346,
#     1035,
#     8909,
#     102],
#    'rank': 13},
#   {'sql_query': 'select count ( distinct singer.country ) from singer',
#    'tables_used': ['singer'],
#    'columns_used': [['singer', 'country']],
#    'target': 0.0,
#    'tokens': ['[CLS]',
#     'how',
#     'many',
#     'singers',
#     'do',
#     'we',
#     'have',
#     '?',
#     '[SEP]',
#     'select',
#     'count',
#     '(',
#     'distinct',
#     'singer',
#     '.',
#     'country',
#     ')',
#     'from',
#     'singer',
#     '[SEP]'],
#    'encoded_tokens': [101,
#     2129,
#     2116,
#     8453,
#     2079,
#     2057,
#     2031,
#     1029,
#     102,
#     7276,
#     4175,
#     1006,
#     5664,
#     3220,
#     1012,
#     2406,
#     1007,
#     2013,
#     3220,
#     102],
#    'rank': 14},
#   {'sql_query': 'select count ( * ) from singer join concert on singer.singer_id = concert.stadium_id',
#    'tables_used': ['singer', 'concert'],
#    'columns_used': [['concert', 'stadium_id'], ['singer', 'singer_id']],
#    'target': 0.0,
#    'tokens': ['[CLS]',
#     'how',
#     'many',
#     'singers',
#     'do',
#     'we',
#     'have',
#     '?',
#     '[SEP]',
#     'select',
#     'count',
#     '(',
#     '*',
#     ')',
#     'from',
#     'singer',
#     'join',
#     'concert',
#     'on',
#     'singer',
#     '.',
#     'singer',
#     '_',
#     'id',
#     '=',
#     'concert',
#     '.',
#     'stadium',
#     '_',
#     'id',
#     '[SEP]'],
#    'encoded_tokens': [101,
#     2129,
#     2116,
#     8453,
#     2079,
#     2057,
#     2031,
#     1029,
#     102,
#     7276,
#     4175,
#     1006,
#     1008,
#     1007,
#     2013,
#     3220,
#     3693,
#     4164,
#     2006,
#     3220,
#     1012,
#     3220,
#     1035,
#     8909,
#     1027,
#     4164,
#     1012,
#     3346,
#     1035,
#     8909,
#     102],
#    'rank': 15},
#   {'sql_query': "select count ( * ) from concert where concert.stadium_id = ' value '",
#    'tables_used': ['concert'],
#    'columns_used': [['concert', 'stadium_id']],
#    'target': 0.0,
#    'tokens': ['[CLS]',
#     'how',
#     'many',
#     'singers',
#     'do',
#     'we',
#     'have',
#     '?',
#     '[SEP]',
#     'select',
#     'count',
#     '(',
#     '*',
#     ')',
#     'from',
#     'concert',
#     'where',
#     'concert',
#     '.',
#     'stadium',
#     '_',
#     'id',
#     '=',
#     "'",
#     'value',
#     "'",
#     '[SEP]'],
#    'encoded_tokens': [101,
#     2129,
#     2116,
#     8453,
#     2079,
#     2057,
#     2031,
#     1029,
#     102,
#     7276,
#     4175,
#     1006,
#     1008,
#     1007,
#     2013,
#     4164,
#     2073,
#     4164,
#     1012,
#     3346,
#     1035,
#     8909,
#     1027,
#     1005,
#     3643,
#     1005,
#     102],
#    'rank': 16},
#   {'sql_query': 'select count ( distinct singer.is_male ) from singer',
#    'tables_used': ['singer'],
#    'columns_used': [['singer', 'is_male']],
#    'target': 0.0,
#    'tokens': ['[CLS]',
#     'how',
#     'many',
#     'singers',
#     'do',
#     'we',
#     'have',
#     '?',
#     '[SEP]',
#     'select',
#     'count',
#     '(',
#     'distinct',
#     'singer',
#     '.',
#     'is',
#     '_',
#     'male',
#     ')',
#     'from',
#     'singer',
#     '[SEP]'],
#    'encoded_tokens': [101,
#     2129,
#     2116,
#     8453,
#     2079,
#     2057,
#     2031,
#     1029,
#     102,
#     7276,
#     4175,
#     1006,
#     5664,
#     3220,
#     1012,
#     2003,
#     1035,
#     3287,
#     1007,
#     2013,
#     3220,
#     102],
#    'rank': 17},
#   {'sql_query': 'select sum ( singer.name ) from singer',
#    'tables_used': ['singer'],
#    'columns_used': [['singer', 'name']],
#    'target': 0.0,
#    'tokens': ['[CLS]',
#     'how',
#     'many',
#     'singers',
#     'do',
#     'we',
#     'have',
#     '?',
#     '[SEP]',
#     'select',
#     'sum',
#     '(',
#     'singer',
#     '.',
#     'name',
#     ')',
#     'from',
#     'singer',
#     '[SEP]'],
#    'encoded_tokens': [101,
#     2129,
#     2116,
#     8453,
#     2079,
#     2057,
#     2031,
#     1029,
#     102,
#     7276,
#     7680,
#     1006,
#     3220,
#     1012,
#     2171,
#     1007,
#     2013,
#     3220,
#     102],
#    'rank': 18},
#   {'sql_query': 'select count ( * ) , singer.name from singer group by singer.name',
#    'tables_used': ['singer'],
#    'columns_used': [['singer', 'name']],
#    'target': 0.0,
#    'tokens': ['[CLS]',
#     'how',
#     'many',
#     'singers',
#     'do',
#     'we',
#     'have',
#     '?',
#     '[SEP]',
#     'select',
#     'count',
#     '(',
#     '*',
#     ')',
#     ',',
#     'singer',
#     '.',
#     'name',
#     'from',
#     'singer',
#     'group',
#     'by',
#     'singer',
#     '.',
#     'name',
#     '[SEP]'],
#    'encoded_tokens': [101,
#     2129,
#     2116,
#     8453,
#     2079,
#     2057,
#     2031,
#     1029,
#     102,
#     7276,
#     4175,
#     1006,
#     1008,
#     1007,
#     1010,
#     3220,
#     1012,
#     2171,
#     2013,
#     3220,
#     2177,
#     2011,
#     3220,
#     1012,
#     2171,
#     102],
#    'rank': 19},
#   {'sql_query': 'select count ( distinct concert.stadium_id ) from concert',
#    'tables_used': ['concert'],
#    'columns_used': [['concert', 'stadium_id']],
#    'target': 0.0,
#    'tokens': ['[CLS]',
#     'how',
#     'many',
#     'singers',
#     'do',
#     'we',
#     'have',
#     '?',
#     '[SEP]',
#     'select',
#     'count',
#     '(',
#     'distinct',
#     'concert',
#     '.',
#     'stadium',
#     '_',
#     'id',
#     ')',
#     'from',
#     'concert',
#     '[SEP]'],
#    'encoded_tokens': [101,
#     2129,
#     2116,
#     8453,
#     2079,
#     2057,
#     2031,
#     1029,
#     102,
#     7276,
#     4175,
#     1006,
#     5664,
#     4164,
#     1012,
#     3346,
#     1035,
#     8909,
#     1007,
#     2013,
#     4164,
#     102],
#    'rank': 20},
#   {'sql_query': 'select distinct count ( * ) from singer',
#    'tables_used': ['singer'],
#    'columns_used': [],
#    'target': 1.0,
#    'tokens': ['[CLS]',
#     'how',
#     'many',
#     'singers',
#     'do',
#     'we',
#     'have',
#     '?',
#     '[SEP]',
#     'select',
#     'distinct',
#     'count',
#     '(',
#     '*',
#     ')',
#     'from',
#     'singer',
#     '[SEP]'],
#    'encoded_tokens': [101,
#     2129,
#     2116,
#     8453,
#     2079,
#     2057,
#     2031,
#     1029,
#     102,
#     7276,
#     5664,
#     4175,
#     1006,
#     1008,
#     1007,
#     2013,
#     3220,
#     102],
#    'rank': 21},
#   {'sql_query': 'select count ( distinct concert.concert_id ) from concert',
#    'tables_used': ['concert'],
#    'columns_used': [['concert', 'concert_id']],
#    'target': 0.0,
#    'tokens': ['[CLS]',
#     'how',
#     'many',
#     'singers',
#     'do',
#     'we',
#     'have',
#     '?',
#     '[SEP]',
#     'select',
#     'count',
#     '(',
#     'distinct',
#     'concert',
#     '.',
#     'concert',
#     '_',
#     'id',
#     ')',
#     'from',
#     'concert',
#     '[SEP]'],
#    'encoded_tokens': [101,
#     2129,
#     2116,
#     8453,
#     2079,
#     2057,
#     2031,
#     1029,
#     102,
#     7276,
#     4175,
#     1006,
#     5664,
#     4164,
#     1012,
#     4164,
#     1035,
#     8909,
#     1007,
#     2013,
#     4164,
#     102],
#    'rank': 22},
#   {'sql_query': 'select singer.name , count ( * ) from singer group by singer.singer_id',
#    'tables_used': ['singer'],
#    'columns_used': [['singer', 'name'], ['singer', 'singer_id']],
#    'target': 0.0,
#    'tokens': ['[CLS]',
#     'how',
#     'many',
#     'singers',
#     'do',
#     'we',
#     'have',
#     '?',
#     '[SEP]',
#     'select',
#     'singer',
#     '.',
#     'name',
#     ',',
#     'count',
#     '(',
#     '*',
#     ')',
#     'from',
#     'singer',
#     'group',
#     'by',
#     'singer',
#     '.',
#     'singer',
#     '_',
#     'id',
#     '[SEP]'],
#    'encoded_tokens': [101,
#     2129,
#     2116,
#     8453,
#     2079,
#     2057,
#     2031,
#     1029,
#     102,
#     7276,
#     3220,
#     1012,
#     2171,
#     1010,
#     4175,
#     1006,
#     1008,
#     1007,
#     2013,
#     3220,
#     2177,
#     2011,
#     3220,
#     1012,
#     3220,
#     1035,
#     8909,
#     102],
#    'rank': 23},
#   {'sql_query': 'select count ( singer.name ) from singer',
#    'tables_used': ['singer'],
#    'columns_used': [['singer', 'name']],
#    'target': 0.0,
#    'tokens': ['[CLS]',
#     'how',
#     'many',
#     'singers',
#     'do',
#     'we',
#     'have',
#     '?',
#     '[SEP]',
#     'select',
#     'count',
#     '(',
#     'singer',
#     '.',
#     'name',
#     ')',
#     'from',
#     'singer',
#     '[SEP]'],
#    'encoded_tokens': [101,
#     2129,
#     2116,
#     8453,
#     2079,
#     2057,
#     2031,
#     1029,
#     102,
#     7276,
#     4175,
#     1006,
#     3220,
#     1012,
#     2171,
#     1007,
#     2013,
#     3220,
#     102],
#    'rank': 24},
#   {'sql_query': 'select count ( distinct stadium.capacity ) from stadium',
#    'tables_used': ['stadium'],
#    'columns_used': [['stadium', 'capacity']],
#    'target': 0.0,
#    'tokens': ['[CLS]',
#     'how',
#     'many',
#     'singers',
#     'do',
#     'we',
#     'have',
#     '?',
#     '[SEP]',
#     'select',
#     'count',
#     '(',
#     'distinct',
#     'stadium',
#     '.',
#     'capacity',
#     ')',
#     'from',
#     'stadium',
#     '[SEP]'],
#    'encoded_tokens': [101,
#     2129,
#     2116,
#     8453,
#     2079,
#     2057,
#     2031,
#     1029,
#     102,
#     7276,
#     4175,
#     1006,
#     5664,
#     3346,
#     1012,
#     3977,
#     1007,
#     2013,
#     3346,
#     102],
#    'rank': 25},
#   {'sql_query': 'select count ( distinct stadium.stadium_id ) from stadium',
#    'tables_used': ['stadium'],
#    'columns_used': [['stadium', 'stadium_id']],
#    'target': 0.0,
#    'tokens': ['[CLS]',
#     'how',
#     'many',
#     'singers',
#     'do',
#     'we',
#     'have',
#     '?',
#     '[SEP]',
#     'select',
#     'count',
#     '(',
#     'distinct',
#     'stadium',
#     '.',
#     'stadium',
#     '_',
#     'id',
#     ')',
#     'from',
#     'stadium',
#     '[SEP]'],
#    'encoded_tokens': [101,
#     2129,
#     2116,
#     8453,
#     2079,
#     2057,
#     2031,
#     1029,
#     102,
#     7276,
#     4175,
#     1006,
#     5664,
#     3346,
#     1012,
#     3346,
#     1035,
#     8909,
#     1007,
#     2013,
#     3346,
#     102],
#    'rank': 26},
#   {'sql_query': 'select count ( distinct stadium.lowest ) from stadium',
#    'tables_used': ['stadium'],
#    'columns_used': [['stadium', 'lowest']],
#    'target': 0.0,
#    'tokens': ['[CLS]',
#     'how',
#     'many',
#     'singers',
#     'do',
#     'we',
#     'have',
#     '?',
#     '[SEP]',
#     'select',
#     'count',
#     '(',
#     'distinct',
#     'stadium',
#     '.',
#     'lowest',
#     ')',
#     'from',
#     'stadium',
#     '[SEP]'],
#    'encoded_tokens': [101,
#     2129,
#     2116,
#     8453,
#     2079,
#     2057,
#     2031,
#     1029,
#     102,
#     7276,
#     4175,
#     1006,
#     5664,
#     3346,
#     1012,
#     7290,
#     1007,
#     2013,
#     3346,
#     102],
#    'rank': 27},
#   {'sql_query': 'select count ( distinct stadium.name ) from stadium',
#    'tables_used': ['stadium'],
#    'columns_used': [['stadium', 'name']],
#    'target': 0.0,
#    'tokens': ['[CLS]',
#     'how',
#     'many',
#     'singers',
#     'do',
#     'we',
#     'have',
#     '?',
#     '[SEP]',
#     'select',
#     'count',
#     '(',
#     'distinct',
#     'stadium',
#     '.',
#     'name',
#     ')',
#     'from',
#     'stadium',
#     '[SEP]'],
#    'encoded_tokens': [101,
#     2129,
#     2116,
#     8453,
#     2079,
#     2057,
#     2031,
#     1029,
#     102,
#     7276,
#     4175,
#     1006,
#     5664,
#     3346,
#     1012,
#     2171,
#     1007,
#     2013,
#     3346,
#     102],
#    'rank': 28},
#   {'sql_query': 'select count ( distinct stadium.highest ) from stadium',
#    'tables_used': ['stadium'],
#    'columns_used': [['stadium', 'highest']],
#    'target': 0.0,
#    'tokens': ['[CLS]',
#     'how',
#     'many',
#     'singers',
#     'do',
#     'we',
#     'have',
#     '?',
#     '[SEP]',
#     'select',
#     'count',
#     '(',
#     'distinct',
#     'stadium',
#     '.',
#     'highest',
#     ')',
#     'from',
#     'stadium',
#     '[SEP]'],
#    'encoded_tokens': [101,
#     2129,
#     2116,
#     8453,
#     2079,
#     2057,
#     2031,
#     1029,
#     102,
#     7276,
#     4175,
#     1006,
#     5664,
#     3346,
#     1012,
#     3284,
#     1007,
#     2013,
#     3346,
#     102],
#    'rank': 29},
#   {'sql_query': 'select count ( distinct stadium.average ) from stadium',
#    'tables_used': ['stadium'],
#    'columns_used': [['stadium', 'average']],
#    'target': 0.0,
#    'tokens': ['[CLS]',
#     'how',
#     'many',
#     'singers',
#     'do',
#     'we',
#     'have',
#     '?',
#     '[SEP]',
#     'select',
#     'count',
#     '(',
#     'distinct',
#     'stadium',
#     '.',
#     'average',
#     ')',
#     'from',
#     'stadium',
#     '[SEP]'],
#    'encoded_tokens': [101,
#     2129,
#     2116,
#     8453,
#     2079,
#     2057,
#     2031,
#     1029,
#     102,
#     7276,
#     4175,
#     1006,
#     5664,
#     3346,
#     1012,
#     2779,
#     1007,
#     2013,
#     3346,
#     102],
#    'rank': 30},
#   {'sql_query': 'select count ( distinct concert.year ) from concert',
#    'tables_used': ['concert'],
#    'columns_used': [['concert', 'year']],
#    'target': 0.0,
#    'tokens': ['[CLS]',
#     'how',
#     'many',
#     'singers',
#     'do',
#     'we',
#     'have',
#     '?',
#     '[SEP]',
#     'select',
#     'count',
#     '(',
#     'distinct',
#     'concert',
#     '.',
#     'year',
#     ')',
#     'from',
#     'concert',
#     '[SEP]'],
#    'encoded_tokens': [101,
#     2129,
#     2116,
#     8453,
#     2079,
#     2057,
#     2031,
#     1029,
#     102,
#     7276,
#     4175,
#     1006,
#     5664,
#     4164,
#     1012,
#     2095,
#     1007,
#     2013,
#     4164,
#     102],
#    'rank': 31},
#   {'sql_query': 'select count ( distinct concert.theme ) from concert',
#    'tables_used': ['concert'],
#    'columns_used': [['concert', 'theme']],
#    'target': 0.0,
#    'tokens': ['[CLS]',
#     'how',
#     'many',
#     'singers',
#     'do',
#     'we',
#     'have',
#     '?',
#     '[SEP]',
#     'select',
#     'count',
#     '(',
#     'distinct',
#     'concert',
#     '.',
#     'theme',
#     ')',
#     'from',
#     'concert',
#     '[SEP]'],
#    'encoded_tokens': [101,
#     2129,
#     2116,
#     8453,
#     2079,
#     2057,
#     2031,
#     1029,
#     102,
#     7276,
#     4175,
#     1006,
#     5664,
#     4164,
#     1012,
#     4323,
#     1007,
#     2013,
#     4164,
#     102],
#    'rank': 32},
#   {'sql_query': 'select count ( distinct stadium.location ) from stadium',
#    'tables_used': ['stadium'],
#    'columns_used': [['stadium', 'location']],
#    'target': 0.0,
#    'tokens': ['[CLS]',
#     'how',
#     'many',
#     'singers',
#     'do',
#     'we',
#     'have',
#     '?',
#     '[SEP]',
#     'select',
#     'count',
#     '(',
#     'distinct',
#     'stadium',
#     '.',
#     'location',
#     ')',
#     'from',
#     'stadium',
#     '[SEP]'],
#    'encoded_tokens': [101,
#     2129,
#     2116,
#     8453,
#     2079,
#     2057,
#     2031,
#     1029,
#     102,
#     7276,
#     4175,
#     1006,
#     5664,
#     3346,
#     1012,
#     3295,
#     1007,
#     2013,
#     3346,
#     102],
#    'rank': 33},
#   {'sql_query': 'select count ( * ) from singer join stadium on singer.singer_id = stadium.capacity',
#    'tables_used': ['singer', 'stadium'],
#    'columns_used': [['stadium', 'capacity'], ['singer', 'singer_id']],
#    'target': 0.0,
#    'tokens': ['[CLS]',
#     'how',
#     'many',
#     'singers',
#     'do',
#     'we',
#     'have',
#     '?',
#     '[SEP]',
#     'select',
#     'count',
#     '(',
#     '*',
#     ')',
#     'from',
#     'singer',
#     'join',
#     'stadium',
#     'on',
#     'singer',
#     '.',
#     'singer',
#     '_',
#     'id',
#     '=',
#     'stadium',
#     '.',
#     'capacity',
#     '[SEP]'],
#    'encoded_tokens': [101,
#     2129,
#     2116,
#     8453,
#     2079,
#     2057,
#     2031,
#     1029,
#     102,
#     7276,
#     4175,
#     1006,
#     1008,
#     1007,
#     2013,
#     3220,
#     3693,
#     3346,
#     2006,
#     3220,
#     1012,
#     3220,
#     1035,
#     8909,
#     1027,
#     3346,
#     1012,
#     3977,
#     102],
#    'rank': 34},
#   {'sql_query': 'select count ( * ) from concert join singer on concert.concert_id = concert.stadium_id',
#    'tables_used': ['concert', 'singer'],
#    'columns_used': [['concert', 'stadium_id'], ['concert', 'concert_id']],
#    'target': 0.0,
#    'tokens': ['[CLS]',
#     'how',
#     'many',
#     'singers',
#     'do',
#     'we',
#     'have',
#     '?',
#     '[SEP]',
#     'select',
#     'count',
#     '(',
#     '*',
#     ')',
#     'from',
#     'concert',
#     'join',
#     'singer',
#     'on',
#     'concert',
#     '.',
#     'concert',
#     '_',
#     'id',
#     '=',
#     'concert',
#     '.',
#     'stadium',
#     '_',
#     'id',
#     '[SEP]'],
#    'encoded_tokens': [101,
#     2129,
#     2116,
#     8453,
#     2079,
#     2057,
#     2031,
#     1029,
#     102,
#     7276,
#     4175,
#     1006,
#     1008,
#     1007,
#     2013,
#     4164,
#     3693,
#     3220,
#     2006,
#     4164,
#     1012,
#     4164,
#     1035,
#     8909,
#     1027,
#     4164,
#     1012,
#     3346,
#     1035,
#     8909,
#     102],
#    'rank': 35},
#   {'sql_query': 'select singer.song_name , count ( * ) from singer group by singer.name',
#    'tables_used': ['singer'],
#    'columns_used': [['singer', 'name'], ['singer', 'song_name']],
#    'target': 0.0,
#    'tokens': ['[CLS]',
#     'how',
#     'many',
#     'singers',
#     'do',
#     'we',
#     'have',
#     '?',
#     '[SEP]',
#     'select',
#     'singer',
#     '.',
#     'song',
#     '_',
#     'name',
#     ',',
#     'count',
#     '(',
#     '*',
#     ')',
#     'from',
#     'singer',
#     'group',
#     'by',
#     'singer',
#     '.',
#     'name',
#     '[SEP]'],
#    'encoded_tokens': [101,
#     2129,
#     2116,
#     8453,
#     2079,
#     2057,
#     2031,
#     1029,
#     102,
#     7276,
#     3220,
#     1012,
#     2299,
#     1035,
#     2171,
#     1010,
#     4175,
#     1006,
#     1008,
#     1007,
#     2013,
#     3220,
#     2177,
#     2011,
#     3220,
#     1012,
#     2171,
#     102],
#    'rank': 36},
#   {'sql_query': 'select count ( * ) from singer join stadium on singer.singer_id = singer.age',
#    'tables_used': ['singer', 'stadium'],
#    'columns_used': [['singer', 'age'], ['singer', 'singer_id']],
#    'target': 0.0,
#    'tokens': ['[CLS]',
#     'how',
#     'many',
#     'singers',
#     'do',
#     'we',
#     'have',
#     '?',
#     '[SEP]',
#     'select',
#     'count',
#     '(',
#     '*',
#     ')',
#     'from',
#     'singer',
#     'join',
#     'stadium',
#     'on',
#     'singer',
#     '.',
#     'singer',
#     '_',
#     'id',
#     '=',
#     'singer',
#     '.',
#     'age',
#     '[SEP]'],
#    'encoded_tokens': [101,
#     2129,
#     2116,
#     8453,
#     2079,
#     2057,
#     2031,
#     1029,
#     102,
#     7276,
#     4175,
#     1006,
#     1008,
#     1007,
#     2013,
#     3220,
#     3693,
#     3346,
#     2006,
#     3220,
#     1012,
#     3220,
#     1035,
#     8909,
#     1027,
#     3220,
#     1012,
#     2287,
#     102],
#    'rank': 37},
#   {'sql_query': 'select singer.name from singer',
#    'tables_used': ['singer'],
#    'columns_used': [['singer', 'name']],
#    'target': 0.0,
#    'tokens': ['[CLS]',
#     'how',
#     'many',
#     'singers',
#     'do',
#     'we',
#     'have',
#     '?',
#     '[SEP]',
#     'select',
#     'singer',
#     '.',
#     'name',
#     'from',
#     'singer',
#     '[SEP]'],
#    'encoded_tokens': [101,
#     2129,
#     2116,
#     8453,
#     2079,
#     2057,
#     2031,
#     1029,
#     102,
#     7276,
#     3220,
#     1012,
#     2171,
#     2013,
#     3220,
#     102],
#    'rank': 38},
#   {'sql_query': "select count ( * ) from stadium where stadium.stadium_id = ' value '",
#    'tables_used': ['stadium'],
#    'columns_used': [['stadium', 'stadium_id']],
#    'target': 0.0,
#    'tokens': ['[CLS]',
#     'how',
#     'many',
#     'singers',
#     'do',
#     'we',
#     'have',
#     '?',
#     '[SEP]',
#     'select',
#     'count',
#     '(',
#     '*',
#     ')',
#     'from',
#     'stadium',
#     'where',
#     'stadium',
#     '.',
#     'stadium',
#     '_',
#     'id',
#     '=',
#     "'",
#     'value',
#     "'",
#     '[SEP]'],
#    'encoded_tokens': [101,
#     2129,
#     2116,
#     8453,
#     2079,
#     2057,
#     2031,
#     1029,
#     102,
#     7276,
#     4175,
#     1006,
#     1008,
#     1007,
#     2013,
#     3346,
#     2073,
#     3346,
#     1012,
#     3346,
#     1035,
#     8909,
#     1027,
#     1005,
#     3643,
#     1005,
#     102],
#    'rank': 39}],
#  'correct_instances': [{'sql_query': 'select count ( * ) from singer',
#    'tables_used': ['singer'],
#    'columns_used': [],
#    'target': 1.0,
#    'tokens': ['[CLS]',
#     'how',
#     'many',
#     'singers',
#     'do',
#     'we',
#     'have',
#     '?',
#     '[SEP]',
#     'select',
#     'count',
#     '(',
#     '*',
#     ')',
#     'from',
#     'singer',
#     '[SEP]'],
#    'encoded_tokens': [101,
#     2129,
#     2116,
#     8453,
#     2079,
#     2057,
#     2031,
#     1029,
#     102,
#     7276,
#     4175,
#     1006,
#     1008,
#     1007,
#     2013,
#     3220,
#     102],
#    'rank': 0},
#   {'sql_query': 'select distinct count ( * ) from singer',
#    'tables_used': ['singer'],
#    'columns_used': [],
#    'target': 1.0,
#    'tokens': ['[CLS]',
#     'how',
#     'many',
#     'singers',
#     'do',
#     'we',
#     'have',
#     '?',
#     '[SEP]',
#     'select',
#     'distinct',
#     'count',
#     '(',
#     '*',
#     ')',
#     'from',
#     'singer',
#     '[SEP]'],
#    'encoded_tokens': [101,
#     2129,
#     2116,
#     8453,
#     2079,
#     2057,
#     2031,
#     1029,
#     102,
#     7276,
#     5664,
#     4175,
#     1006,
#     1008,
#     1007,
#     2013,
#     3220,
#     102],
#    'rank': 21}],
#  'incorrect_instances': [{'sql_query': 'select count ( * ) from concert',
#    'tables_used': ['concert'],
#    'columns_used': [],
#    'target': 0.0,
#    'tokens': ['[CLS]',
#     'how',
#     'many',
#     'singers',
#     'do',
#     'we',
#     'have',
#     '?',
#     '[SEP]',
#     'select',
#     'count',
#     '(',
#     '*',
#     ')',
#     'from',
#     'concert',
#     '[SEP]'],
#    'encoded_tokens': [101,
#     2129,
#     2116,
#     8453,
#     2079,
#     2057,
#     2031,
#     1029,
#     102,
#     7276,
#     4175,
#     1006,
#     1008,
#     1007,
#     2013,
#     4164,
#     102],
#    'rank': 1},
#   {'sql_query': 'select count ( * ) from stadium',
#    'tables_used': ['stadium'],
#    'columns_used': [],
#    'target': 0.0,
#    'tokens': ['[CLS]',
#     'how',
#     'many',
#     'singers',
#     'do',
#     'we',
#     'have',
#     '?',
#     '[SEP]',
#     'select',
#     'count',
#     '(',
#     '*',
#     ')',
#     'from',
#     'stadium',
#     '[SEP]'],
#    'encoded_tokens': [101,
#     2129,
#     2116,
#     8453,
#     2079,
#     2057,
#     2031,
#     1029,
#     102,
#     7276,
#     4175,
#     1006,
#     1008,
#     1007,
#     2013,
#     3346,
#     102],
#    'rank': 2},
#   {'sql_query': 'select count ( * ) from singer_in_concert',
#    'tables_used': ['singer_in_concert'],
#    'columns_used': [],
#    'target': 0.0,
#    'tokens': ['[CLS]',
#     'how',
#     'many',
#     'singers',
#     'do',
#     'we',
#     'have',
#     '?',
#     '[SEP]',
#     'select',
#     'count',
#     '(',
#     '*',
#     ')',
#     'from',
#     'singer',
#     '_',
#     'in',
#     '_',
#     'concert',
#     '[SEP]'],
#    'encoded_tokens': [101,
#     2129,
#     2116,
#     8453,
#     2079,
#     2057,
#     2031,
#     1029,
#     102,
#     7276,
#     4175,
#     1006,
#     1008,
#     1007,
#     2013,
#     3220,
#     1035,
#     1999,
#     1035,
#     4164,
#     102],
#    'rank': 3},
#   {'sql_query': 'select count ( distinct singer.name ) from singer',
#    'tables_used': ['singer'],
#    'columns_used': [['singer', 'name']],
#    'target': 0.0,
#    'tokens': ['[CLS]',
#     'how',
#     'many',
#     'singers',
#     'do',
#     'we',
#     'have',
#     '?',
#     '[SEP]',
#     'select',
#     'count',
#     '(',
#     'distinct',
#     'singer',
#     '.',
#     'name',
#     ')',
#     'from',
#     'singer',
#     '[SEP]'],
#    'encoded_tokens': [101,
#     2129,
#     2116,
#     8453,
#     2079,
#     2057,
#     2031,
#     1029,
#     102,
#     7276,
#     4175,
#     1006,
#     5664,
#     3220,
#     1012,
#     2171,
#     1007,
#     2013,
#     3220,
#     102],
#    'rank': 4},
#   {'sql_query': 'select count ( distinct singer.song_name ) from singer',
#    'tables_used': ['singer'],
#    'columns_used': [['singer', 'song_name']],
#    'target': 0.0,
#    'tokens': ['[CLS]',
#     'how',
#     'many',
#     'singers',
#     'do',
#     'we',
#     'have',
#     '?',
#     '[SEP]',
#     'select',
#     'count',
#     '(',
#     'distinct',
#     'singer',
#     '.',
#     'song',
#     '_',
#     'name',
#     ')',
#     'from',
#     'singer',
#     '[SEP]'],
#    'encoded_tokens': [101,
#     2129,
#     2116,
#     8453,
#     2079,
#     2057,
#     2031,
#     1029,
#     102,
#     7276,
#     4175,
#     1006,
#     5664,
#     3220,
#     1012,
#     2299,
#     1035,
#     2171,
#     1007,
#     2013,
#     3220,
#     102],
#    'rank': 5},
#   {'sql_query': 'select singer.name , count ( * ) from singer group by singer.name',
#    'tables_used': ['singer'],
#    'columns_used': [['singer', 'name']],
#    'target': 0.0,
#    'tokens': ['[CLS]',
#     'how',
#     'many',
#     'singers',
#     'do',
#     'we',
#     'have',
#     '?',
#     '[SEP]',
#     'select',
#     'singer',
#     '.',
#     'name',
#     ',',
#     'count',
#     '(',
#     '*',
#     ')',
#     'from',
#     'singer',
#     'group',
#     'by',
#     'singer',
#     '.',
#     'name',
#     '[SEP]'],
#    'encoded_tokens': [101,
#     2129,
#     2116,
#     8453,
#     2079,
#     2057,
#     2031,
#     1029,
#     102,
#     7276,
#     3220,
#     1012,
#     2171,
#     1010,
#     4175,
#     1006,
#     1008,
#     1007,
#     2013,
#     3220,
#     2177,
#     2011,
#     3220,
#     1012,
#     2171,
#     102],
#    'rank': 6},
#   {'sql_query': 'select count ( distinct singer.song_release_year ) from singer',
#    'tables_used': ['singer'],
#    'columns_used': [['singer', 'song_release_year']],
#    'target': 0.0,
#    'tokens': ['[CLS]',
#     'how',
#     'many',
#     'singers',
#     'do',
#     'we',
#     'have',
#     '?',
#     '[SEP]',
#     'select',
#     'count',
#     '(',
#     'distinct',
#     'singer',
#     '.',
#     'song',
#     '_',
#     'release',
#     '_',
#     'year',
#     ')',
#     'from',
#     'singer',
#     '[SEP]'],
#    'encoded_tokens': [101,
#     2129,
#     2116,
#     8453,
#     2079,
#     2057,
#     2031,
#     1029,
#     102,
#     7276,
#     4175,
#     1006,
#     5664,
#     3220,
#     1012,
#     2299,
#     1035,
#     2713,
#     1035,
#     2095,
#     1007,
#     2013,
#     3220,
#     102],
#    'rank': 7},
#   {'sql_query': 'select count ( distinct singer.singer_id ) from singer',
#    'tables_used': ['singer'],
#    'columns_used': [['singer', 'singer_id']],
#    'target': 0.0,
#    'tokens': ['[CLS]',
#     'how',
#     'many',
#     'singers',
#     'do',
#     'we',
#     'have',
#     '?',
#     '[SEP]',
#     'select',
#     'count',
#     '(',
#     'distinct',
#     'singer',
#     '.',
#     'singer',
#     '_',
#     'id',
#     ')',
#     'from',
#     'singer',
#     '[SEP]'],
#    'encoded_tokens': [101,
#     2129,
#     2116,
#     8453,
#     2079,
#     2057,
#     2031,
#     1029,
#     102,
#     7276,
#     4175,
#     1006,
#     5664,
#     3220,
#     1012,
#     3220,
#     1035,
#     8909,
#     1007,
#     2013,
#     3220,
#     102],
#    'rank': 8},
#   {'sql_query': "select count ( * ) from singer where singer.name = ' value '",
#    'tables_used': ['singer'],
#    'columns_used': [['singer', 'name']],
#    'target': 0.0,
#    'tokens': ['[CLS]',
#     'how',
#     'many',
#     'singers',
#     'do',
#     'we',
#     'have',
#     '?',
#     '[SEP]',
#     'select',
#     'count',
#     '(',
#     '*',
#     ')',
#     'from',
#     'singer',
#     'where',
#     'singer',
#     '.',
#     'name',
#     '=',
#     "'",
#     'value',
#     "'",
#     '[SEP]'],
#    'encoded_tokens': [101,
#     2129,
#     2116,
#     8453,
#     2079,
#     2057,
#     2031,
#     1029,
#     102,
#     7276,
#     4175,
#     1006,
#     1008,
#     1007,
#     2013,
#     3220,
#     2073,
#     3220,
#     1012,
#     2171,
#     1027,
#     1005,
#     3643,
#     1005,
#     102],
#    'rank': 9},
#   {'sql_query': "select count ( * ) from singer where singer.singer_id = ' value '",
#    'tables_used': ['singer'],
#    'columns_used': [['singer', 'singer_id']],
#    'target': 0.0,
#    'tokens': ['[CLS]',
#     'how',
#     'many',
#     'singers',
#     'do',
#     'we',
#     'have',
#     '?',
#     '[SEP]',
#     'select',
#     'count',
#     '(',
#     '*',
#     ')',
#     'from',
#     'singer',
#     'where',
#     'singer',
#     '.',
#     'singer',
#     '_',
#     'id',
#     '=',
#     "'",
#     'value',
#     "'",
#     '[SEP]'],
#    'encoded_tokens': [101,
#     2129,
#     2116,
#     8453,
#     2079,
#     2057,
#     2031,
#     1029,
#     102,
#     7276,
#     4175,
#     1006,
#     1008,
#     1007,
#     2013,
#     3220,
#     2073,
#     3220,
#     1012,
#     3220,
#     1035,
#     8909,
#     1027,
#     1005,
#     3643,
#     1005,
#     102],
#    'rank': 10},
#   {'sql_query': 'select count ( distinct concert.concert_name ) from concert',
#    'tables_used': ['concert'],
#    'columns_used': [['concert', 'concert_name']],
#    'target': 0.0,
#    'tokens': ['[CLS]',
#     'how',
#     'many',
#     'singers',
#     'do',
#     'we',
#     'have',
#     '?',
#     '[SEP]',
#     'select',
#     'count',
#     '(',
#     'distinct',
#     'concert',
#     '.',
#     'concert',
#     '_',
#     'name',
#     ')',
#     'from',
#     'concert',
#     '[SEP]'],
#    'encoded_tokens': [101,
#     2129,
#     2116,
#     8453,
#     2079,
#     2057,
#     2031,
#     1029,
#     102,
#     7276,
#     4175,
#     1006,
#     5664,
#     4164,
#     1012,
#     4164,
#     1035,
#     2171,
#     1007,
#     2013,
#     4164,
#     102],
#    'rank': 11},
#   {'sql_query': 'select count ( distinct singer.age ) from singer',
#    'tables_used': ['singer'],
#    'columns_used': [['singer', 'age']],
#    'target': 0.0,
#    'tokens': ['[CLS]',
#     'how',
#     'many',
#     'singers',
#     'do',
#     'we',
#     'have',
#     '?',
#     '[SEP]',
#     'select',
#     'count',
#     '(',
#     'distinct',
#     'singer',
#     '.',
#     'age',
#     ')',
#     'from',
#     'singer',
#     '[SEP]'],
#    'encoded_tokens': [101,
#     2129,
#     2116,
#     8453,
#     2079,
#     2057,
#     2031,
#     1029,
#     102,
#     7276,
#     4175,
#     1006,
#     5664,
#     3220,
#     1012,
#     2287,
#     1007,
#     2013,
#     3220,
#     102],
#    'rank': 12},
#   {'sql_query': 'select count ( * ) from concert join singer on singer.singer_id = concert.stadium_id',
#    'tables_used': ['concert', 'singer'],
#    'columns_used': [['concert', 'stadium_id'], ['singer', 'singer_id']],
#    'target': 0.0,
#    'tokens': ['[CLS]',
#     'how',
#     'many',
#     'singers',
#     'do',
#     'we',
#     'have',
#     '?',
#     '[SEP]',
#     'select',
#     'count',
#     '(',
#     '*',
#     ')',
#     'from',
#     'concert',
#     'join',
#     'singer',
#     'on',
#     'singer',
#     '.',
#     'singer',
#     '_',
#     'id',
#     '=',
#     'concert',
#     '.',
#     'stadium',
#     '_',
#     'id',
#     '[SEP]'],
#    'encoded_tokens': [101,
#     2129,
#     2116,
#     8453,
#     2079,
#     2057,
#     2031,
#     1029,
#     102,
#     7276,
#     4175,
#     1006,
#     1008,
#     1007,
#     2013,
#     4164,
#     3693,
#     3220,
#     2006,
#     3220,
#     1012,
#     3220,
#     1035,
#     8909,
#     1027,
#     4164,
#     1012,
#     3346,
#     1035,
#     8909,
#     102],
#    'rank': 13},
#   {'sql_query': 'select count ( distinct singer.country ) from singer',
#    'tables_used': ['singer'],
#    'columns_used': [['singer', 'country']],
#    'target': 0.0,
#    'tokens': ['[CLS]',
#     'how',
#     'many',
#     'singers',
#     'do',
#     'we',
#     'have',
#     '?',
#     '[SEP]',
#     'select',
#     'count',
#     '(',
#     'distinct',
#     'singer',
#     '.',
#     'country',
#     ')',
#     'from',
#     'singer',
#     '[SEP]'],
#    'encoded_tokens': [101,
#     2129,
#     2116,
#     8453,
#     2079,
#     2057,
#     2031,
#     1029,
#     102,
#     7276,
#     4175,
#     1006,
#     5664,
#     3220,
#     1012,
#     2406,
#     1007,
#     2013,
#     3220,
#     102],
#    'rank': 14},
#   {'sql_query': 'select count ( * ) from singer join concert on singer.singer_id = concert.stadium_id',
#    'tables_used': ['singer', 'concert'],
#    'columns_used': [['concert', 'stadium_id'], ['singer', 'singer_id']],
#    'target': 0.0,
#    'tokens': ['[CLS]',
#     'how',
#     'many',
#     'singers',
#     'do',
#     'we',
#     'have',
#     '?',
#     '[SEP]',
#     'select',
#     'count',
#     '(',
#     '*',
#     ')',
#     'from',
#     'singer',
#     'join',
#     'concert',
#     'on',
#     'singer',
#     '.',
#     'singer',
#     '_',
#     'id',
#     '=',
#     'concert',
#     '.',
#     'stadium',
#     '_',
#     'id',
#     '[SEP]'],
#    'encoded_tokens': [101,
#     2129,
#     2116,
#     8453,
#     2079,
#     2057,
#     2031,
#     1029,
#     102,
#     7276,
#     4175,
#     1006,
#     1008,
#     1007,
#     2013,
#     3220,
#     3693,
#     4164,
#     2006,
#     3220,
#     1012,
#     3220,
#     1035,
#     8909,
#     1027,
#     4164,
#     1012,
#     3346,
#     1035,
#     8909,
#     102],
#    'rank': 15},
#   {'sql_query': "select count ( * ) from concert where concert.stadium_id = ' value '",
#    'tables_used': ['concert'],
#    'columns_used': [['concert', 'stadium_id']],
#    'target': 0.0,
#    'tokens': ['[CLS]',
#     'how',
#     'many',
#     'singers',
#     'do',
#     'we',
#     'have',
#     '?',
#     '[SEP]',
#     'select',
#     'count',
#     '(',
#     '*',
#     ')',
#     'from',
#     'concert',
#     'where',
#     'concert',
#     '.',
#     'stadium',
#     '_',
#     'id',
#     '=',
#     "'",
#     'value',
#     "'",
#     '[SEP]'],
#    'encoded_tokens': [101,
#     2129,
#     2116,
#     8453,
#     2079,
#     2057,
#     2031,
#     1029,
#     102,
#     7276,
#     4175,
#     1006,
#     1008,
#     1007,
#     2013,
#     4164,
#     2073,
#     4164,
#     1012,
#     3346,
#     1035,
#     8909,
#     1027,
#     1005,
#     3643,
#     1005,
#     102],
#    'rank': 16},
#   {'sql_query': 'select count ( distinct singer.is_male ) from singer',
#    'tables_used': ['singer'],
#    'columns_used': [['singer', 'is_male']],
#    'target': 0.0,
#    'tokens': ['[CLS]',
#     'how',
#     'many',
#     'singers',
#     'do',
#     'we',
#     'have',
#     '?',
#     '[SEP]',
#     'select',
#     'count',
#     '(',
#     'distinct',
#     'singer',
#     '.',
#     'is',
#     '_',
#     'male',
#     ')',
#     'from',
#     'singer',
#     '[SEP]'],
#    'encoded_tokens': [101,
#     2129,
#     2116,
#     8453,
#     2079,
#     2057,
#     2031,
#     1029,
#     102,
#     7276,
#     4175,
#     1006,
#     5664,
#     3220,
#     1012,
#     2003,
#     1035,
#     3287,
#     1007,
#     2013,
#     3220,
#     102],
#    'rank': 17},
#   {'sql_query': 'select sum ( singer.name ) from singer',
#    'tables_used': ['singer'],
#    'columns_used': [['singer', 'name']],
#    'target': 0.0,
#    'tokens': ['[CLS]',
#     'how',
#     'many',
#     'singers',
#     'do',
#     'we',
#     'have',
#     '?',
#     '[SEP]',
#     'select',
#     'sum',
#     '(',
#     'singer',
#     '.',
#     'name',
#     ')',
#     'from',
#     'singer',
#     '[SEP]'],
#    'encoded_tokens': [101,
#     2129,
#     2116,
#     8453,
#     2079,
#     2057,
#     2031,
#     1029,
#     102,
#     7276,
#     7680,
#     1006,
#     3220,
#     1012,
#     2171,
#     1007,
#     2013,
#     3220,
#     102],
#    'rank': 18},
#   {'sql_query': 'select count ( * ) , singer.name from singer group by singer.name',
#    'tables_used': ['singer'],
#    'columns_used': [['singer', 'name']],
#    'target': 0.0,
#    'tokens': ['[CLS]',
#     'how',
#     'many',
#     'singers',
#     'do',
#     'we',
#     'have',
#     '?',
#     '[SEP]',
#     'select',
#     'count',
#     '(',
#     '*',
#     ')',
#     ',',
#     'singer',
#     '.',
#     'name',
#     'from',
#     'singer',
#     'group',
#     'by',
#     'singer',
#     '.',
#     'name',
#     '[SEP]'],
#    'encoded_tokens': [101,
#     2129,
#     2116,
#     8453,
#     2079,
#     2057,
#     2031,
#     1029,
#     102,
#     7276,
#     4175,
#     1006,
#     1008,
#     1007,
#     1010,
#     3220,
#     1012,
#     2171,
#     2013,
#     3220,
#     2177,
#     2011,
#     3220,
#     1012,
#     2171,
#     102],
#    'rank': 19},
#   {'sql_query': 'select count ( distinct concert.stadium_id ) from concert',
#    'tables_used': ['concert'],
#    'columns_used': [['concert', 'stadium_id']],
#    'target': 0.0,
#    'tokens': ['[CLS]',
#     'how',
#     'many',
#     'singers',
#     'do',
#     'we',
#     'have',
#     '?',
#     '[SEP]',
#     'select',
#     'count',
#     '(',
#     'distinct',
#     'concert',
#     '.',
#     'stadium',
#     '_',
#     'id',
#     ')',
#     'from',
#     'concert',
#     '[SEP]'],
#    'encoded_tokens': [101,
#     2129,
#     2116,
#     8453,
#     2079,
#     2057,
#     2031,
#     1029,
#     102,
#     7276,
#     4175,
#     1006,
#     5664,
#     4164,
#     1012,
#     3346,
#     1035,
#     8909,
#     1007,
#     2013,
#     4164,
#     102],
#    'rank': 20},
#   {'sql_query': 'select count ( distinct concert.concert_id ) from concert',
#    'tables_used': ['concert'],
#    'columns_used': [['concert', 'concert_id']],
#    'target': 0.0,
#    'tokens': ['[CLS]',
#     'how',
#     'many',
#     'singers',
#     'do',
#     'we',
#     'have',
#     '?',
#     '[SEP]',
#     'select',
#     'count',
#     '(',
#     'distinct',
#     'concert',
#     '.',
#     'concert',
#     '_',
#     'id',
#     ')',
#     'from',
#     'concert',
#     '[SEP]'],
#    'encoded_tokens': [101,
#     2129,
#     2116,
#     8453,
#     2079,
#     2057,
#     2031,
#     1029,
#     102,
#     7276,
#     4175,
#     1006,
#     5664,
#     4164,
#     1012,
#     4164,
#     1035,
#     8909,
#     1007,
#     2013,
#     4164,
#     102],
#    'rank': 22},
#   {'sql_query': 'select singer.name , count ( * ) from singer group by singer.singer_id',
#    'tables_used': ['singer'],
#    'columns_used': [['singer', 'name'], ['singer', 'singer_id']],
#    'target': 0.0,
#    'tokens': ['[CLS]',
#     'how',
#     'many',
#     'singers',
#     'do',
#     'we',
#     'have',
#     '?',
#     '[SEP]',
#     'select',
#     'singer',
#     '.',
#     'name',
#     ',',
#     'count',
#     '(',
#     '*',
#     ')',
#     'from',
#     'singer',
#     'group',
#     'by',
#     'singer',
#     '.',
#     'singer',
#     '_',
#     'id',
#     '[SEP]'],
#    'encoded_tokens': [101,
#     2129,
#     2116,
#     8453,
#     2079,
#     2057,
#     2031,
#     1029,
#     102,
#     7276,
#     3220,
#     1012,
#     2171,
#     1010,
#     4175,
#     1006,
#     1008,
#     1007,
#     2013,
#     3220,
#     2177,
#     2011,
#     3220,
#     1012,
#     3220,
#     1035,
#     8909,
#     102],
#    'rank': 23},
#   {'sql_query': 'select count ( singer.name ) from singer',
#    'tables_used': ['singer'],
#    'columns_used': [['singer', 'name']],
#    'target': 0.0,
#    'tokens': ['[CLS]',
#     'how',
#     'many',
#     'singers',
#     'do',
#     'we',
#     'have',
#     '?',
#     '[SEP]',
#     'select',
#     'count',
#     '(',
#     'singer',
#     '.',
#     'name',
#     ')',
#     'from',
#     'singer',
#     '[SEP]'],
#    'encoded_tokens': [101,
#     2129,
#     2116,
#     8453,
#     2079,
#     2057,
#     2031,
#     1029,
#     102,
#     7276,
#     4175,
#     1006,
#     3220,
#     1012,
#     2171,
#     1007,
#     2013,
#     3220,
#     102],
#    'rank': 24},
#   {'sql_query': 'select count ( distinct stadium.capacity ) from stadium',
#    'tables_used': ['stadium'],
#    'columns_used': [['stadium', 'capacity']],
#    'target': 0.0,
#    'tokens': ['[CLS]',
#     'how',
#     'many',
#     'singers',
#     'do',
#     'we',
#     'have',
#     '?',
#     '[SEP]',
#     'select',
#     'count',
#     '(',
#     'distinct',
#     'stadium',
#     '.',
#     'capacity',
#     ')',
#     'from',
#     'stadium',
#     '[SEP]'],
#    'encoded_tokens': [101,
#     2129,
#     2116,
#     8453,
#     2079,
#     2057,
#     2031,
#     1029,
#     102,
#     7276,
#     4175,
#     1006,
#     5664,
#     3346,
#     1012,
#     3977,
#     1007,
#     2013,
#     3346,
#     102],
#    'rank': 25},
#   {'sql_query': 'select count ( distinct stadium.stadium_id ) from stadium',
#    'tables_used': ['stadium'],
#    'columns_used': [['stadium', 'stadium_id']],
#    'target': 0.0,
#    'tokens': ['[CLS]',
#     'how',
#     'many',
#     'singers',
#     'do',
#     'we',
#     'have',
#     '?',
#     '[SEP]',
#     'select',
#     'count',
#     '(',
#     'distinct',
#     'stadium',
#     '.',
#     'stadium',
#     '_',
#     'id',
#     ')',
#     'from',
#     'stadium',
#     '[SEP]'],
#    'encoded_tokens': [101,
#     2129,
#     2116,
#     8453,
#     2079,
#     2057,
#     2031,
#     1029,
#     102,
#     7276,
#     4175,
#     1006,
#     5664,
#     3346,
#     1012,
#     3346,
#     1035,
#     8909,
#     1007,
#     2013,
#     3346,
#     102],
#    'rank': 26},
#   {'sql_query': 'select count ( distinct stadium.lowest ) from stadium',
#    'tables_used': ['stadium'],
#    'columns_used': [['stadium', 'lowest']],
#    'target': 0.0,
#    'tokens': ['[CLS]',
#     'how',
#     'many',
#     'singers',
#     'do',
#     'we',
#     'have',
#     '?',
#     '[SEP]',
#     'select',
#     'count',
#     '(',
#     'distinct',
#     'stadium',
#     '.',
#     'lowest',
#     ')',
#     'from',
#     'stadium',
#     '[SEP]'],
#    'encoded_tokens': [101,
#     2129,
#     2116,
#     8453,
#     2079,
#     2057,
#     2031,
#     1029,
#     102,
#     7276,
#     4175,
#     1006,
#     5664,
#     3346,
#     1012,
#     7290,
#     1007,
#     2013,
#     3346,
#     102],
#    'rank': 27},
#   {'sql_query': 'select count ( distinct stadium.name ) from stadium',
#    'tables_used': ['stadium'],
#    'columns_used': [['stadium', 'name']],
#    'target': 0.0,
#    'tokens': ['[CLS]',
#     'how',
#     'many',
#     'singers',
#     'do',
#     'we',
#     'have',
#     '?',
#     '[SEP]',
#     'select',
#     'count',
#     '(',
#     'distinct',
#     'stadium',
#     '.',
#     'name',
#     ')',
#     'from',
#     'stadium',
#     '[SEP]'],
#    'encoded_tokens': [101,
#     2129,
#     2116,
#     8453,
#     2079,
#     2057,
#     2031,
#     1029,
#     102,
#     7276,
#     4175,
#     1006,
#     5664,
#     3346,
#     1012,
#     2171,
#     1007,
#     2013,
#     3346,
#     102],
#    'rank': 28},
#   {'sql_query': 'select count ( distinct stadium.highest ) from stadium',
#    'tables_used': ['stadium'],
#    'columns_used': [['stadium', 'highest']],
#    'target': 0.0,
#    'tokens': ['[CLS]',
#     'how',
#     'many',
#     'singers',
#     'do',
#     'we',
#     'have',
#     '?',
#     '[SEP]',
#     'select',
#     'count',
#     '(',
#     'distinct',
#     'stadium',
#     '.',
#     'highest',
#     ')',
#     'from',
#     'stadium',
#     '[SEP]'],
#    'encoded_tokens': [101,
#     2129,
#     2116,
#     8453,
#     2079,
#     2057,
#     2031,
#     1029,
#     102,
#     7276,
#     4175,
#     1006,
#     5664,
#     3346,
#     1012,
#     3284,
#     1007,
#     2013,
#     3346,
#     102],
#    'rank': 29},
#   {'sql_query': 'select count ( distinct stadium.average ) from stadium',
#    'tables_used': ['stadium'],
#    'columns_used': [['stadium', 'average']],
#    'target': 0.0,
#    'tokens': ['[CLS]',
#     'how',
#     'many',
#     'singers',
#     'do',
#     'we',
#     'have',
#     '?',
#     '[SEP]',
#     'select',
#     'count',
#     '(',
#     'distinct',
#     'stadium',
#     '.',
#     'average',
#     ')',
#     'from',
#     'stadium',
#     '[SEP]'],
#    'encoded_tokens': [101,
#     2129,
#     2116,
#     8453,
#     2079,
#     2057,
#     2031,
#     1029,
#     102,
#     7276,
#     4175,
#     1006,
#     5664,
#     3346,
#     1012,
#     2779,
#     1007,
#     2013,
#     3346,
#     102],
#    'rank': 30},
#   {'sql_query': 'select count ( distinct concert.year ) from concert',
#    'tables_used': ['concert'],
#    'columns_used': [['concert', 'year']],
#    'target': 0.0,
#    'tokens': ['[CLS]',
#     'how',
#     'many',
#     'singers',
#     'do',
#     'we',
#     'have',
#     '?',
#     '[SEP]',
#     'select',
#     'count',
#     '(',
#     'distinct',
#     'concert',
#     '.',
#     'year',
#     ')',
#     'from',
#     'concert',
#     '[SEP]'],
#    'encoded_tokens': [101,
#     2129,
#     2116,
#     8453,
#     2079,
#     2057,
#     2031,
#     1029,
#     102,
#     7276,
#     4175,
#     1006,
#     5664,
#     4164,
#     1012,
#     2095,
#     1007,
#     2013,
#     4164,
#     102],
#    'rank': 31},
#   {'sql_query': 'select count ( distinct concert.theme ) from concert',
#    'tables_used': ['concert'],
#    'columns_used': [['concert', 'theme']],
#    'target': 0.0,
#    'tokens': ['[CLS]',
#     'how',
#     'many',
#     'singers',
#     'do',
#     'we',
#     'have',
#     '?',
#     '[SEP]',
#     'select',
#     'count',
#     '(',
#     'distinct',
#     'concert',
#     '.',
#     'theme',
#     ')',
#     'from',
#     'concert',
#     '[SEP]'],
#    'encoded_tokens': [101,
#     2129,
#     2116,
#     8453,
#     2079,
#     2057,
#     2031,
#     1029,
#     102,
#     7276,
#     4175,
#     1006,
#     5664,
#     4164,
#     1012,
#     4323,
#     1007,
#     2013,
#     4164,
#     102],
#    'rank': 32},
#   {'sql_query': 'select count ( distinct stadium.location ) from stadium',
#    'tables_used': ['stadium'],
#    'columns_used': [['stadium', 'location']],
#    'target': 0.0,
#    'tokens': ['[CLS]',
#     'how',
#     'many',
#     'singers',
#     'do',
#     'we',
#     'have',
#     '?',
#     '[SEP]',
#     'select',
#     'count',
#     '(',
#     'distinct',
#     'stadium',
#     '.',
#     'location',
#     ')',
#     'from',
#     'stadium',
#     '[SEP]'],
#    'encoded_tokens': [101,
#     2129,
#     2116,
#     8453,
#     2079,
#     2057,
#     2031,
#     1029,
#     102,
#     7276,
#     4175,
#     1006,
#     5664,
#     3346,
#     1012,
#     3295,
#     1007,
#     2013,
#     3346,
#     102],
#    'rank': 33},
#   {'sql_query': 'select count ( * ) from singer join stadium on singer.singer_id = stadium.capacity',
#    'tables_used': ['singer', 'stadium'],
#    'columns_used': [['stadium', 'capacity'], ['singer', 'singer_id']],
#    'target': 0.0,
#    'tokens': ['[CLS]',
#     'how',
#     'many',
#     'singers',
#     'do',
#     'we',
#     'have',
#     '?',
#     '[SEP]',
#     'select',
#     'count',
#     '(',
#     '*',
#     ')',
#     'from',
#     'singer',
#     'join',
#     'stadium',
#     'on',
#     'singer',
#     '.',
#     'singer',
#     '_',
#     'id',
#     '=',
#     'stadium',
#     '.',
#     'capacity',
#     '[SEP]'],
#    'encoded_tokens': [101,
#     2129,
#     2116,
#     8453,
#     2079,
#     2057,
#     2031,
#     1029,
#     102,
#     7276,
#     4175,
#     1006,
#     1008,
#     1007,
#     2013,
#     3220,
#     3693,
#     3346,
#     2006,
#     3220,
#     1012,
#     3220,
#     1035,
#     8909,
#     1027,
#     3346,
#     1012,
#     3977,
#     102],
#    'rank': 34},
#   {'sql_query': 'select count ( * ) from concert join singer on concert.concert_id = concert.stadium_id',
#    'tables_used': ['concert', 'singer'],
#    'columns_used': [['concert', 'stadium_id'], ['concert', 'concert_id']],
#    'target': 0.0,
#    'tokens': ['[CLS]',
#     'how',
#     'many',
#     'singers',
#     'do',
#     'we',
#     'have',
#     '?',
#     '[SEP]',
#     'select',
#     'count',
#     '(',
#     '*',
#     ')',
#     'from',
#     'concert',
#     'join',
#     'singer',
#     'on',
#     'concert',
#     '.',
#     'concert',
#     '_',
#     'id',
#     '=',
#     'concert',
#     '.',
#     'stadium',
#     '_',
#     'id',
#     '[SEP]'],
#    'encoded_tokens': [101,
#     2129,
#     2116,
#     8453,
#     2079,
#     2057,
#     2031,
#     1029,
#     102,
#     7276,
#     4175,
#     1006,
#     1008,
#     1007,
#     2013,
#     4164,
#     3693,
#     3220,
#     2006,
#     4164,
#     1012,
#     4164,
#     1035,
#     8909,
#     1027,
#     4164,
#     1012,
#     3346,
#     1035,
#     8909,
#     102],
#    'rank': 35},
#   {'sql_query': 'select singer.song_name , count ( * ) from singer group by singer.name',
#    'tables_used': ['singer'],
#    'columns_used': [['singer', 'name'], ['singer', 'song_name']],
#    'target': 0.0,
#    'tokens': ['[CLS]',
#     'how',
#     'many',
#     'singers',
#     'do',
#     'we',
#     'have',
#     '?',
#     '[SEP]',
#     'select',
#     'singer',
#     '.',
#     'song',
#     '_',
#     'name',
#     ',',
#     'count',
#     '(',
#     '*',
#     ')',
#     'from',
#     'singer',
#     'group',
#     'by',
#     'singer',
#     '.',
#     'name',
#     '[SEP]'],
#    'encoded_tokens': [101,
#     2129,
#     2116,
#     8453,
#     2079,
#     2057,
#     2031,
#     1029,
#     102,
#     7276,
#     3220,
#     1012,
#     2299,
#     1035,
#     2171,
#     1010,
#     4175,
#     1006,
#     1008,
#     1007,
#     2013,
#     3220,
#     2177,
#     2011,
#     3220,
#     1012,
#     2171,
#     102],
#    'rank': 36},
#   {'sql_query': 'select count ( * ) from singer join stadium on singer.singer_id = singer.age',
#    'tables_used': ['singer', 'stadium'],
#    'columns_used': [['singer', 'age'], ['singer', 'singer_id']],
#    'target': 0.0,
#    'tokens': ['[CLS]',
#     'how',
#     'many',
#     'singers',
#     'do',
#     'we',
#     'have',
#     '?',
#     '[SEP]',
#     'select',
#     'count',
#     '(',
#     '*',
#     ')',
#     'from',
#     'singer',
#     'join',
#     'stadium',
#     'on',
#     'singer',
#     '.',
#     'singer',
#     '_',
#     'id',
#     '=',
#     'singer',
#     '.',
#     'age',
#     '[SEP]'],
#    'encoded_tokens': [101,
#     2129,
#     2116,
#     8453,
#     2079,
#     2057,
#     2031,
#     1029,
#     102,
#     7276,
#     4175,
#     1006,
#     1008,
#     1007,
#     2013,
#     3220,
#     3693,
#     3346,
#     2006,
#     3220,
#     1012,
#     3220,
#     1035,
#     8909,
#     1027,
#     3220,
#     1012,
#     2287,
#     102],
#    'rank': 37},
#   {'sql_query': 'select singer.name from singer',
#    'tables_used': ['singer'],
#    'columns_used': [['singer', 'name']],
#    'target': 0.0,
#    'tokens': ['[CLS]',
#     'how',
#     'many',
#     'singers',
#     'do',
#     'we',
#     'have',
#     '?',
#     '[SEP]',
#     'select',
#     'singer',
#     '.',
#     'name',
#     'from',
#     'singer',
#     '[SEP]'],
#    'encoded_tokens': [101,
#     2129,
#     2116,
#     8453,
#     2079,
#     2057,
#     2031,
#     1029,
#     102,
#     7276,
#     3220,
#     1012,
#     2171,
#     2013,
#     3220,
#     102],
#    'rank': 38},
#   {'sql_query': "select count ( * ) from stadium where stadium.stadium_id = ' value '",
#    'tables_used': ['stadium'],
#    'columns_used': [['stadium', 'stadium_id']],
#    'target': 0.0,
#    'tokens': ['[CLS]',
#     'how',
#     'many',
#     'singers',
#     'do',
#     'we',
#     'have',
#     '?',
#     '[SEP]',
#     'select',
#     'count',
#     '(',
#     '*',
#     ')',
#     'from',
#     'stadium',
#     'where',
#     'stadium',
#     '.',
#     'stadium',
#     '_',
#     'id',
#     '=',
#     "'",
#     'value',
#     "'",
#     '[SEP]'],
#    'encoded_tokens': [101,
#     2129,
#     2116,
#     8453,
#     2079,
#     2057,
#     2031,
#     1029,
#     102,
#     7276,
#     4175,
#     1006,
#     1008,
#     1007,
#     2013,
#     3346,
#     2073,
#     3346,
#     1012,
#     3346,
#     1035,
#     8909,
#     1027,
#     1005,
#     3643,
#     1005,
#     102],
#    'rank': 39}]}

# %%
len(train_data_processed), len(val_data_processed)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-c5beccc4fd0a> in <module>
# ----> 1 len(train_data_processed), len(val_data_processed)
#
# NameError: name 'train_data_processed' is not defined

# %%
import torch.utils.data
class BeamOutputDataset(torch.utils.data.Dataset):
    def __init__(self, items):
        self.items = items
        
    def __len__(self):
        return len(self.items)
    
    def __getitem__(self, idx):
        return self.items[idx]

# %%
#train_dataset = BeamOutputDataset(train_data_processed)
val_dataset = BeamOutputDataset(val_data_processed)
#val_normaleval_dataset = BeamOutputDataset(val_data_normaleval_preprocessed)

# %%
# train_loader = torch.utils.data.DataLoader(
#     batch_size=1,
#     dataset=train_dataset,
#     shuffle=True,
#     collate_fn=lambda x: x # So dicts aren't merged
# )
val_loader = torch.utils.data.DataLoader(
    batch_size=1,
    dataset=val_dataset,
    shuffle=False,
    collate_fn=lambda x: x
)
# val_normaleval_loader = torch.utils.data.DataLoader(
#     batch_size=1,
#     dataset=val_normaleval_dataset,
#     shuffle=False,
#     collate_fn=lambda x: x
# )

# %%
train_bert = True

# %%
bert_model = BertForSequenceClassification.from_pretrained('bert-base-uncased', num_labels=2)

# %%
def get_as_batch(batch, key):
    result = []
    for sample in batch:
        result.append(sample[key])
    return result

# %%
optim = torch.optim.Adam([
    {"params": bert_model.parameters(), "lr": 5e-6}  # 5e-6 converges faster than 1e-6
], lr=1e-6)

# %%
for param in bert_model.parameters():
    param.requires_grad = train_bert

# %%
bert_model.cuda()
# Out:
# BertForSequenceClassification(
#   (bert): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(30522, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm(torch.Size([768]), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm(torch.Size([768]), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm(torch.Size([768]), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1)
#           )
#         )
#         (1): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm(torch.Size([768]), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm(torch.Size([768]), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1)
#           )
#         )
#         (2): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm(torch.Size([768]), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm(torch.Size([768]), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1)
#           )
#         )
#         (3): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm(torch.Size([768]), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm(torch.Size([768]), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1)
#           )
#         )
#         (4): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm(torch.Size([768]), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm(torch.Size([768]), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1)
#           )
#         )
#         (5): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm(torch.Size([768]), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm(torch.Size([768]), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1)
#           )
#         )
#         (6): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm(torch.Size([768]), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm(torch.Size([768]), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1)
#           )
#         )
#         (7): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm(torch.Size([768]), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm(torch.Size([768]), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1)
#           )
#         )
#         (8): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm(torch.Size([768]), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm(torch.Size([768]), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1)
#           )
#         )
#         (9): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm(torch.Size([768]), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm(torch.Size([768]), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1)
#           )
#         )
#         (10): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm(torch.Size([768]), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm(torch.Size([768]), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1)
#           )
#         )
#         (11): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm(torch.Size([768]), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm(torch.Size([768]), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (dropout): Dropout(p=0.1)
#   (classifier): Linear(in_features=768, out_features=2, bias=True)
# )

# %%
def run_instance(bert_model, instance):
    encoded_tokens = torch.tensor(instance['encoded_tokens']).unsqueeze(0).cuda()
    target = int(instance['target'])
    labels = torch.tensor([target]).unsqueeze(0).cuda()
    outputs = bert_model(encoded_tokens, labels=labels)
    loss1, logits = outputs[:2]
    preds = F.softmax(logits, dim=1)
    pred_index = torch.argmax(preds[0])  # Remove batch
    if target == pred_index.item():
        correct = 1
    else:
        correct = 0
    return loss1, correct, preds

def run_epoch(bert_model, data_loader, train_bert, optim, training=True, print_samples=False):
    if training:
        bert_model.train()
        torch.set_grad_enabled(True)
    else:
        bert_model.eval()
        torch.set_grad_enabled(False)
        
    tk0 = tqdm(data_loader, total=int(len(data_loader)))
    running_loss = 0.0
    counter = 0
    counter_correct = 0
    for i, batch in enumerate(tk0):
        if training:
            optim.zero_grad()
        
        sample = batch[0]  # Assume batch size of 1
        loss = torch.tensor(0.0).cuda()
        for instance in sample['correct_instances']:
            loss1, correct, preds = run_instance(bert_model, instance)
            loss += loss1
            counter_correct += correct
            counter += 1
        
        num_incorrect = len(sample['incorrect_instances'])
        for instance in random.sample(sample['incorrect_instances'], min(10, num_incorrect)):
            loss1, correct, preds = run_instance(bert_model, instance)
            loss += loss1
            counter_correct += correct
            counter += 1
            
            
            
        if training:
            loss.backward()
            optim.step()          
        running_loss += loss.item()
        tk0.set_postfix(loss=(running_loss/counter),
                        acc=(counter_correct/counter))

# %%
## Smarter (than below) rerank algo that does a stable sort with a threshold value


import functools
def cmp(x, y):
    """
    Replacement for built-in function cmp that was removed in Python 3

    Compare the two objects x and y and return an integer according to
    the outcome. The return value is negative if x < y, zero if x == y
    and strictly positive if x > y.
    """

    return (x > y) - (x < y)

def compare(thresh, a, b):
    a = a['score']
    b = b['score'] + thresh
    return cmp(a, b)
    

def run_rerank(bert_model, data_loader, thresh, print_errors=False):
    bert_model.eval()
    torch.set_grad_enabled(False)
    
    tk0 = tqdm(data_loader, total=int(len(data_loader)))
    counter = 0
    counter_rerank_correct = 0
    counter_original_correct = 0
    
    compare_f = functools.partial(compare, thresh)
    
    for i, batch in enumerate(tk0):
        sample = batch[0]  # Assume batch size of 1
        counter += 1
        instances = sample['instances']
        original_correct = False
        if instances[0]['target'] > 0.5:
            original_correct = True
            counter_original_correct += 1
        
        preds = []
        myinstances = []
        for instance in instances[:10]:
            instance = instance.copy()
            loss, correct, pred = run_instance(bert_model, instance)
            preds.append(pred[0][1].item()) # Remove batch, get prob of 1
            instance['score'] = pred[0][1].item()
            myinstances.append(instance)
            
        pred_instance = list(reversed(sorted(myinstances, key=functools.cmp_to_key(compare_f))))[0]
        rerank_correct = False
        
        if pred_instance['target'] > 0.5:
            rerank_correct = True
            counter_rerank_correct += 1
        
        if print_errors and original_correct and not rerank_correct:
            print('\n')
            print('*' * 10)
            print(sample['utterance'])
            for index, ins in enumerate(sample['instances'][:10]):
                p = False
                if index == 0:
                    print('=' * 10)
                    print(f'CORRECT QUERY ; score: {ins["score"]:.2f}')
                    p = True
                if ins == pred_instance:
                    print('=' * 10)
                    print(f'SELECTED QUERY ; score: {ins["score"]:.2f}')
                    p = True
                if p:
                    print(ins['sql_query'])
                    print(ins['columns_used'])
                    print(ins['tables_used'])
            
        rerank_acc = counter_rerank_correct/counter
        tk0.set_postfix(original_acc=(counter_original_correct/counter),
                        rerank_acc=rerank_acc)
    return rerank_acc

# %%
# Simpler reranking that only compares the best with the top and accepts if it exceeds a threshold
# The one above seems to perform 0.3% better so we'll use that
# def run_rerank(bert_model, data_loader, thresh, print_errors=False):
#     bert_model.eval()
#     torch.set_grad_enabled(False)
    
#     tk0 = tqdm(data_loader, total=int(len(data_loader)))
#     counter = 0
#     counter_rerank_correct = 0
#     counter_original_correct = 0
    
#     for i, batch in enumerate(tk0):
#         sample = batch[0]  # Assume batch size of 1
#         counter += 1
#         instances = sample['instances']
#         original_correct = False
#         if instances[0]['target'] > 0.5:
#             original_correct = True
#             counter_original_correct += 1
        
#         preds = []
#         for instance in instances[:10]:
#             loss, correct, pred = run_instance(bert_model, instance)
#             preds.append(pred[0][1].item()) # Remove batch, get prob of 1
#         best_pred_index = preds.index(max(preds))  # Get the index of the max, picking the first one if there's a conflict
#         rerank_correct = False
#         if preds[best_pred_index] - preds[0] < thresh:
#             # We're only going to rerank if there's a large discrepancy
#             best_pred_index = 0
        
#         if instances[best_pred_index]['target'] > 0.5:
#             rerank_correct = True
#             counter_rerank_correct += 1
        
#         if print_errors and original_correct and not rerank_correct:
#             print('\n')
#             print('*' * 10)
#             print(sample['utterance'])
#             for index, ins in enumerate(sample['instances'][:10]):
#                 p = False
#                 if index == 0:
#                     print('=' * 10)
#                     print(f'CORRECT QUERY ; score: {preds[index]}')
#                     p = True
#                 if index == best_pred_index:
#                     print('=' * 10)
#                     print(f'SELECTED QUERY ; score: {preds[index]}')
#                     p = True
#                 if p:
#                     print(ins['sql_query'])
#                     print(ins['columns_used'])
#                     print(ins['tables_used'])
            
#         rerank_acc = counter_rerank_correct/counter
#         tk0.set_postfix(original_acc=(counter_original_correct/counter),
#                         rerank_acc=rerank_acc)
#     return rerank_acc

# %%
num_epochs = 10

print('Initial validation run')
best_rerank_acc = run_rerank(bert_model, val_loader, thresh=0.1, print_errors=False)
run_epoch(bert_model, val_loader, train_bert, optim, training=False, print_samples=False)
best_epoch = -1


for epoch in range(num_epochs):
    print('Epoch {}/{}'.format(epoch, num_epochs - 1))
    print('-' * 10)
    
    run_epoch(bert_model, train_loader, train_bert, optim, training=True)

    print('Validation')
    
    run_epoch(bert_model, val_loader, train_bert, optim, training=False)
    
    print('Rerank')
    
    rerank_acc = run_rerank(bert_model, val_loader, thresh=0.1, print_errors=False)
    if rerank_acc > best_rerank_acc:
        best_epoch = epoch
        best_rerank_acc = rerank_acc
        print(f'Saving model at epoch {epoch}')
        torch.save(bert_model, 'best_disrim_model.pth')
# Out:
# Initial validation run
# HBox(children=(IntProgress(value=0, max=1020), HTML(value='')))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-63-0b66e93367be> in <module>
#       2
#       3 print('Initial validation run')
# ----> 4 best_rerank_acc = run_rerank(bert_model, val_loader, thresh=0.1, print_errors=False)
#       5 run_epoch(bert_model, val_loader, train_bert, optim, training=False, print_samples=False)
#       6 best_epoch = -1
#
# <ipython-input-61-33c911c2c32c> in run_rerank(bert_model, data_loader, thresh, print_errors)
#      44         for instance in instances[:10]:
#      45             instance = instance.copy()
# ---> 46             loss, correct, pred = run_instance(bert_model, instance)
#      47             preds.append(pred[0][1].item()) # Remove batch, get prob of 1
#      48             instance['score'] = pred[0][1].item()
#
# <ipython-input-60-83f8d5d99268> in run_instance(bert_model, instance)
#       3     target = int(instance['target'])
#       4     labels = torch.tensor([target]).unsqueeze(0).cuda()
# ----> 5     outputs = bert_model(encoded_tokens, labels=labels)
#       6     loss1, logits = outputs[:2]
#       7     preds = F.softmax(logits, dim=1)
#
# ~/miniconda3/envs/spider-schema-gnn/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# ~/miniconda3/envs/spider-schema-gnn/lib/python3.7/site-packages/transformers/modeling_bert.py in forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, labels)
#     895                             token_type_ids=token_type_ids,
#     896                             position_ids=position_ids,
# --> 897                             head_mask=head_mask)
#     898
#     899         pooled_output = outputs[1]
#
# ~/miniconda3/envs/spider-schema-gnn/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# ~/miniconda3/envs/spider-schema-gnn/lib/python3.7/site-packages/transformers/modeling_bert.py in forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask)
#     625         encoder_outputs = self.encoder(embedding_output,
#     626                                        extended_attention_mask,
# --> 627                                        head_mask=head_mask)
#     628         sequence_output = encoder_outputs[0]
#     629         pooled_output = self.pooler(sequence_output)
#
# ~/miniconda3/envs/spider-schema-gnn/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# ~/miniconda3/envs/spider-schema-gnn/lib/python3.7/site-packages/transformers/modeling_bert.py in forward(self, hidden_states, attention_mask, head_mask)
#     346                 all_hidden_states = all_hidden_states + (hidden_states,)
#     347
# --> 348             layer_outputs = layer_module(hidden_states, attention_mask, head_mask[i])
#     349             hidden_states = layer_outputs[0]
#     350
#
# ~/miniconda3/envs/spider-schema-gnn/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# ~/miniconda3/envs/spider-schema-gnn/lib/python3.7/site-packages/transformers/modeling_bert.py in forward(self, hidden_states, attention_mask, head_mask)
#     326         attention_outputs = self.attention(hidden_states, attention_mask, head_mask)
#     327         attention_output = attention_outputs[0]
# --> 328         intermediate_output = self.intermediate(attention_output)
#     329         layer_output = self.output(intermediate_output, attention_output)
#     330         outputs = (layer_output,) + attention_outputs[1:]  # add attentions if we output them
#
# ~/miniconda3/envs/spider-schema-gnn/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# ~/miniconda3/envs/spider-schema-gnn/lib/python3.7/site-packages/transformers/modeling_bert.py in forward(self, hidden_states)
#     297
#     298     def forward(self, hidden_states):
# --> 299         hidden_states = self.dense(hidden_states)
#     300         hidden_states = self.intermediate_act_fn(hidden_states)
#     301         return hidden_states
#
# ~/miniconda3/envs/spider-schema-gnn/lib/python3.7/site-packages/torch/nn/modules/module.py in __getattr__(self, name)
#     530         if '_modules' in self.__dict__:
#     531             modules = self.__dict__['_modules']
# --> 532             if name in modules:
#     533                 return modules[name]
#     534         raise AttributeError("'{}' object has no attribute '{}'".format(
#
# KeyboardInterrupt:

# %%
torch.save(bert_model, 'final_model.pth')

# %%
bert_model.load_state_dict(torch.load('best_discrim_model_full_spider_retrained_sqlonly.state.pth'))
#with open('best_discrim_model_full_spider_retrained_sqlonly.state.pth', 'rb') as f:
    #file = f.read()
#    bert_model = torch.load(f)
bert_model.cuda()
# Out:
# BertForSequenceClassification(
#   (bert): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(30522, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm(torch.Size([768]), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm(torch.Size([768]), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm(torch.Size([768]), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1)
#           )
#         )
#         (1): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm(torch.Size([768]), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm(torch.Size([768]), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1)
#           )
#         )
#         (2): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm(torch.Size([768]), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm(torch.Size([768]), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1)
#           )
#         )
#         (3): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm(torch.Size([768]), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm(torch.Size([768]), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1)
#           )
#         )
#         (4): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm(torch.Size([768]), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm(torch.Size([768]), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1)
#           )
#         )
#         (5): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm(torch.Size([768]), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm(torch.Size([768]), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1)
#           )
#         )
#         (6): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm(torch.Size([768]), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm(torch.Size([768]), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1)
#           )
#         )
#         (7): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm(torch.Size([768]), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm(torch.Size([768]), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1)
#           )
#         )
#         (8): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm(torch.Size([768]), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm(torch.Size([768]), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1)
#           )
#         )
#         (9): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm(torch.Size([768]), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm(torch.Size([768]), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1)
#           )
#         )
#         (10): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm(torch.Size([768]), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm(torch.Size([768]), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1)
#           )
#         )
#         (11): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm(torch.Size([768]), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm(torch.Size([768]), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (dropout): Dropout(p=0.1)
#   (classifier): Linear(in_features=768, out_features=2, bias=True)
# )

# %%
#torch.save(bert_model.state_dict(), 'best_discrim_model_full_spider_retrained_sqlonly.state.pth')

# %%
run_rerank(bert_model, val_loader, thresh=0.10, print_errors=False)
# Out:
# HBox(children=(IntProgress(value=0, max=1020), HTML(value='')))
# 0.5784313725490197

# %% [markdown]
# ## All results with keep_unparsable = false (ie. 1020 devset)
#
# 54.8 (harder eval) vs 55.4 (normal eval)  # bert + gnn + train_spider + HIGH LR
#
# 50.1/54.5 (harder eval) vs 51.2/55.7 (normal eval) # non retrained reranker + bert + gnn + train_all
#
# 50.1/54.5 (harder eval) vs 51.2/56.3 (normal eval) # retrained ranker + bert + gnn + train_all
#
# 50.1/56.9 (harder eval) vs 51.2/57.8 (normal eval) # retrainer ranker (nl + sql) + bert + gnn + train_all
