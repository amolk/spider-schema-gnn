# %% [markdown]
# ## GNNDiscrimNet SQL
# ```
# Input: NLU + Predicted Columns
# Output: 1 if correct, 0 if incorrect
# Side effect: Reranking of BEAM outputs from GNN model
# Architecture:
# BERT + classification layer
# ```

# %% [markdown]
# The beam output files are generated with the following command: (beam output should be 40 instead of 10 for train, can be 10 for dev). Make sure to modify the json source file (train, dev etc) as needed
# ```
# allennlp predict experiments/bert-spider-low-lr/ ./datasets/spider/train_spider.json --predictor spider_discriminator --use-dataset-reader --cuda-device=0 --silent --output-file out.jsonlines --include-package models.semantic_parsing.spider_parser --include-package dataset_readers.spider --include-package predictors.discriminator_dataset_generator --weights-file experiments/bert-spider-low-lr/best.th
# ```

# %%
# !pip install transformers
# !conda install -y -c conda-forge ipywidgets

# %%
# !conda install -y line_profiler

# %%
import os

# %%
os.environ['CUDA_VISIBLE_DEVICES'] = '0'

# %%
#!pip install sql_metadata

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from transformers import *
import numpy as np
import sql_metadata
from pathlib import Path
import json
from tqdm import tqdm_notebook as tqdm
import pprint
import random

# %%
# %load_ext line_profiler

# %%
pp = pprint.PrettyPrinter(indent=2)

# %%
def load_beam_outputs(filename):
    filename = Path(filename)
    data = []
    with filename.open('r') as f:
        for line in f:
            data.append(json.loads(line))
    return data

# %%
val_items = load_beam_outputs('experiments/train_EC30_5k_run2/dev_beam_output.jsonlines')#'dev_all_beam.jsonlines')
train_items = load_beam_outputs('experiments/train_EC30_5k_run2/train_beam_output.jsonlines')#'train_all_beam.jsonlines')  # train_all = train_spider + train_others
#val_normaleval_items = load_beam_outputs('dev_full.jsonlines')#'dev_all_normaleval_beam.jsonlines') # Created with the easier evaluator

# %%
val_items[226]
# Out:
# {'utterance': 'I need the highest price for every user that has made a payment for a subscription that has expired last January 1, 2019.',
#  'instances': [{'sql_query': "select max ( subscription.price ) , braintree_transaction_log.asker_id from braintree_transaction_log join subscription on subscription.purchaser_id = braintree_transaction_log.asker_id where subscription.expiration = ' value ' group by braintree_transaction_log.asker_id",
#    'tables_used': ['braintree_transaction_log', 'subscription'],
#    'columns_used': [['subscription', 'purchaser_id'],
#     ['braintree_transaction_log', 'asker_id'],
#     ['subscription', 'price'],
#     ['subscription', 'expiration']],
#    'target': 0.0},
#   {'sql_query': "select max ( braintree_transaction_log.price ) , braintree_transaction_log.asker_id from braintree_transaction_log join subscription on subscription.purchaser_id = braintree_transaction_log.asker_id where subscription.expiration = ' value ' group by braintree_transaction_log.asker_id",
#    'tables_used': ['braintree_transaction_log', 'subscription'],
#    'columns_used': [['braintree_transaction_log', 'price'],
#     ['braintree_transaction_log', 'asker_id'],
#     ['subscription', 'expiration'],
#     ['subscription', 'purchaser_id']],
#    'target': 1.0},
#   {'sql_query': "select max ( subscription.price ) , braintree_transaction_log.asker_id from braintree_transaction_log join subscription on braintree_transaction_log.asker_id = subscription.purchaser_id where subscription.expiration = ' value ' group by braintree_transaction_log.asker_id",
#    'tables_used': ['braintree_transaction_log', 'subscription'],
#    'columns_used': [['subscription', 'purchaser_id'],
#     ['braintree_transaction_log', 'asker_id'],
#     ['subscription', 'price'],
#     ['subscription', 'expiration']],
#    'target': 0.0},
#   {'sql_query': "select max ( braintree_transaction_log.price ) , braintree_transaction_log.asker_id from braintree_transaction_log join subscription on braintree_transaction_log.asker_id = subscription.purchaser_id where subscription.expiration = ' value ' group by braintree_transaction_log.asker_id",
#    'tables_used': ['braintree_transaction_log', 'subscription'],
#    'columns_used': [['braintree_transaction_log', 'price'],
#     ['braintree_transaction_log', 'asker_id'],
#     ['subscription', 'expiration'],
#     ['subscription', 'purchaser_id']],
#    'target': 1.0},
#   {'sql_query': "select max ( subscription.price ) , problem.asker_id from problem join subscription on problem.asker_id = subscription.purchaser_id where subscription.expiration = ' value ' group by problem.asker_id",
#    'tables_used': ['subscription', 'problem'],
#    'columns_used': [['subscription', 'purchaser_id'],
#     ['subscription', 'price'],
#     ['subscription', 'expiration'],
#     ['problem', 'asker_id']],
#    'target': 0.0},
#   {'sql_query': "select max ( subscription.price ) , braintree_transaction_log.asker_id from braintree_transaction_log join subscription on subscription.purchaser_id = braintree_transaction_log.asker_id where subscription.expiration = ' value ' group by subscription.purchaser_id",
#    'tables_used': ['braintree_transaction_log', 'subscription'],
#    'columns_used': [['subscription', 'purchaser_id'],
#     ['braintree_transaction_log', 'asker_id'],
#     ['subscription', 'price'],
#     ['subscription', 'expiration']],
#    'target': 0.0},
#   {'sql_query': "select max ( subscription.price ) , subscription.purchaser_id from braintree_transaction_log join subscription on braintree_transaction_log.asker_id = subscription.purchaser_id where subscription.expiration = ' value ' group by braintree_transaction_log.asker_id",
#    'tables_used': ['braintree_transaction_log', 'subscription'],
#    'columns_used': [['subscription', 'purchaser_id'],
#     ['braintree_transaction_log', 'asker_id'],
#     ['subscription', 'price'],
#     ['subscription', 'expiration']],
#    'target': 0.0},
#   {'sql_query': "select max ( braintree_transaction_log.price ) , braintree_transaction_log.asker_id from braintree_transaction_log join subscription on subscription.purchaser_id = braintree_transaction_log.asker_id where subscription.expiration = ' value ' group by subscription.purchaser_id",
#    'tables_used': ['braintree_transaction_log', 'subscription'],
#    'columns_used': [['braintree_transaction_log', 'price'],
#     ['braintree_transaction_log', 'asker_id'],
#     ['subscription', 'expiration'],
#     ['subscription', 'purchaser_id']],
#    'target': 1.0},
#   {'sql_query': "select max ( subscription.price ) , braintree_transaction_log.asker_id from braintree_transaction_log join subscription on braintree_transaction_log.asker_id = subscription.purchaser_id where subscription.expiration = ' value ' group by subscription.purchaser_id",
#    'tables_used': ['braintree_transaction_log', 'subscription'],
#    'columns_used': [['subscription', 'purchaser_id'],
#     ['braintree_transaction_log', 'asker_id'],
#     ['subscription', 'price'],
#     ['subscription', 'expiration']],
#    'target': 0.0},
#   {'sql_query': "select max ( subscription.price ) , subscription.purchaser_id from braintree_transaction_log join subscription on subscription.purchaser_id = braintree_transaction_log.asker_id where subscription.expiration = ' value ' group by braintree_transaction_log.asker_id",
#    'tables_used': ['braintree_transaction_log', 'subscription'],
#    'columns_used': [['subscription', 'purchaser_id'],
#     ['braintree_transaction_log', 'asker_id'],
#     ['subscription', 'price'],
#     ['subscription', 'expiration']],
#    'target': 0.0},
#   {'sql_query': "select max ( braintree_transaction_log.price ) , subscription.purchaser_id from braintree_transaction_log join subscription on braintree_transaction_log.asker_id = subscription.purchaser_id where subscription.expiration = ' value ' group by braintree_transaction_log.asker_id",
#    'tables_used': ['braintree_transaction_log', 'subscription'],
#    'columns_used': [['braintree_transaction_log', 'price'],
#     ['braintree_transaction_log', 'asker_id'],
#     ['subscription', 'expiration'],
#     ['subscription', 'purchaser_id']],
#    'target': 1.0},
#   {'sql_query': "select max ( subscription.price ) , visitor.first_asker_id from visitor join subscription on subscription.purchaser_id = visitor.first_asker_id where subscription.expiration = ' value ' group by visitor.first_asker_id",
#    'tables_used': ['visitor', 'subscription'],
#    'columns_used': [['subscription', 'purchaser_id'],
#     ['subscription', 'price'],
#     ['subscription', 'expiration'],
#     ['visitor', 'first_asker_id']],
#    'target': 0.0},
#   {'sql_query': "select max ( subscription.price ) , visitor.first_asker_id from visitor join subscription on visitor.first_asker_id = subscription.purchaser_id where subscription.expiration = ' value ' group by visitor.first_asker_id",
#    'tables_used': ['visitor', 'subscription'],
#    'columns_used': [['subscription', 'purchaser_id'],
#     ['subscription', 'price'],
#     ['subscription', 'expiration'],
#     ['visitor', 'first_asker_id']],
#    'target': 0.0},
#   {'sql_query': "select max ( subscription.price ) , subscription.purchaser_id from braintree_transaction_log join subscription on braintree_transaction_log.asker_id = subscription.purchaser_id where subscription.expiration = ' value ' group by subscription.purchaser_id",
#    'tables_used': ['braintree_transaction_log', 'subscription'],
#    'columns_used': [['subscription', 'purchaser_id'],
#     ['braintree_transaction_log', 'asker_id'],
#     ['subscription', 'price'],
#     ['subscription', 'expiration']],
#    'target': 0.0},
#   {'sql_query': "select max ( subscription.price ) , problem.asker_id from problem join subscription on subscription.purchaser_id = problem.asker_id where subscription.expiration = ' value ' group by problem.asker_id",
#    'tables_used': ['subscription', 'problem'],
#    'columns_used': [['subscription', 'purchaser_id'],
#     ['subscription', 'price'],
#     ['subscription', 'expiration'],
#     ['problem', 'asker_id']],
#    'target': 0.0},
#   {'sql_query': "select max ( braintree_transaction_log.price ) , braintree_transaction_log.asker_id from braintree_transaction_log join subscription on braintree_transaction_log.asker_id = subscription.purchaser_id where subscription.expiration = ' value ' group by subscription.purchaser_id",
#    'tables_used': ['braintree_transaction_log', 'subscription'],
#    'columns_used': [['braintree_transaction_log', 'price'],
#     ['braintree_transaction_log', 'asker_id'],
#     ['subscription', 'expiration'],
#     ['subscription', 'purchaser_id']],
#    'target': 1.0},
#   {'sql_query': "select max ( subscription.price ) , problem.asker_id from braintree_transaction_log join subscription on subscription.purchaser_id = braintree_transaction_log.asker_id join problem on problem.asker_id = braintree_transaction_log.asker_id where subscription.expiration = ' value ' group by braintree_transaction_log.asker_id",
#    'tables_used': ['braintree_transaction_log', 'subscription', 'problem'],
#    'columns_used': [['subscription', 'purchaser_id'],
#     ['subscription', 'price'],
#     ['problem', 'asker_id'],
#     ['braintree_transaction_log', 'asker_id'],
#     ['subscription', 'expiration']],
#    'target': 0.0},
#   {'sql_query': "select max ( subscription.price ) , problem.asker_id from braintree_transaction_log join subscription on subscription.purchaser_id = braintree_transaction_log.asker_id join problem on problem.asker_id = braintree_transaction_log.asker_id where subscription.expiration = ' value ' group by problem.asker_id",
#    'tables_used': ['braintree_transaction_log', 'subscription', 'problem'],
#    'columns_used': [['subscription', 'purchaser_id'],
#     ['subscription', 'price'],
#     ['problem', 'asker_id'],
#     ['braintree_transaction_log', 'asker_id'],
#     ['subscription', 'expiration']],
#    'target': 0.0},
#   {'sql_query': "select max ( braintree_transaction_log.price ) , subscription.purchaser_id from braintree_transaction_log join subscription on subscription.purchaser_id = braintree_transaction_log.asker_id where subscription.expiration = ' value ' group by braintree_transaction_log.asker_id",
#    'tables_used': ['braintree_transaction_log', 'subscription'],
#    'columns_used': [['braintree_transaction_log', 'price'],
#     ['braintree_transaction_log', 'asker_id'],
#     ['subscription', 'expiration'],
#     ['subscription', 'purchaser_id']],
#    'target': 1.0},
#   {'sql_query': "select max ( braintree_transaction_log.price ) , problem.asker_id from problem join subscription on problem.asker_id = subscription.purchaser_id where subscription.expiration = ' value ' group by problem.asker_id",
#    'tables_used': ['subscription', 'problem'],
#    'columns_used': [['braintree_transaction_log', 'price'],
#     ['subscription', 'expiration'],
#     ['problem', 'asker_id'],
#     ['subscription', 'purchaser_id']],
#    'target': 0.0},
#   {'sql_query': "select max ( braintree_transaction_log.price ) , problem.asker_id from braintree_transaction_log join subscription on braintree_transaction_log.asker_id = subscription.purchaser_id where subscription.expiration = ' value ' group by braintree_transaction_log.asker_id",
#    'tables_used': ['braintree_transaction_log', 'subscription'],
#    'columns_used': [['subscription', 'purchaser_id'],
#     ['problem', 'asker_id'],
#     ['braintree_transaction_log', 'price'],
#     ['braintree_transaction_log', 'asker_id'],
#     ['subscription', 'expiration']],
#    'target': 0.0},
#   {'sql_query': "select max ( subscription.price ) , problem.asker_id from subscription join problem on problem.asker_id = subscription.purchaser_id where subscription.expiration = ' value ' group by problem.asker_id",
#    'tables_used': ['subscription', 'problem'],
#    'columns_used': [['subscription', 'purchaser_id'],
#     ['subscription', 'price'],
#     ['subscription', 'expiration'],
#     ['problem', 'asker_id']],
#    'target': 0.0},
#   {'sql_query': "select max ( subscription.price ) , visitor.first_asker_id from visitor join braintree_transaction_log on braintree_transaction_log.asker_id = visitor.first_asker_id join subscription on visitor.first_asker_id = subscription.purchaser_id where subscription.expiration = ' value ' group by visitor.first_asker_id",
#    'tables_used': ['braintree_transaction_log', 'visitor', 'subscription'],
#    'columns_used': [['subscription', 'purchaser_id'],
#     ['subscription', 'price'],
#     ['braintree_transaction_log', 'asker_id'],
#     ['subscription', 'expiration'],
#     ['visitor', 'first_asker_id']],
#    'target': 0.0},
#   {'sql_query': "select max ( subscription.price ) , visitor.first_asker_id from visitor join braintree_transaction_log on braintree_transaction_log.asker_id = visitor.first_asker_id join subscription on subscription.purchaser_id = visitor.first_asker_id where subscription.expiration = ' value ' group by visitor.first_asker_id",
#    'tables_used': ['braintree_transaction_log', 'visitor', 'subscription'],
#    'columns_used': [['subscription', 'purchaser_id'],
#     ['subscription', 'price'],
#     ['braintree_transaction_log', 'asker_id'],
#     ['subscription', 'expiration'],
#     ['visitor', 'first_asker_id']],
#    'target': 0.0},
#   {'sql_query': "select max ( braintree_transaction_log.price ) , problem.asker_id from braintree_transaction_log join subscription on subscription.purchaser_id = braintree_transaction_log.asker_id where subscription.expiration = ' value ' group by braintree_transaction_log.asker_id",
#    'tables_used': ['braintree_transaction_log', 'subscription'],
#    'columns_used': [['subscription', 'purchaser_id'],
#     ['problem', 'asker_id'],
#     ['braintree_transaction_log', 'price'],
#     ['braintree_transaction_log', 'asker_id'],
#     ['subscription', 'expiration']],
#    'target': 0.0},
#   {'sql_query': "select max ( braintree_transaction_log.price ) , visitor.first_asker_id from visitor join subscription on subscription.purchaser_id = visitor.first_asker_id where subscription.expiration = ' value ' group by visitor.first_asker_id",
#    'tables_used': ['visitor', 'subscription'],
#    'columns_used': [['braintree_transaction_log', 'price'],
#     ['subscription', 'expiration'],
#     ['subscription', 'purchaser_id'],
#     ['visitor', 'first_asker_id']],
#    'target': 0.0},
#   {'sql_query': "select max ( braintree_transaction_log.price ) , visitor.first_asker_id from visitor join subscription on visitor.first_asker_id = subscription.purchaser_id where subscription.expiration = ' value ' group by visitor.first_asker_id",
#    'tables_used': ['visitor', 'subscription'],
#    'columns_used': [['braintree_transaction_log', 'price'],
#     ['subscription', 'expiration'],
#     ['visitor', 'first_asker_id'],
#     ['subscription', 'purchaser_id']],
#    'target': 0.0},
#   {'sql_query': "select max ( subscription.price ) , problem.asker_id from braintree_transaction_log join subscription on braintree_transaction_log.asker_id = subscription.purchaser_id join problem on problem.asker_id = braintree_transaction_log.asker_id where subscription.expiration = ' value ' group by problem.asker_id",
#    'tables_used': ['braintree_transaction_log', 'subscription', 'problem'],
#    'columns_used': [['subscription', 'purchaser_id'],
#     ['subscription', 'price'],
#     ['problem', 'asker_id'],
#     ['braintree_transaction_log', 'asker_id'],
#     ['subscription', 'expiration']],
#    'target': 0.0},
#   {'sql_query': "select max ( subscription.price ) , problem.asker_id from braintree_transaction_log join subscription on braintree_transaction_log.asker_id = subscription.purchaser_id join problem on problem.asker_id = braintree_transaction_log.asker_id where subscription.expiration = ' value ' group by braintree_transaction_log.asker_id",
#    'tables_used': ['braintree_transaction_log', 'subscription', 'problem'],
#    'columns_used': [['subscription', 'purchaser_id'],
#     ['subscription', 'price'],
#     ['problem', 'asker_id'],
#     ['braintree_transaction_log', 'asker_id'],
#     ['subscription', 'expiration']],
#    'target': 0.0},
#   {'sql_query': "select max ( subscription.price ) , problem.asker_id from subscription join braintree_transaction_log on braintree_transaction_log.asker_id = subscription.purchaser_id where subscription.expiration = ' value ' group by subscription.purchaser_id",
#    'tables_used': ['braintree_transaction_log', 'subscription'],
#    'columns_used': [['subscription', 'purchaser_id'],
#     ['subscription', 'price'],
#     ['problem', 'asker_id'],
#     ['braintree_transaction_log', 'asker_id'],
#     ['subscription', 'expiration']],
#    'target': 0.0},
#   {'sql_query': "select max ( braintree_transaction_log.price ) , subscription.purchaser_id from braintree_transaction_log join subscription on braintree_transaction_log.asker_id = subscription.purchaser_id where subscription.expiration = ' value ' group by subscription.purchaser_id",
#    'tables_used': ['braintree_transaction_log', 'subscription'],
#    'columns_used': [['braintree_transaction_log', 'price'],
#     ['braintree_transaction_log', 'asker_id'],
#     ['subscription', 'expiration'],
#     ['subscription', 'purchaser_id']],
#    'target': 1.0},
#   {'sql_query': "select max ( subscription.price ) , problem.asker_id from subscription join braintree_transaction_log on braintree_transaction_log.asker_id = subscription.purchaser_id where subscription.expiration = ' value ' group by braintree_transaction_log.asker_id",
#    'tables_used': ['braintree_transaction_log', 'subscription'],
#    'columns_used': [['subscription', 'purchaser_id'],
#     ['subscription', 'price'],
#     ['problem', 'asker_id'],
#     ['braintree_transaction_log', 'asker_id'],
#     ['subscription', 'expiration']],
#    'target': 0.0},
#   {'sql_query': "select max ( subscription.price ) , subscription.purchaser_id from braintree_transaction_log join subscription on subscription.purchaser_id = braintree_transaction_log.asker_id where subscription.expiration = ' value ' group by subscription.purchaser_id",
#    'tables_used': ['braintree_transaction_log', 'subscription'],
#    'columns_used': [['subscription', 'purchaser_id'],
#     ['braintree_transaction_log', 'asker_id'],
#     ['subscription', 'price'],
#     ['subscription', 'expiration']],
#    'target': 0.0},
#   {'sql_query': "select max ( subscription.price ) , braintree_transaction_log.asker_id from subscription join braintree_transaction_log on braintree_transaction_log.asker_id = subscription.purchaser_id where subscription.expiration = ' value ' group by subscription.purchaser_id",
#    'tables_used': ['braintree_transaction_log', 'subscription'],
#    'columns_used': [['subscription', 'purchaser_id'],
#     ['braintree_transaction_log', 'asker_id'],
#     ['subscription', 'price'],
#     ['subscription', 'expiration']],
#    'target': 0.0},
#   {'sql_query': "select max ( subscription.price ) , subscription.purchaser_id from asker join subscription on asker.id = subscription.purchaser_id where subscription.expiration = ' value ' group by asker.id",
#    'tables_used': ['subscription', 'asker'],
#    'columns_used': [['subscription', 'purchaser_id'],
#     ['subscription', 'price'],
#     ['subscription', 'expiration'],
#     ['asker', 'id']],
#    'target': 0.0},
#   {'sql_query': "select max ( braintree_transaction_log.price ) , visitor.first_asker_id from braintree_transaction_log join subscription on braintree_transaction_log.asker_id = subscription.purchaser_id where subscription.expiration = ' value ' group by braintree_transaction_log.asker_id",
#    'tables_used': ['braintree_transaction_log', 'subscription'],
#    'columns_used': [['subscription', 'purchaser_id'],
#     ['braintree_transaction_log', 'price'],
#     ['braintree_transaction_log', 'asker_id'],
#     ['subscription', 'expiration'],
#     ['visitor', 'first_asker_id']],
#    'target': 1.0},
#   {'sql_query': "select max ( braintree_transaction_log.price ) , visitor.first_asker_id from braintree_transaction_log join subscription on subscription.purchaser_id = braintree_transaction_log.asker_id where subscription.expiration = ' value ' group by braintree_transaction_log.asker_id",
#    'tables_used': ['braintree_transaction_log', 'subscription'],
#    'columns_used': [['subscription', 'purchaser_id'],
#     ['braintree_transaction_log', 'price'],
#     ['braintree_transaction_log', 'asker_id'],
#     ['subscription', 'expiration'],
#     ['visitor', 'first_asker_id']],
#    'target': 1.0},
#   {'sql_query': "select max ( subscription.price ) , visitor.first_asker_id from visitor join braintree_transaction_log on visitor.first_asker_id = braintree_transaction_log.asker_id join subscription on subscription.purchaser_id = visitor.first_asker_id where subscription.expiration = ' value ' group by visitor.first_asker_id",
#    'tables_used': ['braintree_transaction_log', 'visitor', 'subscription'],
#    'columns_used': [['subscription', 'purchaser_id'],
#     ['subscription', 'price'],
#     ['braintree_transaction_log', 'asker_id'],
#     ['subscription', 'expiration'],
#     ['visitor', 'first_asker_id']],
#    'target': 0.0},
#   {'sql_query': "select max ( subscription.price ) , problem.asker_id from braintree_transaction_log join subscription on subscription.purchaser_id = braintree_transaction_log.asker_id join problem on braintree_transaction_log.asker_id = problem.asker_id where subscription.expiration = ' value ' group by braintree_transaction_log.asker_id",
#    'tables_used': ['braintree_transaction_log', 'subscription', 'problem'],
#    'columns_used': [['subscription', 'purchaser_id'],
#     ['subscription', 'price'],
#     ['problem', 'asker_id'],
#     ['braintree_transaction_log', 'asker_id'],
#     ['subscription', 'expiration']],
#    'target': 0.0},
#   {'sql_query': "select max ( subscription.price ) , problem.asker_id from braintree_transaction_log join subscription on subscription.purchaser_id = braintree_transaction_log.asker_id join problem on braintree_transaction_log.asker_id = problem.asker_id where subscription.expiration = ' value ' group by problem.asker_id",
#    'tables_used': ['braintree_transaction_log', 'subscription', 'problem'],
#    'columns_used': [['subscription', 'purchaser_id'],
#     ['subscription', 'price'],
#     ['problem', 'asker_id'],
#     ['braintree_transaction_log', 'asker_id'],
#     ['subscription', 'expiration']],
#    'target': 0.0}]}

# %%
count = 0
count_acc = 0
count_too_many_targets = 0
for idx, item in enumerate(val_items):
    instances = item['instances']
    if len(list(filter(lambda instance: instance['target'] > 0.5, instances))) == 0:
        count +=1
    if len(list(filter(lambda instance: instance['target'] > 0.5, instances))) > 1:
        count_too_many_targets += 1
    if instances[0]['target'] > 0.5:
        count_acc += 1
len(val_items), count, count_acc, count_too_many_targets
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-d198bf8ad6ca> in <module>
#       4 for idx, item in enumerate(val_items):
#       5     instances = item['instances']
# ----> 6     if len(list(filter(lambda instance: instance['target'] > 0.5, instances))) == 0:
#       7         count +=1
#       8     if len(list(filter(lambda instance: instance['target'] > 0.5, instances))) > 1:
#
# <ipython-input-12-d198bf8ad6ca> in <lambda>(instance)
#       4 for idx, item in enumerate(val_items):
#       5     instances = item['instances']
# ----> 6     if len(list(filter(lambda instance: instance['target'] > 0.5, instances))) == 0:
#       7         count +=1
#       8     if len(list(filter(lambda instance: instance['target'] > 0.5, instances))) > 1:
#
# KeyError: 'target'

# %%
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')

# %%
# Creates the input for BERT:
# Returns the tokenized bert input [CLS] <tokenized nlu> [SEP] col1 [SEP] col2 ...[SEP]
# and the start and end locations in the tokenized input for each of the columns
def create_tokenized_input(tokenizer, nlu, sql):
    tokens = []
    tokens += tokenizer.tokenize('[CLS]')
    tokens += tokenizer.tokenize(nlu)
    tokens += tokenizer.tokenize('[SEP]')
    tokens += tokenizer.tokenize(sql)
    tokens += tokenizer.tokenize('[SEP]')
    column_locations = []
    return tokens, tokenizer.convert_tokens_to_ids(tokens)

# %%
# {'utterance': 'How many singers do we have?',
# 'instances': [{'sql_query': 'select count ( * ) from singer',
#   'tables_used': ['singer'],
#   'columns_used': [],
#   'target': 1.0},
def preprocess_data(tokenizer, data, train=True):
    new_data = []
    for sample in tqdm(data):
        new_sample = {}
        new_sample['utterance'] = sample['utterance']
        correct_instances = []
        incorrect_instances = []
        instances = []
        try:
            sample['instances'][0]['target']
        except:
            continue
        for i, instance in enumerate(sample['instances']):
            #try: 
            #    instance['target']
            #except: 
            #    continue
                
            instance = instance.copy()
            tokens, encoded_tokens = create_tokenized_input(tokenizer, 
                                                            sample['utterance'], 
                                                            instance['sql_query'])
            instance['tokens'] = tokens
            instance['encoded_tokens'] = encoded_tokens
            instance['rank'] = i
            if len(encoded_tokens) <= 512:
                if instance['target'] > 0.5:
                    correct_instances.append(instance)
                else:
                    incorrect_instances.append(instance)
            else:
                print(f'Warning: too many tokens {instance}')
            instances.append(instance)
            
            # TODO(rohan): Handle case where encoded tokens > 512, right now it's being added to instances
        def make_key(instance): return instance['sql_query']
        unique_instances = {}
        uniq_correct_instances = []
        for instance in correct_instances:  # Need to make sure that earlier rank ones are retained
            key = make_key(instance)
            if key not in unique_instances:
                unique_instances[key] = instance
                uniq_correct_instances.append(instance)
        uniq_incorrect_instances = []
        # We don't reset unique_instances because we also want to exclude incorrect instances
        # if there is an equivalent instance in correct_instances
        for instance in incorrect_instances:
            key = make_key(instance)
            if key not in unique_instances:
                unique_instances[key] = instance
                uniq_incorrect_instances.append(instance)
        sample['correct_instances'] = uniq_correct_instances
        sample['incorrect_instances'] = uniq_incorrect_instances
        sample['instances'] = instances

        # TODO(rohan): Not sure if I want this?
        # Commenting out because I it changes the top 10 queries (eg. if there was a correct and incorrect with the same columns)
        # sample['instances'] = sorted(sample['correct_instances'] + sample['incorrect_instances'], key=lambda ins: ins['rank'])
        if train and len(uniq_correct_instances) == 0:  # For training, there must be at least one correct instance
            pass
        else:
            new_data.append(sample)
    return new_data

# %%
train_data_processed = preprocess_data(tokenizer, train_items, train=True)
val_data_processed = preprocess_data(tokenizer, val_items, train=False)
#val_data_normaleval_preprocessed = preprocess_data(tokenizer, val_normaleval_items, train=False)
# Out:
# HBox(children=(IntProgress(value=0, max=3779), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=944), HTML(value='')))

# %%
len(train_data_processed)
# Out:
# 2896

# %%
val_data_processed[0]
# Out:
# {'utterance': 'Give me the list of askers who made a payment above 51, and get the latest among all of these transactions for each asker. Sort the list by purchase time in descending order.',
#  'instances': [{'sql_query': "select max ( braintree_transaction_log.created ) , braintree_transaction_log.asker_id from braintree_transaction_log where braintree_transaction_log.price > ' value ' group by braintree_transaction_log.asker_id order by braintree_transaction_log.created desc",
#    'tables_used': ['braintree_transaction_log'],
#    'columns_used': [['braintree_transaction_log', 'price'],
#     ['braintree_transaction_log', 'asker_id'],
#     ['braintree_transaction_log', 'created']],
#    'target': 1.0,
#    'tokens': ['[CLS]',
#     'give',
#     'me',
#     'the',
#     'list',
#     'of',
#     'ask',
#     '##ers',
#     'who',
#     'made',
#     'a',
#     'payment',
#     'above',
#     '51',
#     ',',
#     'and',
#     'get',
#     'the',
#     'latest',
#     'among',
#     'all',
#     'of',
#     'these',
#     'transactions',
#     'for',
#     'each',
#     'ask',
#     '##er',
#     '.',
#     'sort',
#     'the',
#     'list',
#     'by',
#     'purchase',
#     'time',
#     'in',
#     'descending',
#     'order',
#     '.',
#     '[SEP]',
#     'select',
#     'max',
#     '(',
#     'brain',
#     '##tree',
#     '_',
#     'transaction',
#     '_',
#     'log',
#     '.',
#     'created',
#     ')',
#     ',',
#     'brain',
#     '##tree',
#     '_',
#     'transaction',
#     '_',
#     'log',
#     '.',
#     'ask',
#     '##er',
#     '_',
#     'id',
#     'from',
#     'brain',
#     '##tree',
#     '_',
#     'transaction',
#     '_',
#     'log',
#     'where',
#     'brain',
#     '##tree',
#     '_',
#     'transaction',
#     '_',
#     'log',
#     '.',
#     'price',
#     '>',
#     "'",
#     'value',
#     "'",
#     'group',
#     'by',
#     'brain',
#     '##tree',
#     '_',
#     'transaction',
#     '_',
#     'log',
#     '.',
#     'ask',
#     '##er',
#     '_',
#     'id',
#     'order',
#     'by',
#     'brain',
#     '##tree',
#     '_',
#     'transaction',
#     '_',
#     'log',
#     '.',
#     'created',
#     'des',
#     '##c',
#     '[SEP]'],
#    'encoded_tokens': [101,
#     2507,
#     2033,
#     1996,
#     2862,
#     1997,
#     3198,
#     2545,
#     2040,
#     2081,
#     1037,
#     7909,
#     2682,
#     4868,
#     1010,
#     1998,
#     2131,
#     1996,
#     6745,
#     2426,
#     2035,
#     1997,
#     2122,
#     11817,
#     2005,
#     2169,
#     3198,
#     2121,
#     1012,
#     4066,
#     1996,
#     2862,
#     2011,
#     5309,
#     2051,
#     1999,
#     15127,
#     2344,
#     1012,
#     102,
#     7276,
#     4098,
#     1006,
#     4167,
#     13334,
#     1035,
#     12598,
#     1035,
#     8833,
#     1012,
#     2580,
#     1007,
#     1010,
#     4167,
#     13334,
#     1035,
#     12598,
#     1035,
#     8833,
#     1012,
#     3198,
#     2121,
#     1035,
#     8909,
#     2013,
#     4167,
#     13334,
#     1035,
#     12598,
#     1035,
#     8833,
#     2073,
#     4167,
#     13334,
#     1035,
#     12598,
#     1035,
#     8833,
#     1012,
#     3976,
#     1028,
#     1005,
#     3643,
#     1005,
#     2177,
#     2011,
#     4167,
#     13334,
#     1035,
#     12598,
#     1035,
#     8833,
#     1012,
#     3198,
#     2121,
#     1035,
#     8909,
#     2344,
#     2011,
#     4167,
#     13334,
#     1035,
#     12598,
#     1035,
#     8833,
#     1012,
#     2580,
#     4078,
#     2278,
#     102],
#    'rank': 0},
#   {'sql_query': "select max ( braintree_transaction_log.created ) , braintree_transaction_log.asker_id from braintree_transaction_log where braintree_transaction_log.price > ' value ' group by braintree_transaction_log.asker_id order by max ( braintree_transaction_log.created ) desc",
#    'tables_used': ['braintree_transaction_log'],
#    'columns_used': [['braintree_transaction_log', 'price'],
#     ['braintree_transaction_log', 'asker_id'],
#     ['braintree_transaction_log', 'created']],
#    'target': 0.0,
#    'tokens': ['[CLS]',
#     'give',
#     'me',
#     'the',
#     'list',
#     'of',
#     'ask',
#     '##ers',
#     'who',
#     'made',
#     'a',
#     'payment',
#     'above',
#     '51',
#     ',',
#     'and',
#     'get',
#     'the',
#     'latest',
#     'among',
#     'all',
#     'of',
#     'these',
#     'transactions',
#     'for',
#     'each',
#     'ask',
#     '##er',
#     '.',
#     'sort',
#     'the',
#     'list',
#     'by',
#     'purchase',
#     'time',
#     'in',
#     'descending',
#     'order',
#     '.',
#     '[SEP]',
#     'select',
#     'max',
#     '(',
#     'brain',
#     '##tree',
#     '_',
#     'transaction',
#     '_',
#     'log',
#     '.',
#     'created',
#     ')',
#     ',',
#     'brain',
#     '##tree',
#     '_',
#     'transaction',
#     '_',
#     'log',
#     '.',
#     'ask',
#     '##er',
#     '_',
#     'id',
#     'from',
#     'brain',
#     '##tree',
#     '_',
#     'transaction',
#     '_',
#     'log',
#     'where',
#     'brain',
#     '##tree',
#     '_',
#     'transaction',
#     '_',
#     'log',
#     '.',
#     'price',
#     '>',
#     "'",
#     'value',
#     "'",
#     'group',
#     'by',
#     'brain',
#     '##tree',
#     '_',
#     'transaction',
#     '_',
#     'log',
#     '.',
#     'ask',
#     '##er',
#     '_',
#     'id',
#     'order',
#     'by',
#     'max',
#     '(',
#     'brain',
#     '##tree',
#     '_',
#     'transaction',
#     '_',
#     'log',
#     '.',
#     'created',
#     ')',
#     'des',
#     '##c',
#     '[SEP]'],
#    'encoded_tokens': [101,
#     2507,
#     2033,
#     1996,
#     2862,
#     1997,
#     3198,
#     2545,
#     2040,
#     2081,
#     1037,
#     7909,
#     2682,
#     4868,
#     1010,
#     1998,
#     2131,
#     1996,
#     6745,
#     2426,
#     2035,
#     1997,
#     2122,
#     11817,
#     2005,
#     2169,
#     3198,
#     2121,
#     1012,
#     4066,
#     1996,
#     2862,
#     2011,
#     5309,
#     2051,
#     1999,
#     15127,
#     2344,
#     1012,
#     102,
#     7276,
#     4098,
#     1006,
#     4167,
#     13334,
#     1035,
#     12598,
#     1035,
#     8833,
#     1012,
#     2580,
#     1007,
#     1010,
#     4167,
#     13334,
#     1035,
#     12598,
#     1035,
#     8833,
#     1012,
#     3198,
#     2121,
#     1035,
#     8909,
#     2013,
#     4167,
#     13334,
#     1035,
#     12598,
#     1035,
#     8833,
#     2073,
#     4167,
#     13334,
#     1035,
#     12598,
#     1035,
#     8833,
#     1012,
#     3976,
#     1028,
#     1005,
#     3643,
#     1005,
#     2177,
#     2011,
#     4167,
#     13334,
#     1035,
#     12598,
#     1035,
#     8833,
#     1012,
#     3198,
#     2121,
#     1035,
#     8909,
#     2344,
#     2011,
#     4098,
#     1006,
#     4167,
#     13334,
#     1035,
#     12598,
#     1035,
#     8833,
#     1012,
#     2580,
#     1007,
#     4078,
#     2278,
#     102],
#    'rank': 1},
#   {'sql_query': "select max ( braintree_transaction_log.price ) , braintree_transaction_log.asker_id from braintree_transaction_log where braintree_transaction_log.price > ' value ' group by braintree_transaction_log.asker_id order by braintree_transaction_log.created desc",
#    'tables_used': ['braintree_transaction_log'],
#    'columns_used': [['braintree_transaction_log', 'price'],
#     ['braintree_transaction_log', 'asker_id'],
#     ['braintree_transaction_log', 'created']],
#    'target': 0.0,
#    'tokens': ['[CLS]',
#     'give',
#     'me',
#     'the',
#     'list',
#     'of',
#     'ask',
#     '##ers',
#     'who',
#     'made',
#     'a',
#     'payment',
#     'above',
#     '51',
#     ',',
#     'and',
#     'get',
#     'the',
#     'latest',
#     'among',
#     'all',
#     'of',
#     'these',
#     'transactions',
#     'for',
#     'each',
#     'ask',
#     '##er',
#     '.',
#     'sort',
#     'the',
#     'list',
#     'by',
#     'purchase',
#     'time',
#     'in',
#     'descending',
#     'order',
#     '.',
#     '[SEP]',
#     'select',
#     'max',
#     '(',
#     'brain',
#     '##tree',
#     '_',
#     'transaction',
#     '_',
#     'log',
#     '.',
#     'price',
#     ')',
#     ',',
#     'brain',
#     '##tree',
#     '_',
#     'transaction',
#     '_',
#     'log',
#     '.',
#     'ask',
#     '##er',
#     '_',
#     'id',
#     'from',
#     'brain',
#     '##tree',
#     '_',
#     'transaction',
#     '_',
#     'log',
#     'where',
#     'brain',
#     '##tree',
#     '_',
#     'transaction',
#     '_',
#     'log',
#     '.',
#     'price',
#     '>',
#     "'",
#     'value',
#     "'",
#     'group',
#     'by',
#     'brain',
#     '##tree',
#     '_',
#     'transaction',
#     '_',
#     'log',
#     '.',
#     'ask',
#     '##er',
#     '_',
#     'id',
#     'order',
#     'by',
#     'brain',
#     '##tree',
#     '_',
#     'transaction',
#     '_',
#     'log',
#     '.',
#     'created',
#     'des',
#     '##c',
#     '[SEP]'],
#    'encoded_tokens': [101,
#     2507,
#     2033,
#     1996,
#     2862,
#     1997,
#     3198,
#     2545,
#     2040,
#     2081,
#     1037,
#     7909,
#     2682,
#     4868,
#     1010,
#     1998,
#     2131,
#     1996,
#     6745,
#     2426,
#     2035,
#     1997,
#     2122,
#     11817,
#     2005,
#     2169,
#     3198,
#     2121,
#     1012,
#     4066,
#     1996,
#     2862,
#     2011,
#     5309,
#     2051,
#     1999,
#     15127,
#     2344,
#     1012,
#     102,
#     7276,
#     4098,
#     1006,
#     4167,
#     13334,
#     1035,
#     12598,
#     1035,
#     8833,
#     1012,
#     3976,
#     1007,
#     1010,
#     4167,
#     13334,
#     1035,
#     12598,
#     1035,
#     8833,
#     1012,
#     3198,
#     2121,
#     1035,
#     8909,
#     2013,
#     4167,
#     13334,
#     1035,
#     12598,
#     1035,
#     8833,
#     2073,
#     4167,
#     13334,
#     1035,
#     12598,
#     1035,
#     8833,
#     1012,
#     3976,
#     1028,
#     1005,
#     3643,
#     1005,
#     2177,
#     2011,
#     4167,
#     13334,
#     1035,
#     12598,
#     1035,
#     8833,
#     1012,
#     3198,
#     2121,
#     1035,
#     8909,
#     2344,
#     2011,
#     4167,
#     13334,
#     1035,
#     12598,
#     1035,
#     8833,
#     1012,
#     2580,
#     4078,
#     2278,
#     102],
#    'rank': 2},
#   {'sql_query': "select max ( braintree_transaction_log.price ) , braintree_transaction_log.asker_id from braintree_transaction_log where braintree_transaction_log.price > ' value ' group by braintree_transaction_log.asker_id order by max ( braintree_transaction_log.created ) desc",
#    'tables_used': ['braintree_transaction_log'],
#    'columns_used': [['braintree_transaction_log', 'price'],
#     ['braintree_transaction_log', 'asker_id'],
#     ['braintree_transaction_log', 'created']],
#    'target': 0.0,
#    'tokens': ['[CLS]',
#     'give',
#     'me',
#     'the',
#     'list',
#     'of',
#     'ask',
#     '##ers',
#     'who',
#     'made',
#     'a',
#     'payment',
#     'above',
#     '51',
#     ',',
#     'and',
#     'get',
#     'the',
#     'latest',
#     'among',
#     'all',
#     'of',
#     'these',
#     'transactions',
#     'for',
#     'each',
#     'ask',
#     '##er',
#     '.',
#     'sort',
#     'the',
#     'list',
#     'by',
#     'purchase',
#     'time',
#     'in',
#     'descending',
#     'order',
#     '.',
#     '[SEP]',
#     'select',
#     'max',
#     '(',
#     'brain',
#     '##tree',
#     '_',
#     'transaction',
#     '_',
#     'log',
#     '.',
#     'price',
#     ')',
#     ',',
#     'brain',
#     '##tree',
#     '_',
#     'transaction',
#     '_',
#     'log',
#     '.',
#     'ask',
#     '##er',
#     '_',
#     'id',
#     'from',
#     'brain',
#     '##tree',
#     '_',
#     'transaction',
#     '_',
#     'log',
#     'where',
#     'brain',
#     '##tree',
#     '_',
#     'transaction',
#     '_',
#     'log',
#     '.',
#     'price',
#     '>',
#     "'",
#     'value',
#     "'",
#     'group',
#     'by',
#     'brain',
#     '##tree',
#     '_',
#     'transaction',
#     '_',
#     'log',
#     '.',
#     'ask',
#     '##er',
#     '_',
#     'id',
#     'order',
#     'by',
#     'max',
#     '(',
#     'brain',
#     '##tree',
#     '_',
#     'transaction',
#     '_',
#     'log',
#     '.',
#     'created',
#     ')',
#     'des',
#     '##c',
#     '[SEP]'],
#    'encoded_tokens': [101,
#     2507,
#     2033,
#     1996,
#     2862,
#     1997,
#     3198,
#     2545,
#     2040,
#     2081,
#     1037,
#     7909,
#     2682,
#     4868,
#     1010,
#     1998,
#     2131,
#     1996,
#     6745,
#     2426,
#     2035,
#     1997,
#     2122,
#     11817,
#     2005,
#     2169,
#     3198,
#     2121,
#     1012,
#     4066,
#     1996,
#     2862,
#     2011,
#     5309,
#     2051,
#     1999,
#     15127,
#     2344,
#     1012,
#     102,
#     7276,
#     4098,
#     1006,
#     4167,
#     13334,
#     1035,
#     12598,
#     1035,
#     8833,
#     1012,
#     3976,
#     1007,
#     1010,
#     4167,
#     13334,
#     1035,
#     12598,
#     1035,
#     8833,
#     1012,
#     3198,
#     2121,
#     1035,
#     8909,
#     2013,
#     4167,
#     13334,
#     1035,
#     12598,
#     1035,
#     8833,
#     2073,
#     4167,
#     13334,
#     1035,
#     12598,
#     1035,
#     8833,
#     1012,
#     3976,
#     1028,
#     1005,
#     3643,
#     1005,
#     2177,
#     2011,
#     4167,
#     13334,
#     1035,
#     12598,
#     1035,
#     8833,
#     1012,
#     3198,
#     2121,
#     1035,
#     8909,
#     2344,
#     2011,
#     4098,
#     1006,
#     4167,
#     13334,
#     1035,
#     12598,
#     1035,
#     8833,
#     1012,
#     2580,
#     1007,
#     4078,
#     2278,
#     102],
#    'rank': 3},
#   {'sql_query': "select max ( braintree_transaction_log.created ) , problem.asker_id from problem join braintree_transaction_log on problem.asker_id = braintree_transaction_log.asker_id where braintree_transaction_log.price > ' value ' group by problem.asker_id order by braintree_transaction_log.created desc",
#    'tables_used': ['braintree_transaction_log', 'problem'],
#    'columns_used': [['braintree_transaction_log', 'price'],
#     ['braintree_transaction_log', 'asker_id'],
#     ['problem', 'asker_id'],
#     ['braintree_transaction_log', 'created']],
#    'target': 0.0,
#    'tokens': ['[CLS]',
#     'give',
#     'me',
#     'the',
#     'list',
#     'of',
#     'ask',
#     '##ers',
#     'who',
#     'made',
#     'a',
#     'payment',
#     'above',
#     '51',
#     ',',
#     'and',
#     'get',
#     'the',
#     'latest',
#     'among',
#     'all',
#     'of',
#     'these',
#     'transactions',
#     'for',
#     'each',
#     'ask',
#     '##er',
#     '.',
#     'sort',
#     'the',
#     'list',
#     'by',
#     'purchase',
#     'time',
#     'in',
#     'descending',
#     'order',
#     '.',
#     '[SEP]',
#     'select',
#     'max',
#     '(',
#     'brain',
#     '##tree',
#     '_',
#     'transaction',
#     '_',
#     'log',
#     '.',
#     'created',
#     ')',
#     ',',
#     'problem',
#     '.',
#     'ask',
#     '##er',
#     '_',
#     'id',
#     'from',
#     'problem',
#     'join',
#     'brain',
#     '##tree',
#     '_',
#     'transaction',
#     '_',
#     'log',
#     'on',
#     'problem',
#     '.',
#     'ask',
#     '##er',
#     '_',
#     'id',
#     '=',
#     'brain',
#     '##tree',
#     '_',
#     'transaction',
#     '_',
#     'log',
#     '.',
#     'ask',
#     '##er',
#     '_',
#     'id',
#     'where',
#     'brain',
#     '##tree',
#     '_',
#     'transaction',
#     '_',
#     'log',
#     '.',
#     'price',
#     '>',
#     "'",
#     'value',
#     "'",
#     'group',
#     'by',
#     'problem',
#     '.',
#     'ask',
#     '##er',
#     '_',
#     'id',
#     'order',
#     'by',
#     'brain',
#     '##tree',
#     '_',
#     'transaction',
#     '_',
#     'log',
#     '.',
#     'created',
#     'des',
#     '##c',
#     '[SEP]'],
#    'encoded_tokens': [101,
#     2507,
#     2033,
#     1996,
#     2862,
#     1997,
#     3198,
#     2545,
#     2040,
#     2081,
#     1037,
#     7909,
#     2682,
#     4868,
#     1010,
#     1998,
#     2131,
#     1996,
#     6745,
#     2426,
#     2035,
#     1997,
#     2122,
#     11817,
#     2005,
#     2169,
#     3198,
#     2121,
#     1012,
#     4066,
#     1996,
#     2862,
#     2011,
#     5309,
#     2051,
#     1999,
#     15127,
#     2344,
#     1012,
#     102,
#     7276,
#     4098,
#     1006,
#     4167,
#     13334,
#     1035,
#     12598,
#     1035,
#     8833,
#     1012,
#     2580,
#     1007,
#     1010,
#     3291,
#     1012,
#     3198,
#     2121,
#     1035,
#     8909,
#     2013,
#     3291,
#     3693,
#     4167,
#     13334,
#     1035,
#     12598,
#     1035,
#     8833,
#     2006,
#     3291,
#     1012,
#     3198,
#     2121,
#     1035,
#     8909,
#     1027,
#     4167,
#     13334,
#     1035,
#     12598,
#     1035,
#     8833,
#     1012,
#     3198,
#     2121,
#     1035,
#     8909,
#     2073,
#     4167,
#     13334,
#     1035,
#     12598,
#     1035,
#     8833,
#     1012,
#     3976,
#     1028,
#     1005,
#     3643,
#     1005,
#     2177,
#     2011,
#     3291,
#     1012,
#     3198,
#     2121,
#     1035,
#     8909,
#     2344,
#     2011,
#     4167,
#     13334,
#     1035,
#     12598,
#     1035,
#     8833,
#     1012,
#     2580,
#     4078,
#     2278,
#     102],
#    'rank': 4},
#   {'sql_query': "select max ( braintree_transaction_log.created ) , problem.asker_id from braintree_transaction_log join problem on problem.asker_id = braintree_transaction_log.asker_id where braintree_transaction_log.price > ' value ' group by problem.asker_id order by braintree_transaction_log.created desc",
#    'tables_used': ['braintree_transaction_log', 'problem'],
#    'columns_used': [['braintree_transaction_log', 'price'],
#     ['braintree_transaction_log', 'asker_id'],
#     ['problem', 'asker_id'],
#     ['braintree_transaction_log', 'created']],
#    'target': 0.0,
#    'tokens': ['[CLS]',
#     'give',
#     'me',
#     'the',
#     'list',
#     'of',
#     'ask',
#     '##ers',
#     'who',
#     'made',
#     'a',
#     'payment',
#     'above',
#     '51',
#     ',',
#     'and',
#     'get',
#     'the',
#     'latest',
#     'among',
#     'all',
#     'of',
#     'these',
#     'transactions',
#     'for',
#     'each',
#     'ask',
#     '##er',
#     '.',
#     'sort',
#     'the',
#     'list',
#     'by',
#     'purchase',
#     'time',
#     'in',
#     'descending',
#     'order',
#     '.',
#     '[SEP]',
#     'select',
#     'max',
#     '(',
#     'brain',
#     '##tree',
#     '_',
#     'transaction',
#     '_',
#     'log',
#     '.',
#     'created',
#     ')',
#     ',',
#     'problem',
#     '.',
#     'ask',
#     '##er',
#     '_',
#     'id',
#     'from',
#     'brain',
#     '##tree',
#     '_',
#     'transaction',
#     '_',
#     'log',
#     'join',
#     'problem',
#     'on',
#     'problem',
#     '.',
#     'ask',
#     '##er',
#     '_',
#     'id',
#     '=',
#     'brain',
#     '##tree',
#     '_',
#     'transaction',
#     '_',
#     'log',
#     '.',
#     'ask',
#     '##er',
#     '_',
#     'id',
#     'where',
#     'brain',
#     '##tree',
#     '_',
#     'transaction',
#     '_',
#     'log',
#     '.',
#     'price',
#     '>',
#     "'",
#     'value',
#     "'",
#     'group',
#     'by',
#     'problem',
#     '.',
#     'ask',
#     '##er',
#     '_',
#     'id',
#     'order',
#     'by',
#     'brain',
#     '##tree',
#     '_',
#     'transaction',
#     '_',
#     'log',
#     '.',
#     'created',
#     'des',
#     '##c',
#     '[SEP]'],
#    'encoded_tokens': [101,
#     2507,
#     2033,
#     1996,
#     2862,
#     1997,
#     3198,
#     2545,
#     2040,
#     2081,
#     1037,
#     7909,
#     2682,
#     4868,
#     1010,
#     1998,
#     2131,
#     1996,
#     6745,
#     2426,
#     2035,
#     1997,
#     2122,
#     11817,
#     2005,
#     2169,
#     3198,
#     2121,
#     1012,
#     4066,
#     1996,
#     2862,
#     2011,
#     5309,
#     2051,
#     1999,
#     15127,
#     2344,
#     1012,
#     102,
#     7276,
#     4098,
#     1006,
#     4167,
#     13334,
#     1035,
#     12598,
#     1035,
#     8833,
#     1012,
#     2580,
#     1007,
#     1010,
#     3291,
#     1012,
#     3198,
#     2121,
#     1035,
#     8909,
#     2013,
#     4167,
#     13334,
#     1035,
#     12598,
#     1035,
#     8833,
#     3693,
#     3291,
#     2006,
#     3291,
#     1012,
#     3198,
#     2121,
#     1035,
#     8909,
#     1027,
#     4167,
#     13334,
#     1035,
#     12598,
#     1035,
#     8833,
#     1012,
#     3198,
#     2121,
#     1035,
#     8909,
#     2073,
#     4167,
#     13334,
#     1035,
#     12598,
#     1035,
#     8833,
#     1012,
#     3976,
#     1028,
#     1005,
#     3643,
#     1005,
#     2177,
#     2011,
#     3291,
#     1012,
#     3198,
#     2121,
#     1035,
#     8909,
#     2344,
#     2011,
#     4167,
#     13334,
#     1035,
#     12598,
#     1035,
#     8833,
#     1012,
#     2580,
#     4078,
#     2278,
#     102],
#    'rank': 5},
#   {'sql_query': "select max ( braintree_transaction_log.created ) , problem.asker_id from problem join braintree_transaction_log on problem.asker_id = braintree_transaction_log.asker_id where braintree_transaction_log.price > ' value ' group by problem.asker_id order by max ( braintree_transaction_log.created ) desc",
#    'tables_used': ['braintree_transaction_log', 'problem'],
#    'columns_used': [['braintree_transaction_log', 'price'],
#     ['braintree_transaction_log', 'asker_id'],
#     ['problem', 'asker_id'],
#     ['braintree_transaction_log', 'created']],
#    'target': 0.0,
#    'tokens': ['[CLS]',
#     'give',
#     'me',
#     'the',
#     'list',
#     'of',
#     'ask',
#     '##ers',
#     'who',
#     'made',
#     'a',
#     'payment',
#     'above',
#     '51',
#     ',',
#     'and',
#     'get',
#     'the',
#     'latest',
#     'among',
#     'all',
#     'of',
#     'these',
#     'transactions',
#     'for',
#     'each',
#     'ask',
#     '##er',
#     '.',
#     'sort',
#     'the',
#     'list',
#     'by',
#     'purchase',
#     'time',
#     'in',
#     'descending',
#     'order',
#     '.',
#     '[SEP]',
#     'select',
#     'max',
#     '(',
#     'brain',
#     '##tree',
#     '_',
#     'transaction',
#     '_',
#     'log',
#     '.',
#     'created',
#     ')',
#     ',',
#     'problem',
#     '.',
#     'ask',
#     '##er',
#     '_',
#     'id',
#     'from',
#     'problem',
#     'join',
#     'brain',
#     '##tree',
#     '_',
#     'transaction',
#     '_',
#     'log',
#     'on',
#     'problem',
#     '.',
#     'ask',
#     '##er',
#     '_',
#     'id',
#     '=',
#     'brain',
#     '##tree',
#     '_',
#     'transaction',
#     '_',
#     'log',
#     '.',
#     'ask',
#     '##er',
#     '_',
#     'id',
#     'where',
#     'brain',
#     '##tree',
#     '_',
#     'transaction',
#     '_',
#     'log',
#     '.',
#     'price',
#     '>',
#     "'",
#     'value',
#     "'",
#     'group',
#     'by',
#     'problem',
#     '.',
#     'ask',
#     '##er',
#     '_',
#     'id',
#     'order',
#     'by',
#     'max',
#     '(',
#     'brain',
#     '##tree',
#     '_',
#     'transaction',
#     '_',
#     'log',
#     '.',
#     'created',
#     ')',
#     'des',
#     '##c',
#     '[SEP]'],
#    'encoded_tokens': [101,
#     2507,
#     2033,
#     1996,
#     2862,
#     1997,
#     3198,
#     2545,
#     2040,
#     2081,
#     1037,
#     7909,
#     2682,
#     4868,
#     1010,
#     1998,
#     2131,
#     1996,
#     6745,
#     2426,
#     2035,
#     1997,
#     2122,
#     11817,
#     2005,
#     2169,
#     3198,
#     2121,
#     1012,
#     4066,
#     1996,
#     2862,
#     2011,
#     5309,
#     2051,
#     1999,
#     15127,
#     2344,
#     1012,
#     102,
#     7276,
#     4098,
#     1006,
#     4167,
#     13334,
#     1035,
#     12598,
#     1035,
#     8833,
#     1012,
#     2580,
#     1007,
#     1010,
#     3291,
#     1012,
#     3198,
#     2121,
#     1035,
#     8909,
#     2013,
#     3291,
#     3693,
#     4167,
#     13334,
#     1035,
#     12598,
#     1035,
#     8833,
#     2006,
#     3291,
#     1012,
#     3198,
#     2121,
#     1035,
#     8909,
#     1027,
#     4167,
#     13334,
#     1035,
#     12598,
#     1035,
#     8833,
#     1012,
#     3198,
#     2121,
#     1035,
#     8909,
#     2073,
#     4167,
#     13334,
#     1035,
#     12598,
#     1035,
#     8833,
#     1012,
#     3976,
#     1028,
#     1005,
#     3643,
#     1005,
#     2177,
#     2011,
#     3291,
#     1012,
#     3198,
#     2121,
#     1035,
#     8909,
#     2344,
#     2011,
#     4098,
#     1006,
#     4167,
#     13334,
#     1035,
#     12598,
#     1035,
#     8833,
#     1012,
#     2580,
#     1007,
#     4078,
#     2278,
#     102],
#    'rank': 6},
#   {'sql_query': "select max ( braintree_transaction_log.created ) , problem.asker_id from braintree_transaction_log join problem on problem.asker_id = braintree_transaction_log.asker_id where braintree_transaction_log.price > ' value ' group by problem.asker_id order by max ( braintree_transaction_log.created ) desc",
#    'tables_used': ['braintree_transaction_log', 'problem'],
#    'columns_used': [['braintree_transaction_log', 'price'],
#     ['braintree_transaction_log', 'asker_id'],
#     ['problem', 'asker_id'],
#     ['braintree_transaction_log', 'created']],
#    'target': 0.0,
#    'tokens': ['[CLS]',
#     'give',
#     'me',
#     'the',
#     'list',
#     'of',
#     'ask',
#     '##ers',
#     'who',
#     'made',
#     'a',
#     'payment',
#     'above',
#     '51',
#     ',',
#     'and',
#     'get',
#     'the',
#     'latest',
#     'among',
#     'all',
#     'of',
#     'these',
#     'transactions',
#     'for',
#     'each',
#     'ask',
#     '##er',
#     '.',
#     'sort',
#     'the',
#     'list',
#     'by',
#     'purchase',
#     'time',
#     'in',
#     'descending',
#     'order',
#     '.',
#     '[SEP]',
#     'select',
#     'max',
#     '(',
#     'brain',
#     '##tree',
#     '_',
#     'transaction',
#     '_',
#     'log',
#     '.',
#     'created',
#     ')',
#     ',',
#     'problem',
#     '.',
#     'ask',
#     '##er',
#     '_',
#     'id',
#     'from',
#     'brain',
#     '##tree',
#     '_',
#     'transaction',
#     '_',
#     'log',
#     'join',
#     'problem',
#     'on',
#     'problem',
#     '.',
#     'ask',
#     '##er',
#     '_',
#     'id',
#     '=',
#     'brain',
#     '##tree',
#     '_',
#     'transaction',
#     '_',
#     'log',
#     '.',
#     'ask',
#     '##er',
#     '_',
#     'id',
#     'where',
#     'brain',
#     '##tree',
#     '_',
#     'transaction',
#     '_',
#     'log',
#     '.',
#     'price',
#     '>',
#     "'",
#     'value',
#     "'",
#     'group',
#     'by',
#     'problem',
#     '.',
#     'ask',
#     '##er',
#     '_',
#     'id',
#     'order',
#     'by',
#     'max',
#     '(',
#     'brain',
#     '##tree',
#     '_',
#     'transaction',
#     '_',
#     'log',
#     '.',
#     'created',
#     ')',
#     'des',
#     '##c',
#     '[SEP]'],
#    'encoded_tokens': [101,
#     2507,
#     2033,
#     1996,
#     2862,
#     1997,
#     3198,
#     2545,
#     2040,
#     2081,
#     1037,
#     7909,
#     2682,
#     4868,
#     1010,
#     1998,
#     2131,
#     1996,
#     6745,
#     2426,
#     2035,
#     1997,
#     2122,
#     11817,
#     2005,
#     2169,
#     3198,
#     2121,
#     1012,
#     4066,
#     1996,
#     2862,
#     2011,
#     5309,
#     2051,
#     1999,
#     15127,
#     2344,
#     1012,
#     102,
#     7276,
#     4098,
#     1006,
#     4167,
#     13334,
#     1035,
#     12598,
#     1035,
#     8833,
#     1012,
#     2580,
#     1007,
#     1010,
#     3291,
#     1012,
#     3198,
#     2121,
#     1035,
#     8909,
#     2013,
#     4167,
#     13334,
#     1035,
#     12598,
#     1035,
#     8833,
#     3693,
#     3291,
#     2006,
#     3291,
#     1012,
#     3198,
#     2121,
#     1035,
#     8909,
#     1027,
#     4167,
#     13334,
#     1035,
#     12598,
#     1035,
#     8833,
#     1012,
#     3198,
#     2121,
#     1035,
#     8909,
#     2073,
#     4167,
#     13334,
#     1035,
#     12598,
#     1035,
#     8833,
#     1012,
#     3976,
#     1028,
#     1005,
#     3643,
#     1005,
#     2177,
#     2011,
#     3291,
#     1012,
#     3198,
#     2121,
#     1035,
#     8909,
#     2344,
#     2011,
#     4098,
#     1006,
#     4167,
#     13334,
#     1035,
#     12598,
#     1035,
#     8833,
#     1012,
#     2580,
#     1007,
#     4078,
#     2278,
#     102],
#    'rank': 7},
#   {'sql_query': "select max ( braintree_transaction_log.created ) , problem.asker_id from braintree_transaction_log join problem on braintree_transaction_log.asker_id = problem.asker_id where braintree_transaction_log.price > ' value ' group by problem.asker_id order by braintree_transaction_log.created desc",
#    'tables_used': ['braintree_transaction_log', 'problem'],
#    'columns_used': [['braintree_transaction_log', 'price'],
#     ['braintree_transaction_log', 'asker_id'],
#     ['problem', 'asker_id'],
#     ['braintree_transaction_log', 'created']],
#    'target': 0.0,
#    'tokens': ['[CLS]',
#     'give',
#     'me',
#     'the',
#     'list',
#     'of',
#     'ask',
#     '##ers',
#     'who',
#     'made',
#     'a',
#     'payment',
#     'above',
#     '51',
#     ',',
#     'and',
#     'get',
#     'the',
#     'latest',
#     'among',
#     'all',
#     'of',
#     'these',
#     'transactions',
#     'for',
#     'each',
#     'ask',
#     '##er',
#     '.',
#     'sort',
#     'the',
#     'list',
#     'by',
#     'purchase',
#     'time',
#     'in',
#     'descending',
#     'order',
#     '.',
#     '[SEP]',
#     'select',
#     'max',
#     '(',
#     'brain',
#     '##tree',
#     '_',
#     'transaction',
#     '_',
#     'log',
#     '.',
#     'created',
#     ')',
#     ',',
#     'problem',
#     '.',
#     'ask',
#     '##er',
#     '_',
#     'id',
#     'from',
#     'brain',
#     '##tree',
#     '_',
#     'transaction',
#     '_',
#     'log',
#     'join',
#     'problem',
#     'on',
#     'brain',
#     '##tree',
#     '_',
#     'transaction',
#     '_',
#     'log',
#     '.',
#     'ask',
#     '##er',
#     '_',
#     'id',
#     '=',
#     'problem',
#     '.',
#     'ask',
#     '##er',
#     '_',
#     'id',
#     'where',
#     'brain',
#     '##tree',
#     '_',
#     'transaction',
#     '_',
#     'log',
#     '.',
#     'price',
#     '>',
#     "'",
#     'value',
#     "'",
#     'group',
#     'by',
#     'problem',
#     '.',
#     'ask',
#     '##er',
#     '_',
#     'id',
#     'order',
#     'by',
#     'brain',
#     '##tree',
#     '_',
#     'transaction',
#     '_',
#     'log',
#     '.',
#     'created',
#     'des',
#     '##c',
#     '[SEP]'],
#    'encoded_tokens': [101,
#     2507,
#     2033,
#     1996,
#     2862,
#     1997,
#     3198,
#     2545,
#     2040,
#     2081,
#     1037,
#     7909,
#     2682,
#     4868,
#     1010,
#     1998,
#     2131,
#     1996,
#     6745,
#     2426,
#     2035,
#     1997,
#     2122,
#     11817,
#     2005,
#     2169,
#     3198,
#     2121,
#     1012,
#     4066,
#     1996,
#     2862,
#     2011,
#     5309,
#     2051,
#     1999,
#     15127,
#     2344,
#     1012,
#     102,
#     7276,
#     4098,
#     1006,
#     4167,
#     13334,
#     1035,
#     12598,
#     1035,
#     8833,
#     1012,
#     2580,
#     1007,
#     1010,
#     3291,
#     1012,
#     3198,
#     2121,
#     1035,
#     8909,
#     2013,
#     4167,
#     13334,
#     1035,
#     12598,
#     1035,
#     8833,
#     3693,
#     3291,
#     2006,
#     4167,
#     13334,
#     1035,
#     12598,
#     1035,
#     8833,
#     1012,
#     3198,
#     2121,
#     1035,
#     8909,
#     1027,
#     3291,
#     1012,
#     3198,
#     2121,
#     1035,
#     8909,
#     2073,
#     4167,
#     13334,
#     1035,
#     12598,
#     1035,
#     8833,
#     1012,
#     3976,
#     1028,
#     1005,
#     3643,
#     1005,
#     2177,
#     2011,
#     3291,
#     1012,
#     3198,
#     2121,
#     1035,
#     8909,
#     2344,
#     2011,
#     4167,
#     13334,
#     1035,
#     12598,
#     1035,
#     8833,
#     1012,
#     2580,
#     4078,
#     2278,
#     102],
#    'rank': 8},
#   {'sql_query': "select max ( braintree_transaction_log.asker_id ) , problem.asker_id from braintree_transaction_log join problem on problem.asker_id = braintree_transaction_log.asker_id where braintree_transaction_log.price > ' value ' group by problem.asker_id order by braintree_transaction_log.created desc",
#    'tables_used': ['braintree_transaction_log', 'problem'],
#    'columns_used': [['braintree_transaction_log', 'price'],
#     ['braintree_transaction_log', 'asker_id'],
#     ['problem', 'asker_id'],
#     ['braintree_transaction_log', 'created']],
#    'target': 0.0,
#    'tokens': ['[CLS]',
#     'give',
#     'me',
#     'the',
#     'list',
#     'of',
#     'ask',
#     '##ers',
#     'who',
#     'made',
#     'a',
#     'payment',
#     'above',
#     '51',
#     ',',
#     'and',
#     'get',
#     'the',
#     'latest',
#     'among',
#     'all',
#     'of',
#     'these',
#     'transactions',
#     'for',
#     'each',
#     'ask',
#     '##er',
#     '.',
#     'sort',
#     'the',
#     'list',
#     'by',
#     'purchase',
#     'time',
#     'in',
#     'descending',
#     'order',
#     '.',
#     '[SEP]',
#     'select',
#     'max',
#     '(',
#     'brain',
#     '##tree',
#     '_',
#     'transaction',
#     '_',
#     'log',
#     '.',
#     'ask',
#     '##er',
#     '_',
#     'id',
#     ')',
#     ',',
#     'problem',
#     '.',
#     'ask',
#     '##er',
#     '_',
#     'id',
#     'from',
#     'brain',
#     '##tree',
#     '_',
#     'transaction',
#     '_',
#     'log',
#     'join',
#     'problem',
#     'on',
#     'problem',
#     '.',
#     'ask',
#     '##er',
#     '_',
#     'id',
#     '=',
#     'brain',
#     '##tree',
#     '_',
#     'transaction',
#     '_',
#     'log',
#     '.',
#     'ask',
#     '##er',
#     '_',
#     'id',
#     'where',
#     'brain',
#     '##tree',
#     '_',
#     'transaction',
#     '_',
#     'log',
#     '.',
#     'price',
#     '>',
#     "'",
#     'value',
#     "'",
#     'group',
#     'by',
#     'problem',
#     '.',
#     'ask',
#     '##er',
#     '_',
#     'id',
#     'order',
#     'by',
#     'brain',
#     '##tree',
#     '_',
#     'transaction',
#     '_',
#     'log',
#     '.',
#     'created',
#     'des',
#     '##c',
#     '[SEP]'],
#    'encoded_tokens': [101,
#     2507,
#     2033,
#     1996,
#     2862,
#     1997,
#     3198,
#     2545,
#     2040,
#     2081,
#     1037,
#     7909,
#     2682,
#     4868,
#     1010,
#     1998,
#     2131,
#     1996,
#     6745,
#     2426,
#     2035,
#     1997,
#     2122,
#     11817,
#     2005,
#     2169,
#     3198,
#     2121,
#     1012,
#     4066,
#     1996,
#     2862,
#     2011,
#     5309,
#     2051,
#     1999,
#     15127,
#     2344,
#     1012,
#     102,
#     7276,
#     4098,
#     1006,
#     4167,
#     13334,
#     1035,
#     12598,
#     1035,
#     8833,
#     1012,
#     3198,
#     2121,
#     1035,
#     8909,
#     1007,
#     1010,
#     3291,
#     1012,
#     3198,
#     2121,
#     1035,
#     8909,
#     2013,
#     4167,
#     13334,
#     1035,
#     12598,
#     1035,
#     8833,
#     3693,
#     3291,
#     2006,
#     3291,
#     1012,
#     3198,
#     2121,
#     1035,
#     8909,
#     1027,
#     4167,
#     13334,
#     1035,
#     12598,
#     1035,
#     8833,
#     1012,
#     3198,
#     2121,
#     1035,
#     8909,
#     2073,
#     4167,
#     13334,
#     1035,
#     12598,
#     1035,
#     8833,
#     1012,
#     3976,
#     1028,
#     1005,
#     3643,
#     1005,
#     2177,
#     2011,
#     3291,
#     1012,
#     3198,
#     2121,
#     1035,
#     8909,
#     2344,
#     2011,
#     4167,
#     13334,
#     1035,
#     12598,
#     1035,
#     8833,
#     1012,
#     2580,
#     4078,
#     2278,
#     102],
#    'rank': 9},
#   {'sql_query': "select max ( braintree_transaction_log.created ) , problem.asker_id from braintree_transaction_log join problem on braintree_transaction_log.asker_id = problem.asker_id where braintree_transaction_log.price > ' value ' group by problem.asker_id order by max ( braintree_transaction_log.created ) desc",
#    'tables_used': ['braintree_transaction_log', 'problem'],
#    'columns_used': [['braintree_transaction_log', 'price'],
#     ['braintree_transaction_log', 'asker_id'],
#     ['problem', 'asker_id'],
#     ['braintree_transaction_log', 'created']],
#    'target': 0.0,
#    'tokens': ['[CLS]',
#     'give',
#     'me',
#     'the',
#     'list',
#     'of',
#     'ask',
#     '##ers',
#     'who',
#     'made',
#     'a',
#     'payment',
#     'above',
#     '51',
#     ',',
#     'and',
#     'get',
#     'the',
#     'latest',
#     'among',
#     'all',
#     'of',
#     'these',
#     'transactions',
#     'for',
#     'each',
#     'ask',
#     '##er',
#     '.',
#     'sort',
#     'the',
#     'list',
#     'by',
#     'purchase',
#     'time',
#     'in',
#     'descending',
#     'order',
#     '.',
#     '[SEP]',
#     'select',
#     'max',
#     '(',
#     'brain',
#     '##tree',
#     '_',
#     'transaction',
#     '_',
#     'log',
#     '.',
#     'created',
#     ')',
#     ',',
#     'problem',
#     '.',
#     'ask',
#     '##er',
#     '_',
#     'id',
#     'from',
#     'brain',
#     '##tree',
#     '_',
#     'transaction',
#     '_',
#     'log',
#     'join',
#     'problem',
#     'on',
#     'brain',
#     '##tree',
#     '_',
#     'transaction',
#     '_',
#     'log',
#     '.',
#     'ask',
#     '##er',
#     '_',
#     'id',
#     '=',
#     'problem',
#     '.',
#     'ask',
#     '##er',
#     '_',
#     'id',
#     'where',
#     'brain',
#     '##tree',
#     '_',
#     'transaction',
#     '_',
#     'log',
#     '.',
#     'price',
#     '>',
#     "'",
#     'value',
#     "'",
#     'group',
#     'by',
#     'problem',
#     '.',
#     'ask',
#     '##er',
#     '_',
#     'id',
#     'order',
#     'by',
#     'max',
#     '(',
#     'brain',
#     '##tree',
#     '_',
#     'transaction',
#     '_',
#     'log',
#     '.',
#     'created',
#     ')',
#     'des',
#     '##c',
#     '[SEP]'],
#    'encoded_tokens': [101,
#     2507,
#     2033,
#     1996,
#     2862,
#     1997,
#     3198,
#     2545,
#     2040,
#     2081,
#     1037,
#     7909,
#     2682,
#     4868,
#     1010,
#     1998,
#     2131,
#     1996,
#     6745,
#     2426,
#     2035,
#     1997,
#     2122,
#     11817,
#     2005,
#     2169,
#     3198,
#     2121,
#     1012,
#     4066,
#     1996,
#     2862,
#     2011,
#     5309,
#     2051,
#     1999,
#     15127,
#     2344,
#     1012,
#     102,
#     7276,
#     4098,
#     1006,
#     4167,
#     13334,
#     1035,
#     12598,
#     1035,
#     8833,
#     1012,
#     2580,
#     1007,
#     1010,
#     3291,
#     1012,
#     3198,
#     2121,
#     1035,
#     8909,
#     2013,
#     4167,
#     13334,
#     1035,
#     12598,
#     1035,
#     8833,
#     3693,
#     3291,
#     2006,
#     4167,
#     13334,
#     1035,
#     12598,
#     1035,
#     8833,
#     1012,
#     3198,
#     2121,
#     1035,
#     8909,
#     1027,
#     3291,
#     1012,
#     3198,
#     2121,
#     1035,
#     8909,
#     2073,
#     4167,
#     13334,
#     1035,
#     12598,
#     1035,
#     8833,
#     1012,
#     3976,
#     1028,
#     1005,
#     3643,
#     1005,
#     2177,
#     2011,
#     3291,
#     1012,
#     3198,
#     2121,
#     1035,
#     8909,
#     2344,
#     2011,
#     4098,
#     1006,
#     4167,
#     13334,
#     1035,
#     12598,
#     1035,
#     8833,
#     1012,
#     2580,
#     1007,
#     4078,
#     2278,
#     102],
#    'rank': 10},
#   {'sql_query': "select max ( braintree_transaction_log.asker_id ) , asker.id from asker join braintree_transaction_log on braintree_transaction_log.asker_id = asker.id where braintree_transaction_log.price > ' value ' group by asker.id order by braintree_transaction_log.created desc",
#    'tables_used': ['braintree_transaction_log', 'asker'],
#    'columns_used': [['braintree_transaction_log', 'price'],
#     ['braintree_transaction_log', 'asker_id'],
#     ['asker', 'id'],
#     ['braintree_transaction_log', 'created']],
#    'target': 0.0,
#    'tokens': ['[CLS]',
#     'give',
#     'me',
#     'the',
#     'list',
#     'of',
#     'ask',
#     '##ers',
#     'who',
#     'made',
#     'a',
#     'payment',
#     'above',
#     '51',
#     ',',
#     'and',
#     'get',
#     'the',
#     'latest',
#     'among',
#     'all',
#     'of',
#     'these',
#     'transactions',
#     'for',
#     'each',
#     'ask',
#     '##er',
#     '.',
#     'sort',
#     'the',
#     'list',
#     'by',
#     'purchase',
#     'time',
#     'in',
#     'descending',
#     'order',
#     '.',
#     '[SEP]',
#     'select',
#     'max',
#     '(',
#     'brain',
#     '##tree',
#     '_',
#     'transaction',
#     '_',
#     'log',
#     '.',
#     'ask',
#     '##er',
#     '_',
#     'id',
#     ')',
#     ',',
#     'ask',
#     '##er',
#     '.',
#     'id',
#     'from',
#     'ask',
#     '##er',
#     'join',
#     'brain',
#     '##tree',
#     '_',
#     'transaction',
#     '_',
#     'log',
#     'on',
#     'brain',
#     '##tree',
#     '_',
#     'transaction',
#     '_',
#     'log',
#     '.',
#     'ask',
#     '##er',
#     '_',
#     'id',
#     '=',
#     'ask',
#     '##er',
#     '.',
#     'id',
#     'where',
#     'brain',
#     '##tree',
#     '_',
#     'transaction',
#     '_',
#     'log',
#     '.',
#     'price',
#     '>',
#     "'",
#     'value',
#     "'",
#     'group',
#     'by',
#     'ask',
#     '##er',
#     '.',
#     'id',
#     'order',
#     'by',
#     'brain',
#     '##tree',
#     '_',
#     'transaction',
#     '_',
#     'log',
#     '.',
#     'created',
#     'des',
#     '##c',
#     '[SEP]'],
#    'encoded_tokens': [101,
#     2507,
#     2033,
#     1996,
#     2862,
#     1997,
#     3198,
#     2545,
#     2040,
#     2081,
#     1037,
#     7909,
#     2682,
#     4868,
#     1010,
#     1998,
#     2131,
#     1996,
#     6745,
#     2426,
#     2035,
#     1997,
#     2122,
#     11817,
#     2005,
#     2169,
#     3198,
#     2121,
#     1012,
#     4066,
#     1996,
#     2862,
#     2011,
#     5309,
#     2051,
#     1999,
#     15127,
#     2344,
#     1012,
#     102,
#     7276,
#     4098,
#     1006,
#     4167,
#     13334,
#     1035,
#     12598,
#     1035,
#     8833,
#     1012,
#     3198,
#     2121,
#     1035,
#     8909,
#     1007,
#     1010,
#     3198,
#     2121,
#     1012,
#     8909,
#     2013,
#     3198,
#     2121,
#     3693,
#     4167,
#     13334,
#     1035,
#     12598,
#     1035,
#     8833,
#     2006,
#     4167,
#     13334,
#     1035,
#     12598,
#     1035,
#     8833,
#     1012,
#     3198,
#     2121,
#     1035,
#     8909,
#     1027,
#     3198,
#     2121,
#     1012,
#     8909,
#     2073,
#     4167,
#     13334,
#     1035,
#     12598,
#     1035,
#     8833,
#     1012,
#     3976,
#     1028,
#     1005,
#     3643,
#     1005,
#     2177,
#     2011,
#     3198,
#     2121,
#     1012,
#     8909,
#     2344,
#     2011,
#     4167,
#     13334,
#     1035,
#     12598,
#     1035,
#     8833,
#     1012,
#     2580,
#     4078,
#     2278,
#     102],
#    'rank': 11},
#   {'sql_query': "select max ( braintree_transaction_log.asker_id ) , problem.asker_id from problem join braintree_transaction_log on problem.asker_id = braintree_transaction_log.asker_id where braintree_transaction_log.price > ' value ' group by problem.asker_id order by braintree_transaction_log.created desc",
#    'tables_used': ['braintree_transaction_log', 'problem'],
#    'columns_used': [['braintree_transaction_log', 'price'],
#     ['braintree_transaction_log', 'asker_id'],
#     ['problem', 'asker_id'],
#     ['braintree_transaction_log', 'created']],
#    'target': 0.0,
#    'tokens': ['[CLS]',
#     'give',
#     'me',
#     'the',
#     'list',
#     'of',
#     'ask',
#     '##ers',
#     'who',
#     'made',
#     'a',
#     'payment',
#     'above',
#     '51',
#     ',',
#     'and',
#     'get',
#     'the',
#     'latest',
#     'among',
#     'all',
#     'of',
#     'these',
#     'transactions',
#     'for',
#     'each',
#     'ask',
#     '##er',
#     '.',
#     'sort',
#     'the',
#     'list',
#     'by',
#     'purchase',
#     'time',
#     'in',
#     'descending',
#     'order',
#     '.',
#     '[SEP]',
#     'select',
#     'max',
#     '(',
#     'brain',
#     '##tree',
#     '_',
#     'transaction',
#     '_',
#     'log',
#     '.',
#     'ask',
#     '##er',
#     '_',
#     'id',
#     ')',
#     ',',
#     'problem',
#     '.',
#     'ask',
#     '##er',
#     '_',
#     'id',
#     'from',
#     'problem',
#     'join',
#     'brain',
#     '##tree',
#     '_',
#     'transaction',
#     '_',
#     'log',
#     'on',
#     'problem',
#     '.',
#     'ask',
#     '##er',
#     '_',
#     'id',
#     '=',
#     'brain',
#     '##tree',
#     '_',
#     'transaction',
#     '_',
#     'log',
#     '.',
#     'ask',
#     '##er',
#     '_',
#     'id',
#     'where',
#     'brain',
#     '##tree',
#     '_',
#     'transaction',
#     '_',
#     'log',
#     '.',
#     'price',
#     '>',
#     "'",
#     'value',
#     "'",
#     'group',
#     'by',
#     'problem',
#     '.',
#     'ask',
#     '##er',
#     '_',
#     'id',
#     'order',
#     'by',
#     'brain',
#     '##tree',
#     '_',
#     'transaction',
#     '_',
#     'log',
#     '.',
#     'created',
#     'des',
#     '##c',
#     '[SEP]'],
#    'encoded_tokens': [101,
#     2507,
#     2033,
#     1996,
#     2862,
#     1997,
#     3198,
#     2545,
#     2040,
#     2081,
#     1037,
#     7909,
#     2682,
#     4868,
#     1010,
#     1998,
#     2131,
#     1996,
#     6745,
#     2426,
#     2035,
#     1997,
#     2122,
#     11817,
#     2005,
#     2169,
#     3198,
#     2121,
#     1012,
#     4066,
#     1996,
#     2862,
#     2011,
#     5309,
#     2051,
#     1999,
#     15127,
#     2344,
#     1012,
#     102,
#     7276,
#     4098,
#     1006,
#     4167,
#     13334,
#     1035,
#     12598,
#     1035,
#     8833,
#     1012,
#     3198,
#     2121,
#     1035,
#     8909,
#     1007,
#     1010,
#     3291,
#     1012,
#     3198,
#     2121,
#     1035,
#     8909,
#     2013,
#     3291,
#     3693,
#     4167,
#     13334,
#     1035,
#     12598,
#     1035,
#     8833,
#     2006,
#     3291,
#     1012,
#     3198,
#     2121,
#     1035,
#     8909,
#     1027,
#     4167,
#     13334,
#     1035,
#     12598,
#     1035,
#     8833,
#     1012,
#     3198,
#     2121,
#     1035,
#     8909,
#     2073,
#     4167,
#     13334,
#     1035,
#     12598,
#     1035,
#     8833,
#     1012,
#     3976,
#     1028,
#     1005,
#     3643,
#     1005,
#     2177,
#     2011,
#     3291,
#     1012,
#     3198,
#     2121,
#     1035,
#     8909,
#     2344,
#     2011,
#     4167,
#     13334,
#     1035,
#     12598,
#     1035,
#     8833,
#     1012,
#     2580,
#     4078,
#     2278,
#     102],
#    'rank': 12},
#   {'sql_query': "select max ( braintree_transaction_log.created ) , problem.asker_id from problem join braintree_transaction_log on braintree_transaction_log.asker_id = problem.asker_id where braintree_transaction_log.price > ' value ' group by problem.asker_id order by braintree_transaction_log.created desc",
#    'tables_used': ['braintree_transaction_log', 'problem'],
#    'columns_used': [['braintree_transaction_log', 'price'],
#     ['braintree_transaction_log', 'asker_id'],
#     ['problem', 'asker_id'],
#     ['braintree_transaction_log', 'created']],
#    'target': 0.0,
#    'tokens': ['[CLS]',
#     'give',
#     'me',
#     'the',
#     'list',
#     'of',
#     'ask',
#     '##ers',
#     'who',
#     'made',
#     'a',
#     'payment',
#     'above',
#     '51',
#     ',',
#     'and',
#     'get',
#     'the',
#     'latest',
#     'among',
#     'all',
#     'of',
#     'these',
#     'transactions',
#     'for',
#     'each',
#     'ask',
#     '##er',
#     '.',
#     'sort',
#     'the',
#     'list',
#     'by',
#     'purchase',
#     'time',
#     'in',
#     'descending',
#     'order',
#     '.',
#     '[SEP]',
#     'select',
#     'max',
#     '(',
#     'brain',
#     '##tree',
#     '_',
#     'transaction',
#     '_',
#     'log',
#     '.',
#     'created',
#     ')',
#     ',',
#     'problem',
#     '.',
#     'ask',
#     '##er',
#     '_',
#     'id',
#     'from',
#     'problem',
#     'join',
#     'brain',
#     '##tree',
#     '_',
#     'transaction',
#     '_',
#     'log',
#     'on',
#     'brain',
#     '##tree',
#     '_',
#     'transaction',
#     '_',
#     'log',
#     '.',
#     'ask',
#     '##er',
#     '_',
#     'id',
#     '=',
#     'problem',
#     '.',
#     'ask',
#     '##er',
#     '_',
#     'id',
#     'where',
#     'brain',
#     '##tree',
#     '_',
#     'transaction',
#     '_',
#     'log',
#     '.',
#     'price',
#     '>',
#     "'",
#     'value',
#     "'",
#     'group',
#     'by',
#     'problem',
#     '.',
#     'ask',
#     '##er',
#     '_',
#     'id',
#     'order',
#     'by',
#     'brain',
#     '##tree',
#     '_',
#     'transaction',
#     '_',
#     'log',
#     '.',
#     'created',
#     'des',
#     '##c',
#     '[SEP]'],
#    'encoded_tokens': [101,
#     2507,
#     2033,
#     1996,
#     2862,
#     1997,
#     3198,
#     2545,
#     2040,
#     2081,
#     1037,
#     7909,
#     2682,
#     4868,
#     1010,
#     1998,
#     2131,
#     1996,
#     6745,
#     2426,
#     2035,
#     1997,
#     2122,
#     11817,
#     2005,
#     2169,
#     3198,
#     2121,
#     1012,
#     4066,
#     1996,
#     2862,
#     2011,
#     5309,
#     2051,
#     1999,
#     15127,
#     2344,
#     1012,
#     102,
#     7276,
#     4098,
#     1006,
#     4167,
#     13334,
#     1035,
#     12598,
#     1035,
#     8833,
#     1012,
#     2580,
#     1007,
#     1010,
#     3291,
#     1012,
#     3198,
#     2121,
#     1035,
#     8909,
#     2013,
#     3291,
#     3693,
#     4167,
#     13334,
#     1035,
#     12598,
#     1035,
#     8833,
#     2006,
#     4167,
#     13334,
#     1035,
#     12598,
#     1035,
#     8833,
#     1012,
#     3198,
#     2121,
#     1035,
#     8909,
#     1027,
#     3291,
#     1012,
#     3198,
#     2121,
#     1035,
#     8909,
#     2073,
#     4167,
#     13334,
#     1035,
#     12598,
#     1035,
#     8833,
#     1012,
#     3976,
#     1028,
#     1005,
#     3643,
#     1005,
#     2177,
#     2011,
#     3291,
#     1012,
#     3198,
#     2121,
#     1035,
#     8909,
#     2344,
#     2011,
#     4167,
#     13334,
#     1035,
#     12598,
#     1035,
#     8833,
#     1012,
#     2580,
#     4078,
#     2278,
#     102],
#    'rank': 13},
#   {'sql_query': "select max ( braintree_transaction_log.asker_id ) , asker.id from asker join braintree_transaction_log on asker.id = braintree_transaction_log.asker_id where braintree_transaction_log.price > ' value ' group by asker.id order by braintree_transaction_log.created desc",
#    'tables_used': ['braintree_transaction_log', 'asker'],
#    'columns_used': [['braintree_transaction_log', 'price'],
#     ['braintree_transaction_log', 'asker_id'],
#     ['asker', 'id'],
#     ['braintree_transaction_log', 'created']],
#    'target': 0.0,
#    'tokens': ['[CLS]',
#     'give',
#     'me',
#     'the',
#     'list',
#     'of',
#     'ask',
#     '##ers',
#     'who',
#     'made',
#     'a',
#     'payment',
#     'above',
#     '51',
#     ',',
#     'and',
#     'get',
#     'the',
#     'latest',
#     'among',
#     'all',
#     'of',
#     'these',
#     'transactions',
#     'for',
#     'each',
#     'ask',
#     '##er',
#     '.',
#     'sort',
#     'the',
#     'list',
#     'by',
#     'purchase',
#     'time',
#     'in',
#     'descending',
#     'order',
#     '.',
#     '[SEP]',
#     'select',
#     'max',
#     '(',
#     'brain',
#     '##tree',
#     '_',
#     'transaction',
#     '_',
#     'log',
#     '.',
#     'ask',
#     '##er',
#     '_',
#     'id',
#     ')',
#     ',',
#     'ask',
#     '##er',
#     '.',
#     'id',
#     'from',
#     'ask',
#     '##er',
#     'join',
#     'brain',
#     '##tree',
#     '_',
#     'transaction',
#     '_',
#     'log',
#     'on',
#     'ask',
#     '##er',
#     '.',
#     'id',
#     '=',
#     'brain',
#     '##tree',
#     '_',
#     'transaction',
#     '_',
#     'log',
#     '.',
#     'ask',
#     '##er',
#     '_',
#     'id',
#     'where',
#     'brain',
#     '##tree',
#     '_',
#     'transaction',
#     '_',
#     'log',
#     '.',
#     'price',
#     '>',
#     "'",
#     'value',
#     "'",
#     'group',
#     'by',
#     'ask',
#     '##er',
#     '.',
#     'id',
#     'order',
#     'by',
#     'brain',
#     '##tree',
#     '_',
#     'transaction',
#     '_',
#     'log',
#     '.',
#     'created',
#     'des',
#     '##c',
#     '[SEP]'],
#    'encoded_tokens': [101,
#     2507,
#     2033,
#     1996,
#     2862,
#     1997,
#     3198,
#     2545,
#     2040,
#     2081,
#     1037,
#     7909,
#     2682,
#     4868,
#     1010,
#     1998,
#     2131,
#     1996,
#     6745,
#     2426,
#     2035,
#     1997,
#     2122,
#     11817,
#     2005,
#     2169,
#     3198,
#     2121,
#     1012,
#     4066,
#     1996,
#     2862,
#     2011,
#     5309,
#     2051,
#     1999,
#     15127,
#     2344,
#     1012,
#     102,
#     7276,
#     4098,
#     1006,
#     4167,
#     13334,
#     1035,
#     12598,
#     1035,
#     8833,
#     1012,
#     3198,
#     2121,
#     1035,
#     8909,
#     1007,
#     1010,
#     3198,
#     2121,
#     1012,
#     8909,
#     2013,
#     3198,
#     2121,
#     3693,
#     4167,
#     13334,
#     1035,
#     12598,
#     1035,
#     8833,
#     2006,
#     3198,
#     2121,
#     1012,
#     8909,
#     1027,
#     4167,
#     13334,
#     1035,
#     12598,
#     1035,
#     8833,
#     1012,
#     3198,
#     2121,
#     1035,
#     8909,
#     2073,
#     4167,
#     13334,
#     1035,
#     12598,
#     1035,
#     8833,
#     1012,
#     3976,
#     1028,
#     1005,
#     3643,
#     1005,
#     2177,
#     2011,
#     3198,
#     2121,
#     1012,
#     8909,
#     2344,
#     2011,
#     4167,
#     13334,
#     1035,
#     12598,
#     1035,
#     8833,
#     1012,
#     2580,
#     4078,
# ...
#     'brain',
#     '##tree',
#     '_',
#     'transaction',
#     '_',
#     'log',
#     '.',
#     'created',
#     ')',
#     ',',
#     'problem',
#     '.',
#     'ask',
#     '##er',
#     '_',
#     'id',
#     'from',
#     'brain',
#     '##tree',
#     '_',
#     'transaction',
#     '_',
#     'log',
#     'join',
#     'problem',
#     'on',
#     'brain',
#     '##tree',
#     '_',
#     'transaction',
#     '_',
#     'log',
#     '.',
#     'ask',
#     '##er',
#     '_',
#     'id',
#     '=',
#     'problem',
#     '.',
#     'ask',
#     '##er',
#     '_',
#     'id',
#     'where',
#     'brain',
#     '##tree',
#     '_',
#     'transaction',
#     '_',
#     'log',
#     '.',
#     'price',
#     '>',
#     "'",
#     'value',
#     "'",
#     'group',
#     'by',
#     'brain',
#     '##tree',
#     '_',
#     'transaction',
#     '_',
#     'log',
#     '.',
#     'ask',
#     '##er',
#     '_',
#     'id',
#     'order',
#     'by',
#     'brain',
#     '##tree',
#     '_',
#     'transaction',
#     '_',
#     'log',
#     '.',
#     'created',
#     'des',
#     '##c',
#     '[SEP]'],
#    'encoded_tokens': [101,
#     2507,
#     2033,
#     1996,
#     2862,
#     1997,
#     3198,
#     2545,
#     2040,
#     2081,
#     1037,
#     7909,
#     2682,
#     4868,
#     1010,
#     1998,
#     2131,
#     1996,
#     6745,
#     2426,
#     2035,
#     1997,
#     2122,
#     11817,
#     2005,
#     2169,
#     3198,
#     2121,
#     1012,
#     4066,
#     1996,
#     2862,
#     2011,
#     5309,
#     2051,
#     1999,
#     15127,
#     2344,
#     1012,
#     102,
#     7276,
#     4098,
#     1006,
#     4167,
#     13334,
#     1035,
#     12598,
#     1035,
#     8833,
#     1012,
#     2580,
#     1007,
#     1010,
#     3291,
#     1012,
#     3198,
#     2121,
#     1035,
#     8909,
#     2013,
#     4167,
#     13334,
#     1035,
#     12598,
#     1035,
#     8833,
#     3693,
#     3291,
#     2006,
#     4167,
#     13334,
#     1035,
#     12598,
#     1035,
#     8833,
#     1012,
#     3198,
#     2121,
#     1035,
#     8909,
#     1027,
#     3291,
#     1012,
#     3198,
#     2121,
#     1035,
#     8909,
#     2073,
#     4167,
#     13334,
#     1035,
#     12598,
#     1035,
#     8833,
#     1012,
#     3976,
#     1028,
#     1005,
#     3643,
#     1005,
#     2177,
#     2011,
#     4167,
#     13334,
#     1035,
#     12598,
#     1035,
#     8833,
#     1012,
#     3198,
#     2121,
#     1035,
#     8909,
#     2344,
#     2011,
#     4167,
#     13334,
#     1035,
#     12598,
#     1035,
#     8833,
#     1012,
#     2580,
#     4078,
#     2278,
#     102],
#    'rank': 35},
#   {'sql_query': "select max ( braintree_transaction_log.created ) , problem.asker_id from braintree_transaction_log join subscription on subscription.purchaser_id = braintree_transaction_log.asker_id where braintree_transaction_log.price > ' value ' group by braintree_transaction_log.asker_id order by max ( braintree_transaction_log.created ) desc",
#    'tables_used': ['braintree_transaction_log', 'subscription'],
#    'columns_used': [['subscription', 'purchaser_id'],
#     ['problem', 'asker_id'],
#     ['braintree_transaction_log', 'price'],
#     ['braintree_transaction_log', 'asker_id'],
#     ['braintree_transaction_log', 'created']],
#    'target': 0.0,
#    'tokens': ['[CLS]',
#     'give',
#     'me',
#     'the',
#     'list',
#     'of',
#     'ask',
#     '##ers',
#     'who',
#     'made',
#     'a',
#     'payment',
#     'above',
#     '51',
#     ',',
#     'and',
#     'get',
#     'the',
#     'latest',
#     'among',
#     'all',
#     'of',
#     'these',
#     'transactions',
#     'for',
#     'each',
#     'ask',
#     '##er',
#     '.',
#     'sort',
#     'the',
#     'list',
#     'by',
#     'purchase',
#     'time',
#     'in',
#     'descending',
#     'order',
#     '.',
#     '[SEP]',
#     'select',
#     'max',
#     '(',
#     'brain',
#     '##tree',
#     '_',
#     'transaction',
#     '_',
#     'log',
#     '.',
#     'created',
#     ')',
#     ',',
#     'problem',
#     '.',
#     'ask',
#     '##er',
#     '_',
#     'id',
#     'from',
#     'brain',
#     '##tree',
#     '_',
#     'transaction',
#     '_',
#     'log',
#     'join',
#     'subscription',
#     'on',
#     'subscription',
#     '.',
#     'purchase',
#     '##r',
#     '_',
#     'id',
#     '=',
#     'brain',
#     '##tree',
#     '_',
#     'transaction',
#     '_',
#     'log',
#     '.',
#     'ask',
#     '##er',
#     '_',
#     'id',
#     'where',
#     'brain',
#     '##tree',
#     '_',
#     'transaction',
#     '_',
#     'log',
#     '.',
#     'price',
#     '>',
#     "'",
#     'value',
#     "'",
#     'group',
#     'by',
#     'brain',
#     '##tree',
#     '_',
#     'transaction',
#     '_',
#     'log',
#     '.',
#     'ask',
#     '##er',
#     '_',
#     'id',
#     'order',
#     'by',
#     'max',
#     '(',
#     'brain',
#     '##tree',
#     '_',
#     'transaction',
#     '_',
#     'log',
#     '.',
#     'created',
#     ')',
#     'des',
#     '##c',
#     '[SEP]'],
#    'encoded_tokens': [101,
#     2507,
#     2033,
#     1996,
#     2862,
#     1997,
#     3198,
#     2545,
#     2040,
#     2081,
#     1037,
#     7909,
#     2682,
#     4868,
#     1010,
#     1998,
#     2131,
#     1996,
#     6745,
#     2426,
#     2035,
#     1997,
#     2122,
#     11817,
#     2005,
#     2169,
#     3198,
#     2121,
#     1012,
#     4066,
#     1996,
#     2862,
#     2011,
#     5309,
#     2051,
#     1999,
#     15127,
#     2344,
#     1012,
#     102,
#     7276,
#     4098,
#     1006,
#     4167,
#     13334,
#     1035,
#     12598,
#     1035,
#     8833,
#     1012,
#     2580,
#     1007,
#     1010,
#     3291,
#     1012,
#     3198,
#     2121,
#     1035,
#     8909,
#     2013,
#     4167,
#     13334,
#     1035,
#     12598,
#     1035,
#     8833,
#     3693,
#     15002,
#     2006,
#     15002,
#     1012,
#     5309,
#     2099,
#     1035,
#     8909,
#     1027,
#     4167,
#     13334,
#     1035,
#     12598,
#     1035,
#     8833,
#     1012,
#     3198,
#     2121,
#     1035,
#     8909,
#     2073,
#     4167,
#     13334,
#     1035,
#     12598,
#     1035,
#     8833,
#     1012,
#     3976,
#     1028,
#     1005,
#     3643,
#     1005,
#     2177,
#     2011,
#     4167,
#     13334,
#     1035,
#     12598,
#     1035,
#     8833,
#     1012,
#     3198,
#     2121,
#     1035,
#     8909,
#     2344,
#     2011,
#     4098,
#     1006,
#     4167,
#     13334,
#     1035,
#     12598,
#     1035,
#     8833,
#     1012,
#     2580,
#     1007,
#     4078,
#     2278,
#     102],
#    'rank': 36},
#   {'sql_query': "select max ( braintree_transaction_log.asker_id ) , problem.asker_id from braintree_transaction_log join problem on problem.asker_id = braintree_transaction_log.asker_id where braintree_transaction_log.price > ' value ' group by braintree_transaction_log.asker_id order by braintree_transaction_log.created desc",
#    'tables_used': ['braintree_transaction_log', 'problem'],
#    'columns_used': [['braintree_transaction_log', 'price'],
#     ['braintree_transaction_log', 'asker_id'],
#     ['problem', 'asker_id'],
#     ['braintree_transaction_log', 'created']],
#    'target': 0.0,
#    'tokens': ['[CLS]',
#     'give',
#     'me',
#     'the',
#     'list',
#     'of',
#     'ask',
#     '##ers',
#     'who',
#     'made',
#     'a',
#     'payment',
#     'above',
#     '51',
#     ',',
#     'and',
#     'get',
#     'the',
#     'latest',
#     'among',
#     'all',
#     'of',
#     'these',
#     'transactions',
#     'for',
#     'each',
#     'ask',
#     '##er',
#     '.',
#     'sort',
#     'the',
#     'list',
#     'by',
#     'purchase',
#     'time',
#     'in',
#     'descending',
#     'order',
#     '.',
#     '[SEP]',
#     'select',
#     'max',
#     '(',
#     'brain',
#     '##tree',
#     '_',
#     'transaction',
#     '_',
#     'log',
#     '.',
#     'ask',
#     '##er',
#     '_',
#     'id',
#     ')',
#     ',',
#     'problem',
#     '.',
#     'ask',
#     '##er',
#     '_',
#     'id',
#     'from',
#     'brain',
#     '##tree',
#     '_',
#     'transaction',
#     '_',
#     'log',
#     'join',
#     'problem',
#     'on',
#     'problem',
#     '.',
#     'ask',
#     '##er',
#     '_',
#     'id',
#     '=',
#     'brain',
#     '##tree',
#     '_',
#     'transaction',
#     '_',
#     'log',
#     '.',
#     'ask',
#     '##er',
#     '_',
#     'id',
#     'where',
#     'brain',
#     '##tree',
#     '_',
#     'transaction',
#     '_',
#     'log',
#     '.',
#     'price',
#     '>',
#     "'",
#     'value',
#     "'",
#     'group',
#     'by',
#     'brain',
#     '##tree',
#     '_',
#     'transaction',
#     '_',
#     'log',
#     '.',
#     'ask',
#     '##er',
#     '_',
#     'id',
#     'order',
#     'by',
#     'brain',
#     '##tree',
#     '_',
#     'transaction',
#     '_',
#     'log',
#     '.',
#     'created',
#     'des',
#     '##c',
#     '[SEP]'],
#    'encoded_tokens': [101,
#     2507,
#     2033,
#     1996,
#     2862,
#     1997,
#     3198,
#     2545,
#     2040,
#     2081,
#     1037,
#     7909,
#     2682,
#     4868,
#     1010,
#     1998,
#     2131,
#     1996,
#     6745,
#     2426,
#     2035,
#     1997,
#     2122,
#     11817,
#     2005,
#     2169,
#     3198,
#     2121,
#     1012,
#     4066,
#     1996,
#     2862,
#     2011,
#     5309,
#     2051,
#     1999,
#     15127,
#     2344,
#     1012,
#     102,
#     7276,
#     4098,
#     1006,
#     4167,
#     13334,
#     1035,
#     12598,
#     1035,
#     8833,
#     1012,
#     3198,
#     2121,
#     1035,
#     8909,
#     1007,
#     1010,
#     3291,
#     1012,
#     3198,
#     2121,
#     1035,
#     8909,
#     2013,
#     4167,
#     13334,
#     1035,
#     12598,
#     1035,
#     8833,
#     3693,
#     3291,
#     2006,
#     3291,
#     1012,
#     3198,
#     2121,
#     1035,
#     8909,
#     1027,
#     4167,
#     13334,
#     1035,
#     12598,
#     1035,
#     8833,
#     1012,
#     3198,
#     2121,
#     1035,
#     8909,
#     2073,
#     4167,
#     13334,
#     1035,
#     12598,
#     1035,
#     8833,
#     1012,
#     3976,
#     1028,
#     1005,
#     3643,
#     1005,
#     2177,
#     2011,
#     4167,
#     13334,
#     1035,
#     12598,
#     1035,
#     8833,
#     1012,
#     3198,
#     2121,
#     1035,
#     8909,
#     2344,
#     2011,
#     4167,
#     13334,
#     1035,
#     12598,
#     1035,
#     8833,
#     1012,
#     2580,
#     4078,
#     2278,
#     102],
#    'rank': 37},
#   {'sql_query': "select max ( braintree_transaction_log.asker_id ) , problem.asker_id from problem join braintree_transaction_log on braintree_transaction_log.asker_id = problem.asker_id where braintree_transaction_log.price > ' value ' group by problem.asker_id order by braintree_transaction_log.created desc",
#    'tables_used': ['braintree_transaction_log', 'problem'],
#    'columns_used': [['braintree_transaction_log', 'price'],
#     ['braintree_transaction_log', 'asker_id'],
#     ['problem', 'asker_id'],
#     ['braintree_transaction_log', 'created']],
#    'target': 0.0,
#    'tokens': ['[CLS]',
#     'give',
#     'me',
#     'the',
#     'list',
#     'of',
#     'ask',
#     '##ers',
#     'who',
#     'made',
#     'a',
#     'payment',
#     'above',
#     '51',
#     ',',
#     'and',
#     'get',
#     'the',
#     'latest',
#     'among',
#     'all',
#     'of',
#     'these',
#     'transactions',
#     'for',
#     'each',
#     'ask',
#     '##er',
#     '.',
#     'sort',
#     'the',
#     'list',
#     'by',
#     'purchase',
#     'time',
#     'in',
#     'descending',
#     'order',
#     '.',
#     '[SEP]',
#     'select',
#     'max',
#     '(',
#     'brain',
#     '##tree',
#     '_',
#     'transaction',
#     '_',
#     'log',
#     '.',
#     'ask',
#     '##er',
#     '_',
#     'id',
#     ')',
#     ',',
#     'problem',
#     '.',
#     'ask',
#     '##er',
#     '_',
#     'id',
#     'from',
#     'problem',
#     'join',
#     'brain',
#     '##tree',
#     '_',
#     'transaction',
#     '_',
#     'log',
#     'on',
#     'brain',
#     '##tree',
#     '_',
#     'transaction',
#     '_',
#     'log',
#     '.',
#     'ask',
#     '##er',
#     '_',
#     'id',
#     '=',
#     'problem',
#     '.',
#     'ask',
#     '##er',
#     '_',
#     'id',
#     'where',
#     'brain',
#     '##tree',
#     '_',
#     'transaction',
#     '_',
#     'log',
#     '.',
#     'price',
#     '>',
#     "'",
#     'value',
#     "'",
#     'group',
#     'by',
#     'problem',
#     '.',
#     'ask',
#     '##er',
#     '_',
#     'id',
#     'order',
#     'by',
#     'brain',
#     '##tree',
#     '_',
#     'transaction',
#     '_',
#     'log',
#     '.',
#     'created',
#     'des',
#     '##c',
#     '[SEP]'],
#    'encoded_tokens': [101,
#     2507,
#     2033,
#     1996,
#     2862,
#     1997,
#     3198,
#     2545,
#     2040,
#     2081,
#     1037,
#     7909,
#     2682,
#     4868,
#     1010,
#     1998,
#     2131,
#     1996,
#     6745,
#     2426,
#     2035,
#     1997,
#     2122,
#     11817,
#     2005,
#     2169,
#     3198,
#     2121,
#     1012,
#     4066,
#     1996,
#     2862,
#     2011,
#     5309,
#     2051,
#     1999,
#     15127,
#     2344,
#     1012,
#     102,
#     7276,
#     4098,
#     1006,
#     4167,
#     13334,
#     1035,
#     12598,
#     1035,
#     8833,
#     1012,
#     3198,
#     2121,
#     1035,
#     8909,
#     1007,
#     1010,
#     3291,
#     1012,
#     3198,
#     2121,
#     1035,
#     8909,
#     2013,
#     3291,
#     3693,
#     4167,
#     13334,
#     1035,
#     12598,
#     1035,
#     8833,
#     2006,
#     4167,
#     13334,
#     1035,
#     12598,
#     1035,
#     8833,
#     1012,
#     3198,
#     2121,
#     1035,
#     8909,
#     1027,
#     3291,
#     1012,
#     3198,
#     2121,
#     1035,
#     8909,
#     2073,
#     4167,
#     13334,
#     1035,
#     12598,
#     1035,
#     8833,
#     1012,
#     3976,
#     1028,
#     1005,
#     3643,
#     1005,
#     2177,
#     2011,
#     3291,
#     1012,
#     3198,
#     2121,
#     1035,
#     8909,
#     2344,
#     2011,
#     4167,
#     13334,
#     1035,
#     12598,
#     1035,
#     8833,
#     1012,
#     2580,
#     4078,
#     2278,
#     102],
#    'rank': 38},
#   {'sql_query': "select max ( braintree_transaction_log.created ) , problem.asker_id from braintree_transaction_log join problem on braintree_transaction_log.asker_id = problem.asker_id where braintree_transaction_log.price > ' value ' group by braintree_transaction_log.asker_id order by max ( braintree_transaction_log.created ) desc",
#    'tables_used': ['braintree_transaction_log', 'problem'],
#    'columns_used': [['braintree_transaction_log', 'price'],
#     ['braintree_transaction_log', 'asker_id'],
#     ['problem', 'asker_id'],
#     ['braintree_transaction_log', 'created']],
#    'target': 0.0,
#    'tokens': ['[CLS]',
#     'give',
#     'me',
#     'the',
#     'list',
#     'of',
#     'ask',
#     '##ers',
#     'who',
#     'made',
#     'a',
#     'payment',
#     'above',
#     '51',
#     ',',
#     'and',
#     'get',
#     'the',
#     'latest',
#     'among',
#     'all',
#     'of',
#     'these',
#     'transactions',
#     'for',
#     'each',
#     'ask',
#     '##er',
#     '.',
#     'sort',
#     'the',
#     'list',
#     'by',
#     'purchase',
#     'time',
#     'in',
#     'descending',
#     'order',
#     '.',
#     '[SEP]',
#     'select',
#     'max',
#     '(',
#     'brain',
#     '##tree',
#     '_',
#     'transaction',
#     '_',
#     'log',
#     '.',
#     'created',
#     ')',
#     ',',
#     'problem',
#     '.',
#     'ask',
#     '##er',
#     '_',
#     'id',
#     'from',
#     'brain',
#     '##tree',
#     '_',
#     'transaction',
#     '_',
#     'log',
#     'join',
#     'problem',
#     'on',
#     'brain',
#     '##tree',
#     '_',
#     'transaction',
#     '_',
#     'log',
#     '.',
#     'ask',
#     '##er',
#     '_',
#     'id',
#     '=',
#     'problem',
#     '.',
#     'ask',
#     '##er',
#     '_',
#     'id',
#     'where',
#     'brain',
#     '##tree',
#     '_',
#     'transaction',
#     '_',
#     'log',
#     '.',
#     'price',
#     '>',
#     "'",
#     'value',
#     "'",
#     'group',
#     'by',
#     'brain',
#     '##tree',
#     '_',
#     'transaction',
#     '_',
#     'log',
#     '.',
#     'ask',
#     '##er',
#     '_',
#     'id',
#     'order',
#     'by',
#     'max',
#     '(',
#     'brain',
#     '##tree',
#     '_',
#     'transaction',
#     '_',
#     'log',
#     '.',
#     'created',
#     ')',
#     'des',
#     '##c',
#     '[SEP]'],
#    'encoded_tokens': [101,
#     2507,
#     2033,
#     1996,
#     2862,
#     1997,
#     3198,
#     2545,
#     2040,
#     2081,
#     1037,
#     7909,
#     2682,
#     4868,
#     1010,
#     1998,
#     2131,
#     1996,
#     6745,
#     2426,
#     2035,
#     1997,
#     2122,
#     11817,
#     2005,
#     2169,
#     3198,
#     2121,
#     1012,
#     4066,
#     1996,
#     2862,
#     2011,
#     5309,
#     2051,
#     1999,
#     15127,
#     2344,
#     1012,
#     102,
#     7276,
#     4098,
#     1006,
#     4167,
#     13334,
#     1035,
#     12598,
#     1035,
#     8833,
#     1012,
#     2580,
#     1007,
#     1010,
#     3291,
#     1012,
#     3198,
#     2121,
#     1035,
#     8909,
#     2013,
#     4167,
#     13334,
#     1035,
#     12598,
#     1035,
#     8833,
#     3693,
#     3291,
#     2006,
#     4167,
#     13334,
#     1035,
#     12598,
#     1035,
#     8833,
#     1012,
#     3198,
#     2121,
#     1035,
#     8909,
#     1027,
#     3291,
#     1012,
#     3198,
#     2121,
#     1035,
#     8909,
#     2073,
#     4167,
#     13334,
#     1035,
#     12598,
#     1035,
#     8833,
#     1012,
#     3976,
#     1028,
#     1005,
#     3643,
#     1005,
#     2177,
#     2011,
#     4167,
#     13334,
#     1035,
#     12598,
#     1035,
#     8833,
#     1012,
#     3198,
#     2121,
#     1035,
#     8909,
#     2344,
#     2011,
#     4098,
#     1006,
#     4167,
#     13334,
#     1035,
#     12598,
#     1035,
#     8833,
#     1012,
#     2580,
#     1007,
#     4078,
#     2278,
#     102],
#    'rank': 39}]}

# %%
len(train_data_processed), len(val_data_processed)
# Out:
# (2896, 892)

# %%
import torch.utils.data
class BeamOutputDataset(torch.utils.data.Dataset):
    def __init__(self, items):
        self.items = items
        
    def __len__(self):
        return len(self.items)
    
    def __getitem__(self, idx):
        return self.items[idx]

# %%
train_dataset = BeamOutputDataset(train_data_processed)
val_dataset = BeamOutputDataset(val_data_processed)
#val_normaleval_dataset = BeamOutputDataset(val_data_normaleval_preprocessed)

# %%
 train_loader = torch.utils.data.DataLoader(
     batch_size=1,
     dataset=train_dataset,
     shuffle=True,
     collate_fn=lambda x: x # So dicts aren't merged
 )
val_loader = torch.utils.data.DataLoader(
    batch_size=1,
    dataset=val_dataset,
    shuffle=False,
    collate_fn=lambda x: x
)
# val_normaleval_loader = torch.utils.data.DataLoader(
#     batch_size=1,
#     dataset=val_normaleval_dataset,
#     shuffle=False,
#     collate_fn=lambda x: x
# )

# %%
train_bert = True

# %%
bert_model = BertForSequenceClassification.from_pretrained('bert-base-uncased', num_labels=2)
bert_model.load_state_dict(torch.load('best_discrim_model_full_spider_retrained_sqlonly.state.pth'))

# %%
def get_as_batch(batch, key):
    result = []
    for sample in batch:
        result.append(sample[key])
    return result

# %%
optim = torch.optim.Adam([
    {"params": bert_model.parameters(), "lr": 5e-6}  # 5e-6 converges faster than 1e-6
], lr=1e-6)

# %%
for param in bert_model.parameters():
    param.requires_grad = train_bert

# %%
bert_model.cuda()
# Out:
# BertForSequenceClassification(
#   (bert): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(30522, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm(torch.Size([768]), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm(torch.Size([768]), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm(torch.Size([768]), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1)
#           )
#         )
#         (1): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm(torch.Size([768]), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm(torch.Size([768]), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1)
#           )
#         )
#         (2): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm(torch.Size([768]), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm(torch.Size([768]), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1)
#           )
#         )
#         (3): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm(torch.Size([768]), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm(torch.Size([768]), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1)
#           )
#         )
#         (4): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm(torch.Size([768]), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm(torch.Size([768]), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1)
#           )
#         )
#         (5): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm(torch.Size([768]), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm(torch.Size([768]), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1)
#           )
#         )
#         (6): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm(torch.Size([768]), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm(torch.Size([768]), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1)
#           )
#         )
#         (7): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm(torch.Size([768]), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm(torch.Size([768]), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1)
#           )
#         )
#         (8): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm(torch.Size([768]), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm(torch.Size([768]), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1)
#           )
#         )
#         (9): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm(torch.Size([768]), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm(torch.Size([768]), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1)
#           )
#         )
#         (10): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm(torch.Size([768]), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm(torch.Size([768]), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1)
#           )
#         )
#         (11): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm(torch.Size([768]), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm(torch.Size([768]), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (dropout): Dropout(p=0.1)
#   (classifier): Linear(in_features=768, out_features=2, bias=True)
# )

# %%
def run_instance(bert_model, instance):
    encoded_tokens = torch.tensor(instance['encoded_tokens']).unsqueeze(0).cuda()
    target = int(instance['target'])
    labels = torch.tensor([target]).unsqueeze(0).cuda()
    outputs = bert_model(encoded_tokens, labels=labels)
    loss1, logits = outputs[:2]
    preds = F.softmax(logits, dim=1)
    pred_index = torch.argmax(preds[0])  # Remove batch
    if target == pred_index.item():
        correct = 1
    else:
        correct = 0
    return loss1, correct, preds

def run_epoch(bert_model, data_loader, train_bert, optim, training=True, print_samples=False):
    if training:
        bert_model.train()
        torch.set_grad_enabled(True)
    else:
        bert_model.eval()
        torch.set_grad_enabled(False)
        
    tk0 = tqdm(data_loader, total=int(len(data_loader)))
    running_loss = 0.0
    counter = 0
    counter_correct = 0
    for i, batch in enumerate(tk0):
        if training:
            optim.zero_grad()
        
        sample = batch[0]  # Assume batch size of 1
        loss = torch.tensor(0.0).cuda()
        for instance in sample['correct_instances']:
            loss1, correct, preds = run_instance(bert_model, instance)
            loss += loss1
            counter_correct += correct
            counter += 1
        
        num_incorrect = len(sample['incorrect_instances'])
        for instance in random.sample(sample['incorrect_instances'], min(10, num_incorrect)):
            loss1, correct, preds = run_instance(bert_model, instance)
            loss += loss1
            counter_correct += correct
            counter += 1
            
            
            
        if training:
            loss.backward()
            optim.step()          
        running_loss += loss.item()
        tk0.set_postfix(loss=(running_loss/counter),
                        acc=(counter_correct/counter))

# %%
## Smarter (than below) rerank algo that does a stable sort with a threshold value


import functools
def cmp(x, y):
    """
    Replacement for built-in function cmp that was removed in Python 3

    Compare the two objects x and y and return an integer according to
    the outcome. The return value is negative if x < y, zero if x == y
    and strictly positive if x > y.
    """

    return (x > y) - (x < y)

def compare(thresh, a, b):
    a = a['score']
    b = b['score'] + thresh
    return cmp(a, b)
    

def run_rerank(bert_model, data_loader, thresh, print_errors=False):
    bert_model.eval()
    torch.set_grad_enabled(False)
    
    tk0 = tqdm(data_loader, total=int(len(data_loader)))
    counter = 0
    counter_rerank_correct = 0
    counter_original_correct = 0
    
    compare_f = functools.partial(compare, thresh)
    
    for i, batch in enumerate(tk0):
        sample = batch[0]  # Assume batch size of 1
        counter += 1
        instances = sample['instances']
        original_correct = False
        if instances[0]['target'] > 0.5:
            original_correct = True
            counter_original_correct += 1
        
        preds = []
        myinstances = []
        for instance in instances[:10]:
            instance = instance.copy()
            loss, correct, pred = run_instance(bert_model, instance)
            preds.append(pred[0][1].item()) # Remove batch, get prob of 1
            instance['score'] = pred[0][1].item()
            myinstances.append(instance)
            
        pred_instance = list(reversed(sorted(myinstances, key=functools.cmp_to_key(compare_f))))[0]
        rerank_correct = False
        
        if pred_instance['target'] > 0.5:
            rerank_correct = True
            counter_rerank_correct += 1
        
        if print_errors and original_correct and not rerank_correct:
            print('\n')
            print('*' * 10)
            print(sample['utterance'])
            for index, ins in enumerate(sample['instances'][:10]):
                p = False
                if index == 0:
                    print('=' * 10)
                    print(f'CORRECT QUERY ; score: {ins["score"]:.2f}')
                    p = True
                if ins == pred_instance:
                    print('=' * 10)
                    print(f'SELECTED QUERY ; score: {ins["score"]:.2f}')
                    p = True
                if p:
                    print(ins['sql_query'])
                    print(ins['columns_used'])
                    print(ins['tables_used'])
            
        rerank_acc = counter_rerank_correct/counter
        tk0.set_postfix(original_acc=(counter_original_correct/counter),
                        rerank_acc=rerank_acc)
    return rerank_acc

# %%
# Simpler reranking that only compares the best with the top and accepts if it exceeds a threshold
# The one above seems to perform 0.3% better so we'll use that
# def run_rerank(bert_model, data_loader, thresh, print_errors=False):
#     bert_model.eval()
#     torch.set_grad_enabled(False)
    
#     tk0 = tqdm(data_loader, total=int(len(data_loader)))
#     counter = 0
#     counter_rerank_correct = 0
#     counter_original_correct = 0
    
#     for i, batch in enumerate(tk0):
#         sample = batch[0]  # Assume batch size of 1
#         counter += 1
#         instances = sample['instances']
#         original_correct = False
#         if instances[0]['target'] > 0.5:
#             original_correct = True
#             counter_original_correct += 1
        
#         preds = []
#         for instance in instances[:10]:
#             loss, correct, pred = run_instance(bert_model, instance)
#             preds.append(pred[0][1].item()) # Remove batch, get prob of 1
#         best_pred_index = preds.index(max(preds))  # Get the index of the max, picking the first one if there's a conflict
#         rerank_correct = False
#         if preds[best_pred_index] - preds[0] < thresh:
#             # We're only going to rerank if there's a large discrepancy
#             best_pred_index = 0
        
#         if instances[best_pred_index]['target'] > 0.5:
#             rerank_correct = True
#             counter_rerank_correct += 1
        
#         if print_errors and original_correct and not rerank_correct:
#             print('\n')
#             print('*' * 10)
#             print(sample['utterance'])
#             for index, ins in enumerate(sample['instances'][:10]):
#                 p = False
#                 if index == 0:
#                     print('=' * 10)
#                     print(f'CORRECT QUERY ; score: {preds[index]}')
#                     p = True
#                 if index == best_pred_index:
#                     print('=' * 10)
#                     print(f'SELECTED QUERY ; score: {preds[index]}')
#                     p = True
#                 if p:
#                     print(ins['sql_query'])
#                     print(ins['columns_used'])
#                     print(ins['tables_used'])
            
#         rerank_acc = counter_rerank_correct/counter
#         tk0.set_postfix(original_acc=(counter_original_correct/counter),
#                         rerank_acc=rerank_acc)
#     return rerank_acc

# %%
num_epochs = 10

print('Initial validation run')
best_rerank_acc = run_rerank(bert_model, val_loader, thresh=0.1, print_errors=False)
run_epoch(bert_model, val_loader, train_bert, optim, training=False, print_samples=False)
best_epoch = -1


for epoch in range(num_epochs):
    print('Epoch {}/{}'.format(epoch, num_epochs - 1))
    print('-' * 10)
    
    run_epoch(bert_model, train_loader, train_bert, optim, training=True)

    print('Validation')
    
    run_epoch(bert_model, val_loader, train_bert, optim, training=False)
    
    print('Rerank')
    
    rerank_acc = run_rerank(bert_model, val_loader, thresh=0.1, print_errors=False)
    if rerank_acc > best_rerank_acc:
        best_epoch = epoch
        best_rerank_acc = rerank_acc
        print(f'Saving model at epoch {epoch}')
        torch.save(bert_model, 'best_disrim_model.pth')
# Out:
# Initial validation run
# HBox(children=(IntProgress(value=0, max=892), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=892), HTML(value='')))
# Epoch 0/9
# ----------
# HBox(children=(IntProgress(value=0, max=2896), HTML(value='')))
# Validation
# HBox(children=(IntProgress(value=0, max=892), HTML(value='')))
# Rerank
# HBox(children=(IntProgress(value=0, max=892), HTML(value='')))
# Epoch 1/9
# ----------
# HBox(children=(IntProgress(value=0, max=2896), HTML(value='')))
# Validation
# HBox(children=(IntProgress(value=0, max=892), HTML(value='')))
# Rerank
# HBox(children=(IntProgress(value=0, max=892), HTML(value='')))
# Saving model at epoch 1
# Epoch 2/9
# ----------
# HBox(children=(IntProgress(value=0, max=2896), HTML(value='')))
# Validation
# HBox(children=(IntProgress(value=0, max=892), HTML(value='')))
# Rerank
# HBox(children=(IntProgress(value=0, max=892), HTML(value='')))
# Saving model at epoch 2
# Epoch 3/9
# ----------
# HBox(children=(IntProgress(value=0, max=2896), HTML(value='')))
# Validation
# HBox(children=(IntProgress(value=0, max=892), HTML(value='')))
# Rerank
# HBox(children=(IntProgress(value=0, max=892), HTML(value='')))
# Saving model at epoch 3
# Epoch 4/9
# ----------
# HBox(children=(IntProgress(value=0, max=2896), HTML(value='')))
# Validation
# HBox(children=(IntProgress(value=0, max=892), HTML(value='')))
# Rerank
# HBox(children=(IntProgress(value=0, max=892), HTML(value='')))
# Saving model at epoch 4
# Epoch 5/9
# ----------
# HBox(children=(IntProgress(value=0, max=2896), HTML(value='')))
# Validation
# HBox(children=(IntProgress(value=0, max=892), HTML(value='')))
# Rerank
# HBox(children=(IntProgress(value=0, max=892), HTML(value='')))
# Epoch 6/9
# ----------
# HBox(children=(IntProgress(value=0, max=2896), HTML(value='')))
# Validation
# HBox(children=(IntProgress(value=0, max=892), HTML(value='')))
# Rerank
# HBox(children=(IntProgress(value=0, max=892), HTML(value='')))
# Epoch 7/9
# ----------
# HBox(children=(IntProgress(value=0, max=2896), HTML(value='')))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-35-0b66e93367be> in <module>
#      11     print('-' * 10)
#      12
# ---> 13     run_epoch(bert_model, train_loader, train_bert, optim, training=True)
#      14
#      15     print('Validation')
#
# <ipython-input-30-83f8d5d99268> in run_epoch(bert_model, data_loader, train_bert, optim, training, print_samples)
#      47
#      48         if training:
# ---> 49             loss.backward()
#      50             optim.step()
#      51         running_loss += loss.item()
#
# ~/miniconda3/envs/spider-schema-gnn/lib/python3.7/site-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph)
#     100                 products. Defaults to ``False``.
#     101         """
# --> 102         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     103
#     104     def register_hook(self, hook):
#
# ~/miniconda3/envs/spider-schema-gnn/lib/python3.7/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#      88     Variable._execution_engine.run_backward(
#      89         tensors, grad_tensors, retain_graph, create_graph,
# ---> 90         allow_unreachable=True)  # allow_unreachable flag
#      91
#      92
#
# KeyboardInterrupt:

# %%
torch.save(bert_model, 'final_model.pth')

# %%
bert_model.load_state_dict(torch.load('best_discrim_model_EC30_retrained_sqlonly.state.pth'))
#with open('best_discrim_model_full_spider_retrained_sqlonly.state.pth', 'rb') as f:
    #file = f.read()
#    bert_model = torch.load(f)
bert_model.cuda()
# Out:
# BertForSequenceClassification(
#   (bert): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(30522, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm(torch.Size([768]), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm(torch.Size([768]), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm(torch.Size([768]), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1)
#           )
#         )
#         (1): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm(torch.Size([768]), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm(torch.Size([768]), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1)
#           )
#         )
#         (2): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm(torch.Size([768]), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm(torch.Size([768]), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1)
#           )
#         )
#         (3): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm(torch.Size([768]), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm(torch.Size([768]), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1)
#           )
#         )
#         (4): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm(torch.Size([768]), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm(torch.Size([768]), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1)
#           )
#         )
#         (5): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm(torch.Size([768]), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm(torch.Size([768]), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1)
#           )
#         )
#         (6): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm(torch.Size([768]), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm(torch.Size([768]), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1)
#           )
#         )
#         (7): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm(torch.Size([768]), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm(torch.Size([768]), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1)
#           )
#         )
#         (8): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm(torch.Size([768]), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm(torch.Size([768]), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1)
#           )
#         )
#         (9): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm(torch.Size([768]), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm(torch.Size([768]), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1)
#           )
#         )
#         (10): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm(torch.Size([768]), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm(torch.Size([768]), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1)
#           )
#         )
#         (11): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm(torch.Size([768]), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm(torch.Size([768]), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (dropout): Dropout(p=0.1)
#   (classifier): Linear(in_features=768, out_features=2, bias=True)
# )

# %%
torch.save(bert_model.state_dict(), 'best_discrim_model_EC30_retrained_sqlonly.state.pth')

# %%
run_rerank(bert_model, val_loader, thresh=0.10, print_errors=False)
# Out:
# HBox(children=(IntProgress(value=0, max=892), HTML(value='')))

# %% [markdown]
# ## All results with keep_unparsable = false (ie. 1020 devset)
#
# 54.8 (harder eval) vs 55.4 (normal eval)  # bert + gnn + train_spider + HIGH LR
#
# 50.1/54.5 (harder eval) vs 51.2/55.7 (normal eval) # non retrained reranker + bert + gnn + train_all
#
# 50.1/54.5 (harder eval) vs 51.2/56.3 (normal eval) # retrained ranker + bert + gnn + train_all
#
# 50.1/56.9 (harder eval) vs 51.2/57.8 (normal eval) # retrainer ranker (nl + sql) + bert + gnn + train_all
